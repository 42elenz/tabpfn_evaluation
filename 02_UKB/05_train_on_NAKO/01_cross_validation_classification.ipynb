# %%
from sklearn.metrics import accuracy_score, roc_auc_score
from sklearn.model_selection import train_test_split, StratifiedKFold
from tabpfn import TabPFNClassifier
import pandas as pd
import os
from tensorflow.keras.models import Sequential
from tensorflow.keras import layers
from scikeras.wrappers import KerasClassifier
import numpy as np
from sklearn.metrics import balanced_accuracy_score, classification_report
import lightgbm as lgb
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import label_binarize
import gc
import torch
from tensorflow.keras import backend as K
import  statsmodels.api as sm
from sklearn.decomposition import PCA
import warnings
warnings.filterwarnings('ignore')

# %%
def create_mlp_model(input_shape, num_classes):
    model = Sequential([
        layers.Dense(1024, activation="relu", input_shape=(input_shape,)),
        layers.Dropout(0.3),
        layers.Dense(512, activation="relu"),
        layers.Dropout(0.3),
        layers.Dense(256, activation="relu"),
        layers.Dropout(0.3),
        layers.Dense(128, activation="relu"),
        layers.Dropout(0.3),
        layers.Dense(num_classes, activation="softmax")
    ])
    model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
    return model

def create_cnn_model(input_shape, num_classes):
    model = Sequential([
        layers.Conv1D(128, kernel_size=3, activation='relu', input_shape=(input_shape[0], 1)),
        layers.MaxPooling1D(pool_size=2),
        layers.Conv1D(64, kernel_size=3, activation='relu'),
        layers.MaxPooling1D(pool_size=2),
        layers.Flatten(),
        layers.Dense(128, activation='relu'),
        layers.Dropout(0.3),
        layers.Dense(num_classes, activation='softmax')
    ])
    model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
    return model

# %%
def clean_up_cuda(model):
    # Delete the Keras model
    K.clear_session()
    del model
    
    # Run garbage collection
    gc.collect()
    
    # Free CUDA memory
    if torch.cuda.is_available():
        torch.cuda.empty_cache()
        torch.cuda.ipc_collect()
    
    print("CUDA memory cleared and model deleted.")

# %%
def feature_extraction_best_corr_with_target(X,X_val, X_control, y, threshold=0.6, df_columns=None, number_of_features=40):
    if isinstance(X, np.ndarray):
        X = pd.DataFrame(X)
        if df_columns is not None:
            X.columns = df_columns
    if isinstance(y, np.ndarray):
        y = pd.Series(y)
    if isinstance(x_val, np.ndarray):
        x_val = pd.DataFrame(x_val)
        if df_columns is not None:
            x_val.columns = df_columns
    if isinstance(x_control, np.ndarray):
        x_control = pd.DataFrame(x_control)
        if df_columns is not None:
            x_control.columns = df_columns
    correlation_matrix = X.corrwith(y).abs()
    to_keep = correlation_matrix.sort_values(ascending=False).head(number_of_features).index
    X = X[to_keep]
    X_val = X_val[to_keep]
    X_control = X_control[to_keep]
    X_ret = X.to_numpy().copy()
    X_val_ret = X_val.to_numpy().copy()
    X_control_ret = X_control.to_numpy().copy()
    return X_ret, X_val_ret, X_control_ret


def feature_extraction_with_Pearson(X, X_val, X_control, y, threshold=0.6, df_columns=None):
    if isinstance(X, np.ndarray):
        X = pd.DataFrame(X)
        if df_columns is not None:
            X.columns = df_columns
    if isinstance(X_val, np.ndarray):
        X_val = pd.DataFrame(X_val)
        if df_columns is not None:
            X_val.columns = df_columns
    if isinstance(X_control, np.ndarray):
        X_control = pd.DataFrame(X_control)
        if df_columns is not None:
            X_control.columns = df_columns
    correlation_matrix = X.corr().abs()
    upper = correlation_matrix.where(np.triu(np.ones(correlation_matrix.shape), k=1).astype(bool))
    to_drop = [column for column in upper.columns if any(upper[column] > threshold)]
    X = X.drop(columns=to_drop)
    X_val = X_val.drop(columns=to_drop)
    X_control = X_control.drop(columns=to_drop)
    X_ret = X.to_numpy().copy()
    X_val_ret = X_val.to_numpy().copy()
    X_control_ret = X_control.to_numpy().copy()
    return X_ret, X_val_ret, X_control_ret

def feature_extration_with_PCA(X, X_val, X_control, n_components):
    pca = PCA(n_components=n_components)
    X_pca = pca.fit_transform(X)
    X_val_pca = pca.transform(X_val)
    X_control_pca = pca.transform(X_control)
    return X_pca, X_val_pca, X_control_pca

def feature_extration_with_BE(X, X_val, X_control, y, significance_level=0.05, df_columns=None):
    if isinstance(X, np.ndarray):
        X = pd.DataFrame(X)
        if df_columns is not None:
            X.columns = df_columns
    if isinstance(X_val, np.ndarray):
        X_val = pd.DataFrame(X_val)
        if df_columns is not None:
            X_val.columns = df_columns
    if isinstance(X_control, np.ndarray):
        X_control = pd.DataFrame(X_control)
        if df_columns is not None:
            X_control.columns = df_columns
    # Add constant for intercept
    X = X.reset_index(drop=True)
    y = y.reset_index(drop=True)
    X = sm.add_constant(X)

    while True:
        # Fit the OLS model
        model = sm.OLS(y, X).fit()
        
        # Get the p-values for each feature
        p_values = model.pvalues
        
        # Find the feature with the highest p-value
        max_p_value = p_values.max()
        
        if max_p_value > significance_level:
            # Remove the feature with the highest p-value
            feature_to_remove = p_values.idxmax()
            print(f"Removing {feature_to_remove} with p-value {max_p_value:.4f}")
            X = X.drop(columns=[feature_to_remove])
            X_val = X_val.drop(columns=[feature_to_remove])
            X_control = X_control.drop(columns=[feature_to_remove])
        else:
            break
        print("Final Feature lengthe: ", len(X.columns))
    # Return the final selected feature set (excluding the intercept)
    X_ret = X.drop(columns=['const']).to_numpy().copy()
    X_val_ret = X_val.to_numpy().copy()
    X_control_ret = X_control.to_numpy().copy()
    return X_ret, X_val_ret, X_control_ret

# %%
# Example usage
def print_model_performance(results):
    """
    Print model performance metrics
    
    Parameters:
    results (dict): Performance metrics from evaluate_model_performance()
    """
    for metric, value in results.items():
        if metric == 'classification_report':
            print("\nClassification Report:")
            print(value)
        else:
            print(f"{metric.replace('_', ' ').title()}: {value}")
def aggregate_cv_metrics_and_print(all_results, model_name, tag="Validation"):
    """
    Aggregate cross-validation metrics
    
    Parameters:
    all_results (list): List of results dictionaries from each fold
    
    Returns:
    dict: Aggregated metrics with means and standard deviations
    """
    # Initialize aggregation dictionary
    aggregated = {
        'accuracy': [],
        'balanced_accuracy': [],
        'random_balanced_accuracy': [],
        'roc_auc': []
    }
    
    # Collect metrics from each fold
    for result in all_results:
        aggregated['accuracy'].append(result['accuracy'])
        aggregated['balanced_accuracy'].append(result['balanced_accuracy'])
        aggregated['random_balanced_accuracy'].append(result['random_balanced_accuracy'])
        aggregated['roc_auc'].append(result['roc_auc'])
    # Compute mean and standard deviation
    summary = {
        'mean_accuracy': np.mean(aggregated['accuracy']),
        'std_accuracy': np.std(aggregated['accuracy']),
        'mean_balanced_accuracy': np.mean(aggregated['balanced_accuracy']),
        'std_balanced_accuracy': np.std(aggregated['balanced_accuracy']),
        'mean_random_balanced_accuracy': np.mean(aggregated['random_balanced_accuracy']),
        'std_random_balanced_accuracy': np.std(aggregated['random_balanced_accuracy']),
        'mean_roc_auc': np.mean(aggregated['roc_auc']),
        'std_roc_auc': np.std(aggregated['roc_auc'])
    }
    
    print(f"\n {model_name} Classifier Performance {tag}:")
    print_model_performance(summary)
    return summary

# %%
mri_table = "aseg.volume_aparc.volume_aparc.thickness.csv"
df = pd.read_csv(f"../data/deconfounded_but_age/{mri_table}")
label_df = pd.read_csv("../00_data/age_label/all_ages_all_ids_healthy.csv")
n_splits = 5
label_col= "label_age_group"

label_df = label_df[['ID', 'label_age_group']]
merged_df = pd.merge(df, label_df, on='ID', how='inner')
merged_df.dropna(inplace=True)
df_sampled, _ = train_test_split(merged_df, train_size=10000, stratify=merged_df["label_age_group"], random_state=42)
df_sampled["label_age_group"].value_counts()
# Out:
# label_age_group
# 2.0    2931
# 3.0    2722
# 4.0    2056
# 1.0    1124
# 0.0    1020
# 5.0     147
# Name: count, dtype: int64

# %%
df_control = pd.read_csv("/zi/home/esra.lenz/Documents/00_HITKIP/09_TABPFN/01_Validation_data_set/00_data/final_folder/aparc.thickness_aparc.volume_aseg.volume.csv")
label_df_control = pd.read_csv("/zi/home/esra.lenz/Documents/00_HITKIP/09_TABPFN/01_Validation_data_set/00_data/final_folder/aparc.thickness_aparc.volume_aseg.volume_label.csv")

label_df_control = label_df_control[['ID', 'label_age_group']]
df_control = df_control[df.columns]
merged_df_control = pd.merge(df_control, label_df_control, on='ID', how='inner')
merged_df_control.dropna(inplace=True)

X_control = merged_df_control.drop(["ID", "label_age_group"], axis=1)
y_control = merged_df_control["label_age_group"]

merged_df_control["label_age_group"].value_counts()
# Out:
# label_age_group
# 0.0    320
# 2.0     76
# 1.0     61
# 3.0      7
# Name: count, dtype: int64

# %%
def evaluate_model_performance_train(y_test, y_pred, y_pred_proba, y_val_bin=None):
    # Compute basic metrics
    acc = accuracy_score(y_test, y_pred)
    balanced_acc = balanced_accuracy_score(y_test, y_pred)
    report = classification_report(y_test, y_pred)
    
    # Random comparison
    n_classes = len(np.unique(y_test))
    random_y_test = np.random.randint(0, n_classes, size=y_test.shape)
    random_balanced_acc = balanced_accuracy_score(random_y_test, y_pred)
    
    # ROC AUC (if probabilities provided)
    if y_val_bin is not None:
        y_test = y_val_bin
    auc = roc_auc_score(y_test, y_pred_proba, multi_class='ovr', average='macro')
    
    # Prepare results
    results = {
        'accuracy': acc,
        'balanced_accuracy': balanced_acc,
        'random_balanced_accuracy': random_balanced_acc,
        'classification_report': report
    }
    
    if auc is not None:
        results['roc_auc'] = auc
    
    return results, balanced_acc

# %%
def predict_and_evaluate(model, X_val, y_val, original_classes=None, multi_class=False):
    if multi_class:
        y_pred_proba = model.predict(X_val)
        y_pred = np.argmax(y_pred_proba, axis=1)
        #print(y_pred)
    else:
        y_pred_proba = model.predict_proba(X_val)
        y_pred = model.predict(X_val)
        #print(y_pred)
    
    # Get unique classes present in validation data
    present_classes = np.unique(y_val)
    
    # Get the indices of these classes in the original prediction probabilities
    class_indices = [np.where(original_classes == cls)[0][0] for cls in present_classes]
    
    # Select only the probability columns for present classes
    y_pred_proba_filtered = y_pred_proba[:, class_indices]
    
    # Binarize the true labels using only the present classes
    y_val_bin = label_binarize(y_val, classes=present_classes)

    results, balanced_acc = evaluate_model_performance_train(y_val, y_pred, y_pred_proba_filtered, y_val_bin)
    print_model_performance(results)
    return results, balanced_acc

# %%
percentage_of_the_data = [0.01]
data = []
percentage_dict = {}
best_mse_mlp = float('inf')
best_mse_lgb = float('inf')
best_mse_tab = float('inf')
deconfounding_strategies = ["BE", "Correlation_in_Feature","Correlation_with_target", "PCA" "Nothing"]
for percentage in percentage_of_the_data:
        percentage_dict[percentage] = {}
        for deconfounding_strategy in deconfounding_strategies:
                print(f"\n=== Deconfounding Strategy: {deconfounding_strategy} ===")
                if percentage == 1:
                        print(f"\n #### TRAINING WITH {percentage} OF THE DATA ####")
                        df_sampled_subset = df_sampled
                else:
                        print(f"\n #### TRAINING WITH {percentage} OF THE DATA ####")
                        df_sampled_subset, _ = train_test_split(
                        df_sampled,
                        train_size=percentage,  # Use train_size to get desired percentage
                        stratify=df_sampled["label_age_group"],
                        random_state=42
                        )

                y = df_sampled_subset["label_age_group"]
                X = df_sampled_subset.drop(["ID", "label_age_group"], axis=1)

                print(f"Training data shape: {X.shape}, length of y: {len(y)}")
                print(f"Training data class distribution: {y.value_counts()}")
                

                skf = StratifiedKFold(n_splits=n_splits, shuffle=True, random_state=42)
                cv_results = {
                        'accuracy': [],
                        'balanced_accuracy': [],
                        'roc_auc': [],
                        'classification_reports': []
                }

                tab_pfn = TabPFNClassifier()

                tabpfn_results = []
                tabpfn_results_eval = []
                lgb_results = []
                lgb_results_eval = []
                random_results = []
                mlp_results = []
                mlp_results_eval = []
                cnn_results = []
                cnn_results_eval = []
                model_dict = {}
                model_results = {}


                best_balanced_accuracy_mlp = 0
                best_balanced_accuracy_tabpfn = 0
                best_balanced_accuracy_lgb = 0
                for fold, (train_index, val_index) in enumerate(skf.split(X, y), 1):
                        unique_classes = np.unique(y)
                        missing_classes = [cls for cls in unique_classes if cls not in y.iloc[val_index]]
                        for cls in missing_classes:
                                cls_indices = np.where(y == cls)[0]  # Get all indices of the missing class
                                # Check if removing a sample would leave train set empty for the class
                                train_cls_indices = np.intersect1d(cls_indices, train_index)

                                if len(train_cls_indices) <= 1:
                                        # If moving the last one, instead take a duplicate from the whole y array
                                        cls_idx_to_move = np.random.choice(cls_indices, 1)[0]
                                else:
                                        cls_idx_to_move = np.random.choice(train_cls_indices, 1)[0]
                                # Add to validation set
                                val_index = np.append(val_index, cls_idx_to_move)
                                # Remove only if it's not the last one in train
                                if len(train_cls_indices) > 1:
                                        train_index = np.setdiff1d(train_index, cls_idx_to_move)
                        print(f"\nFold {fold}")
                        X_train, X_test = X.iloc[train_index], X.iloc[val_index]
                        y_train, y_test = y.iloc[train_index], y.iloc[val_index]

                        #scaler = MinMaxScaler()
                        df_columns = X.columns
                        scaler = StandardScaler()
                        X_train_scaled = scaler.fit_transform(X_train)
                        X_test_scaled = scaler.transform(X_test)
                        X_control_scaled = scaler.fit_transform(X_control)
                        if deconfounding_strategy == "BE":
                                X_train, X_test, X_control = feature_extration_with_BE(X_train_scaled, X_test_scaled, X_control_scaled, y_train, df_columns=df_columns)
                        elif deconfounding_strategy == "PCA":
                                X_train, X_test, X_control= feature_extration_with_PCA(X_train_scaled, X_test_scaled, X_control_scaled,  n_components=50)
                        elif deconfounding_strategy == "Correlation_in_Feature":
                                X_train, X_test, X_control = feature_extraction_with_Pearson(X_train_scaled, X_test_scaled, X_control_scaled, y_train, threshold=0.6, df_columns=df_columns)
                        elif deconfounding_strategy == "Correlation_with_target":
                                X_train, X_test, X_control = feature_extraction_best_corr_with_target(X_train_scaled, X_test_scaled, X_control_scaled, y_train, threshold=0.6, df_columns=df_columns)
                        n_classes = len(np.unique(y_test))
                        random_y_test = np.random.randint(0, n_classes, size=y_test.shape)
                        random_y_pred_proba = np.random.rand(len(y_test), n_classes)
                        random_y_pred_proba /= random_y_pred_proba.sum(axis=1)[:, np.newaxis]
                        results, balanced_accuracy  = evaluate_model_performance_train(y_test, random_y_test, random_y_pred_proba)
                        print("RANDOM PERFORMANCE")
                        print_model_performance(results)
                        random_results.append(results)

                        cnnclf = create_cnn_model(input_shape=(X_train.shape[1], 1), num_classes=len(y.unique()))
                        X_train_cnn = X_train.reshape(X_train.shape[0], X_train.shape[1], 1)
                        X_test_cnn = X_test.reshape(X_test.shape[0], X_test.shape[1], 1)
                        X_control_cnn = X_control.reshape(X_control.shape[0], X_control.shape[1], 1)
                        cnnclf.fit(X_train_cnn, pd.get_dummies(y_train), epochs=10, batch_size=32, verbose=0)
                        y_pred_proba = cnnclf.predict(X_test_cnn)
                        y_pred = np.argmax(y_pred_proba, axis=1)
                        results, balanced_accuracy = evaluate_model_performance_train(y_test, y_pred, y_pred_proba)
                        print("CNN PERFORMANCE")
                        print_model_performance(results)
                        cnn_results.append(results)
                        print("CNN PERFORMANCE FOR CONTROL")
                        results, balanced_accuracy = predict_and_evaluate(cnnclf, X_control_cnn, y_control, original_classes = np.unique(y_train), multi_class=True)
                        cnn_results_eval.append(results)
                        clean_up_cuda(cnnclf)

                        mlpclf = create_mlp_model(input_shape=X_train.shape[1], num_classes=len(y.unique()))
                        mlpclf.fit(X_train, pd.get_dummies(y_train), epochs=10, batch_size=32, verbose=0)
                        y_pred_proba = mlpclf.predict(X_test)
                        y_pred = np.argmax(y_pred_proba, axis=1)
                        results, balanced_accuracy = evaluate_model_performance_train(y_test, y_pred, y_pred_proba)
                        print("MLP PERFORMANCE")
                        print_model_performance(results)
                        mlp_results.append(results)
                        #model_dict["mlp"] = mlpclf
                        print("MLP PERFORMANCE FOR CONTROL")
                        results, balanced_accuracy = predict_and_evaluate(mlpclf, X_control, y_control, original_classes = np.unique(y_train), multi_class=True)
                        mlp_results_eval.append(results)
                        if balanced_accuracy > best_balanced_accuracy_mlp:
                                best_balanced_accuracy_mlp = balanced_accuracy
                                model_dict["mlp"] = mlpclf
                        clean_up_cuda(mlpclf)

                        tabclf = TabPFNClassifier()
                        tabclf.fit(X_train, y_train)
                        y_pred_proba = tabclf.predict_proba(X_test)
                        y_pred = tabclf.predict(X_test)
                        results, balanced_accuracy = evaluate_model_performance_train(y_test, y_pred, y_pred_proba)
                        print("tabpfn PERFORMANCE")
                        print_model_performance(results)
                        tabpfn_results.append(results)
                        #model_dict["tabpfn"] = tabclf
                        original_classes = tabclf.classes_
                        print("tabpfn PERFORMANCE FOR CONTROL")
                        results, balanced_accuracy = predict_and_evaluate(tabclf, X_control, y_control, original_classes=original_classes)
                        tabpfn_results_eval.append(results)
                        if balanced_accuracy > best_balanced_accuracy_tabpfn:
                                best_balanced_accuracy_tabpfn = balanced_accuracy
                                model_dict["tabpfn"] = tabclf
                        clean_up_cuda(tabclf)
                        
                        lgb_train = lgb.Dataset(X_train, label=y_train)
                        lgb_eval = lgb.Dataset(X_test, label=y_test, reference=lgb_train)
                        params = {
                        'objective': 'multiclass',
                        'num_class': len(y.unique()),
                        'metric': 'multi_logloss',
                        'num_leaves': 31,
                        'learning_rate': 0.05,
                        'feature_fraction': 0.9,
                        'seed': 42,
                        'verbose': -1
                        }
                        lgbclf = lgb.train(params, lgb_train, valid_sets=[lgb_train, lgb_eval], num_boost_round=1000)
                        y_pred_proba = lgbclf.predict(X_test)
                        y_pred = np.argmax(y_pred_proba, axis=1)
                        results, balanced_accuracy = evaluate_model_performance_train(y_test, y_pred, y_pred_proba)
                        print("LGBM PERFORMANCE")
                        print_model_performance(results)
                        lgb_results.append(results)
                        print("LGBM PERFORMANCE FOR CONTROL")
                        results, balanced_accuracy = predict_and_evaluate(lgbclf, X_control, y_control, original_classes=original_classes, multi_class=True)
                        lgb_results_eval.append(results)
                        if balanced_accuracy > best_balanced_accuracy_lgb:
                                best_balanced_accuracy_lgb = balanced_accuracy
                                model_dict["lgb"] = lgbclf
                        clean_up_cuda(lgbclf)

                random_summary = aggregate_cv_metrics_and_print(random_results, "Random")
                tabpfn_summary = aggregate_cv_metrics_and_print(tabpfn_results, "TabPFN")
                lgb_summary = aggregate_cv_metrics_and_print(lgb_results, "LGBM")
                mlp_summary = aggregate_cv_metrics_and_print(mlp_results, "MLP")
                cnn_summary = aggregate_cv_metrics_and_print(cnn_results, "CNN")

                tabpfn_eval_summary = aggregate_cv_metrics_and_print(tabpfn_results_eval, "TabPFN", "Control")
                lgb_eval_summary = aggregate_cv_metrics_and_print(lgb_results_eval, "LGBM", "Control")
                mlp_eval_summary = aggregate_cv_metrics_and_print(mlp_results_eval, "MLP", "Control")
                cnn_eval_summary = aggregate_cv_metrics_and_print(cnn_results_eval, "CNN", "Control")

                percentage_dict[percentage][deconfounding_strategy] = {
                "TabPFN": {
                        "results": tabpfn_summary,
                        "results_eval": tabpfn_eval_summary,
                        "cv_results": tabpfn_results,
                        "cv_results_eval": tabpfn_results_eval
                },
                "LGBM": {
                        "results": lgb_summary,
                        "results_eval": lgb_eval_summary,
                        "cv_results": lgb_results,
                        "cv_results_eval": lgb_results_eval
                },
                "Random": {
                        "results": random_summary,
                        "results_eval": random_summary,
                        "cv_results": random_results,
                        "cv_results_eval": random_results,

                },
                "MLP": {
                        "results": mlp_summary,
                        "results_eval": mlp_eval_summary,
                        "cv_results": mlp_results,
                        "cv_results_eval": mlp_results_eval
                },
                "CNN": {
                        "results": cnn_summary,
                        "results_eval": cnn_eval_summary,
                        "cv_results": cnn_results,
                        "cv_results_eval": cnn_results_eval
                }
        }
# Out:
# === Deconfounding Strategy: BE ===
#
#  #### TRAINING WITH 0.01 OF THE DATA ####
# Training data shape: (100, 192), length of y: 100
# Training data class distribution: label_age_group
# 2.0    29
# 3.0    27
# 4.0    21
# 1.0    11
# 0.0    10
# 5.0     2
# Name: count, dtype: int64
#
# Fold 1
# RANDOM PERFORMANCE
# Accuracy: 0.07692307692307693
# Balanced Accuracy: 0.07936507936507936
# Random Balanced Accuracy: 0.25595238095238093
#
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       0.14      0.33      0.20         3
#          1.0       0.00      0.00      0.00         3
#          2.0       0.20      0.14      0.17         7
#          3.0       0.00      0.00      0.00         7
#          4.0       0.00      0.00      0.00         5
#          5.0       0.00      0.00      0.00         1
#
#     accuracy                           0.08        26
#    macro avg       0.06      0.08      0.06        26
# weighted avg       0.07      0.08      0.07        26
#
# Roc Auc: 0.47536958337873664
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step
# CNN PERFORMANCE
# Accuracy: 0.5769230769230769
# Balanced Accuracy: 0.5222222222222221
# Random Balanced Accuracy: 0.10000000000000002
#
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       0.50      0.33      0.40         3
#          1.0       0.60      1.00      0.75         3
#          2.0       0.44      0.57      0.50         7
#          3.0       0.60      0.43      0.50         7
#          4.0       0.80      0.80      0.80         5
#          5.0       0.00      0.00      0.00         1
#
#     accuracy                           0.58        26
#    macro avg       0.49      0.52      0.49        26
# weighted avg       0.56      0.58      0.56        26
#
# Roc Auc: 0.6949053793905052
# CNN PERFORMANCE FOR CONTROL
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Accuracy: 0.1336206896551724
# Balanced Accuracy: 0.14277798748921483
# Random Balanced Accuracy: 0.19850284965325943
#
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       0.96      0.08      0.15       320
#          1.0       0.11      0.08      0.10        61
#          2.0       0.18      0.41      0.25        76
#          3.0       0.00      0.00      0.00         7
#          4.0       0.00      0.00      0.00         0
#
#     accuracy                           0.13       464
#    macro avg       0.25      0.11      0.10       464
# weighted avg       0.71      0.13      0.16       464
#
# Roc Auc: 0.5448611859707484
# CUDA memory cleared and model deleted.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# MLP PERFORMANCE
# Accuracy: 0.34615384615384615
# Balanced Accuracy: 0.2650793650793651
# Random Balanced Accuracy: 0.25277777777777777
#
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       0.50      0.33      0.40         3
#          1.0       0.00      0.00      0.00         3
#          2.0       0.33      0.43      0.38         7
#          3.0       0.30      0.43      0.35         7
#          4.0       0.67      0.40      0.50         5
#          5.0       0.00      0.00      0.00         1
#
#     accuracy                           0.35        26
#    macro avg       0.30      0.27      0.27        26
# weighted avg       0.36      0.35      0.34        26
#
# Roc Auc: 0.6712164469143874
# MLP PERFORMANCE FOR CONTROL
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Accuracy: 0.12284482758620689
# Balanced Accuracy: 0.2145441729323308
# Random Balanced Accuracy: 0.18969445985575017
#
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       0.97      0.09      0.16       320
#          1.0       0.00      0.00      0.00        61
#          2.0       0.18      0.34      0.24        76
#          3.0       0.02      0.43      0.03         7
#          4.0       0.00      0.00      0.00         0
#
#     accuracy                           0.12       464
#    macro avg       0.23      0.17      0.09       464
# weighted avg       0.70      0.12      0.15       464
#
# Roc Auc: 0.538310843275885
# CUDA memory cleared and model deleted.
# tabpfn PERFORMANCE
# Accuracy: 0.46153846153846156
# Balanced Accuracy: 0.3555555555555556
# Random Balanced Accuracy: 0.19999999999999998
#
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       0.00      0.00      0.00         3
#          1.0       0.33      0.33      0.33         3
#          2.0       0.36      0.71      0.48         7
#          3.0       0.50      0.29      0.36         7
#          4.0       0.80      0.80      0.80         5
#          5.0       0.00      0.00      0.00         1
#
#     accuracy                           0.46        26
#    macro avg       0.33      0.36      0.33        26
# weighted avg       0.42      0.46      0.42        26
#
# Roc Auc: 0.8260767861683194
# tabpfn PERFORMANCE FOR CONTROL
# Accuracy: 0.1314655172413793
# Balanced Accuracy: 0.2434787339763343
# Random Balanced Accuracy: 0.18351039251268608
#
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       0.82      0.07      0.13       320
#          1.0       0.14      0.07      0.09        61
#          2.0       0.20      0.41      0.27        76
#          3.0       0.02      0.43      0.04         7
#          4.0       0.00      0.00      0.00         0
#
#     accuracy                           0.13       464
#    macro avg       0.24      0.19      0.11       464
# weighted avg       0.62      0.13      0.15       464
#
# Roc Auc: 0.5682983407976983
# CUDA memory cleared and model deleted.
# LGBM PERFORMANCE
# Accuracy: 0.5384615384615384
# Balanced Accuracy: 0.4984126984126984
# Random Balanced Accuracy: 0.1111111111111111
#
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       1.00      0.33      0.50         3
#          1.0       0.50      1.00      0.67         3
#          2.0       0.33      0.43      0.38         7
#          3.0       0.50      0.43      0.46         7
#          4.0       1.00      0.80      0.89         5
#          5.0       0.00      0.00      0.00         1
#
#     accuracy                           0.54        26
#    macro avg       0.56      0.50      0.48        26
# weighted avg       0.59      0.54      0.53        26
#
# Roc Auc: 0.762541135447314
# LGBM PERFORMANCE FOR CONTROL
# Accuracy: 0.10560344827586207
# Balanced Accuracy: 0.2507518796992481
# Random Balanced Accuracy: 0.199370709382151
#
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       1.00      0.05      0.10       320
#          1.0       0.00      0.00      0.00        61
#          2.0       0.21      0.38      0.27        76
#          3.0       0.02      0.57      0.04         7
#          4.0       0.00      0.00      0.00         0
#
#     accuracy                           0.11       464
#    macro avg       0.25      0.20      0.08       464
# weighted avg       0.73      0.11      0.11       464
#
# Roc Auc: 0.5941938005817485
# CUDA memory cleared and model deleted.
#
# Fold 2
# RANDOM PERFORMANCE
# Accuracy: 0.23076923076923078
# Balanced Accuracy: 0.3365079365079365
# Random Balanced Accuracy: 0.1111111111111111
#
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       0.20      0.33      0.25         3
#          1.0       0.00      0.00      0.00         3
#          2.0       0.17      0.14      0.15         7
#          3.0       0.17      0.14      0.15         7
#          4.0       0.67      0.40      0.50         5
#          5.0       0.25      1.00      0.40         1
#
#     accuracy                           0.23        26
#    macro avg       0.24      0.34      0.24        26
# weighted avg       0.25      0.23      0.22        26
#
# Roc Auc: 0.5328698557989177
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step
# CNN PERFORMANCE
# Accuracy: 0.3076923076923077
# Balanced Accuracy: 0.24126984126984122
# Random Balanced Accuracy: 0.09722222222222221
#
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       0.20      0.33      0.25         3
#          1.0       0.00      0.00      0.00         3
#          2.0       0.25      0.43      0.32         7
#          3.0       0.40      0.29      0.33         7
#          4.0       0.67      0.40      0.50         5
#          5.0       0.00      0.00      0.00         1
#
#     accuracy                           0.31        26
#    macro avg       0.25      0.24      0.23        26
# weighted avg       0.33      0.31      0.30        26
#
# Roc Auc: 0.6691591297083287
# CNN PERFORMANCE FOR CONTROL
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Accuracy: 0.21551724137931033
# Balanced Accuracy: 0.2593438963700234
# Random Balanced Accuracy: 0.2207781472313864
#
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       0.95      0.13      0.23       320
#          1.0       0.08      0.02      0.03        61
#          2.0       0.21      0.75      0.33        76
#          3.0       0.01      0.14      0.02         7
#          4.0       0.00      0.00      0.00         0
#
#     accuracy                           0.22       464
#    macro avg       0.25      0.21      0.12       464
# weighted avg       0.70      0.22      0.21       464
#
# Roc Auc: 0.6100111543811395
# CUDA memory cleared and model deleted.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# MLP PERFORMANCE
# Accuracy: 0.34615384615384615
# Balanced Accuracy: 0.2968253968253968
# Random Balanced Accuracy: 0.1130952380952381
#
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       0.50      0.67      0.57         3
#          1.0       0.00      0.00      0.00         3
#          2.0       0.33      0.14      0.20         7
#          3.0       0.31      0.57      0.40         7
#          4.0       0.50      0.40      0.44         5
#          5.0       0.00      0.00      0.00         1
#
#     accuracy                           0.35        26
#    macro avg       0.27      0.30      0.27        26
# weighted avg       0.33      0.35      0.31        26
#
# Roc Auc: 0.5626980494715049
# MLP PERFORMANCE FOR CONTROL
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Accuracy: 0.1206896551724138
# Balanced Accuracy: 0.30852913533834586
# Random Balanced Accuracy: 0.22230580295452318
#
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       1.00      0.09      0.16       320
#          1.0       0.00      0.00      0.00        61
#          2.0       0.22      0.29      0.25        76
#          3.0       0.02      0.86      0.04         7
#          4.0       0.00      0.00      0.00         0
#
#     accuracy                           0.12       464
#    macro avg       0.25      0.25      0.09       464
# weighted avg       0.73      0.12      0.15       464
#
# Roc Auc: 0.5773653994997455
# CUDA memory cleared and model deleted.
# tabpfn PERFORMANCE
# Accuracy: 0.2692307692307692
# Balanced Accuracy: 0.22698412698412698
# Random Balanced Accuracy: 0.18055555555555555
#
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       0.25      0.33      0.29         3
#          1.0       0.00      0.00      0.00         3
#          2.0       0.00      0.00      0.00         7
#          3.0       0.38      0.43      0.40         7
#          4.0       0.60      0.60      0.60         5
#          5.0       0.00      0.00      0.00         1
#
#     accuracy                           0.27        26
#    macro avg       0.20      0.23      0.21        26
# weighted avg       0.25      0.27      0.26        26
#
# Roc Auc: 0.7937641204460427
# tabpfn PERFORMANCE FOR CONTROL
# Accuracy: 0.11637931034482758
# Balanced Accuracy: 0.24041767456551213
# Random Balanced Accuracy: 0.19142846138100666
#
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       0.90      0.08      0.15       320
#          1.0       0.09      0.02      0.03        61
#          2.0       0.13      0.29      0.18        76
#          3.0       0.03      0.57      0.05         7
#          4.0       0.00      0.00      0.00         0
#
#     accuracy                           0.12       464
#    macro avg       0.23      0.19      0.08       464
# weighted avg       0.65      0.12      0.14       464
#
# Roc Auc: 0.5540623110547693
# CUDA memory cleared and model deleted.
# LGBM PERFORMANCE
# Accuracy: 0.34615384615384615
# Balanced Accuracy: 0.30634920634920637
# Random Balanced Accuracy: 0.07936507936507936
#
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       0.33      0.67      0.44         3
#          1.0       0.00      0.00      0.00         3
#          2.0       0.33      0.29      0.31         7
#          3.0       0.40      0.29      0.33         7
#          4.0       0.43      0.60      0.50         5
#          5.0       0.00      0.00      0.00         1
#
#     accuracy                           0.35        26
#    macro avg       0.25      0.31      0.26        26
# weighted avg       0.32      0.35      0.32        26
#
# Roc Auc: 0.6032399840180162
# LGBM PERFORMANCE FOR CONTROL
# Accuracy: 0.1314655172413793
# Balanced Accuracy: 0.11117072907679033
# Random Balanced Accuracy: 0.18287511145712726
#
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       0.90      0.11      0.20       320
#          1.0       0.03      0.02      0.02        61
#          2.0       0.16      0.32      0.21        76
#          3.0       0.00      0.00      0.00         7
#          4.0       0.00      0.00      0.00         0
#
#     accuracy                           0.13       464
#    macro avg       0.22      0.09      0.09       464
# weighted avg       0.65      0.13      0.18       464
#
# Roc Auc: 0.5015194520795685
# CUDA memory cleared and model deleted.
#
# Fold 3
# RANDOM PERFORMANCE
# Accuracy: 0.4230769230769231
# Balanced Accuracy: 0.38888888888888884
# Random Balanced Accuracy: 0.10317460317460318
#
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       0.50      0.67      0.57         3
#          1.0       0.50      0.50      0.50         4
#          2.0       0.50      0.33      0.40         6
#          3.0       0.60      0.50      0.55         6
#          4.0       0.33      0.33      0.33         6
#          5.0       0.00      0.00      0.00         1
#
#     accuracy                           0.42        26
#    macro avg       0.41      0.39      0.39        26
# weighted avg       0.47      0.42      0.44        26
#
# Roc Auc: 0.4917841458058849
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step
# CNN PERFORMANCE
# Accuracy: 0.5
# Balanced Accuracy: 0.38888888888888884
# Random Balanced Accuracy: 0.06666666666666667
#
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       1.00      0.33      0.50         3
#          1.0       0.00      0.00      0.00         4
#          2.0       0.43      0.50      0.46         6
#          3.0       0.45      0.83      0.59         6
#          4.0       0.57      0.67      0.62         6
#          5.0       0.00      0.00      0.00         1
#
#     accuracy                           0.50        26
#    macro avg       0.41      0.39      0.36        26
# weighted avg       0.45      0.50      0.44        26
#
# Roc Auc: 0.7708981115502854
# CNN PERFORMANCE FOR CONTROL
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Accuracy: 0.1271551724137931
# Balanced Accuracy: 0.19954008997904596
# Random Balanced Accuracy: 0.20994296269232332
#
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       1.00      0.07      0.14       320
#          1.0       1.00      0.02      0.03        61
#          2.0       0.20      0.42      0.27        76
#          3.0       0.01      0.29      0.02         7
#          4.0       0.00      0.00      0.00         0
#
#     accuracy                           0.13       464
#    macro avg       0.44      0.16      0.09       464
# weighted avg       0.85      0.13      0.15       464
#
# Roc Auc: 0.5583958381066368
# CUDA memory cleared and model deleted.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# MLP PERFORMANCE
# Accuracy: 0.5769230769230769
# Balanced Accuracy: 0.4444444444444444
# Random Balanced Accuracy: 0.22420634920634921
#
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       1.00      0.33      0.50         3
#          1.0       0.00      0.00      0.00         4
#          2.0       0.40      0.67      0.50         6
#          3.0       0.67      0.67      0.67         6
#          4.0       0.75      1.00      0.86         6
#          5.0       0.00      0.00      0.00         1
#
#     accuracy                           0.58        26
#    macro avg       0.47      0.44      0.42        26
# weighted avg       0.53      0.58      0.52        26
#
# Roc Auc: 0.6681873078612209
# MLP PERFORMANCE FOR CONTROL
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Accuracy: 0.17456896551724138
# Balanced Accuracy: 0.18108620038826573
# Random Balanced Accuracy: 0.21131695122371003
#
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       1.00      0.11      0.20       320
#          1.0       0.09      0.05      0.06        61
#          2.0       0.25      0.57      0.34        76
#          3.0       0.00      0.00      0.00         7
#          4.0       0.00      0.00      0.00         0
#
#     accuracy                           0.17       464
#    macro avg       0.27      0.14      0.12       464
# weighted avg       0.74      0.17      0.20       464
#
# Roc Auc: 0.5703756814827912
# CUDA memory cleared and model deleted.
# tabpfn PERFORMANCE
# Accuracy: 0.46153846153846156
# Balanced Accuracy: 0.375
# Random Balanced Accuracy: 0.2759259259259259
#
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       1.00      0.33      0.50         3
#          1.0       0.50      0.25      0.33         4
#          2.0       0.30      0.50      0.38         6
#          3.0       0.33      0.33      0.33         6
#          4.0       0.71      0.83      0.77         6
#          5.0       0.00      0.00      0.00         1
#
#     accuracy                           0.46        26
#    macro avg       0.47      0.38      0.39        26
# weighted avg       0.50      0.46      0.45        26
#
# Roc Auc: 0.7785924462011419
# tabpfn PERFORMANCE FOR CONTROL
# Accuracy: 0.11853448275862069
# Balanced Accuracy: 0.2602927015284112
# Random Balanced Accuracy: 0.18738525013697982
#
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       0.96      0.07      0.13       320
#          1.0       0.24      0.10      0.14        61
#          2.0       0.12      0.30      0.18        76
#          3.0       0.02      0.57      0.05         7
#          4.0       0.00      0.00      0.00         0
#
#     accuracy                           0.12       464
#    macro avg       0.27      0.21      0.10       464
# weighted avg       0.71      0.12      0.14       464
#
# Roc Auc: 0.5216730996241837
# CUDA memory cleared and model deleted.
# LGBM PERFORMANCE
# Accuracy: 0.34615384615384615
# Balanced Accuracy: 0.27777777777777773
# Random Balanced Accuracy: 0.21666666666666667
#
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       1.00      0.33      0.50         3
#          1.0       0.00      0.00      0.00         4
#          2.0       0.29      0.33      0.31         6
#          3.0       0.23      0.50      0.32         6
#          4.0       0.75      0.50      0.60         6
#          5.0       0.00      0.00      0.00         1
#
#     accuracy                           0.35        26
#    macro avg       0.38      0.28      0.29        26
# weighted avg       0.41      0.35      0.34        26
#
# Roc Auc: 0.6188735177865613
# LGBM PERFORMANCE FOR CONTROL
# Accuracy: 0.08405172413793104
# Balanced Accuracy: 0.15713351642425735
# Random Balanced Accuracy: 0.18609400140788415
#
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       1.00      0.05      0.09       320
#          1.0       0.08      0.03      0.05        61
#          2.0       0.11      0.26      0.16        76
#          3.0       0.01      0.29      0.02         7
#          4.0       0.00      0.00      0.00         0
#          5.0       0.00      0.00      0.00         0
#
#     accuracy                           0.08       464
#    macro avg       0.20      0.10      0.05       464
# weighted avg       0.72      0.08      0.09       464
#
# Roc Auc: 0.45031267920280316
# CUDA memory cleared and model deleted.
#
# Fold 4
# RANDOM PERFORMANCE
# Accuracy: 0.23076923076923078
# Balanced Accuracy: 0.1880952380952381
# Random Balanced Accuracy: 0.2796296296296296
#
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       0.00      0.00      0.00         3
#          1.0       0.14      0.33      0.20         3
#          2.0       0.38      0.43      0.40         7
#          3.0       0.25      0.17      0.20         6
#          4.0       0.25      0.20      0.22         5
#          5.0       0.00      0.00      0.00         2
#
#     accuracy                           0.23        26
#    macro avg       0.17      0.19      0.17        26
# weighted avg       0.22      0.23      0.22        26
#
# Roc Auc: 0.6305012985361956
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step
# CNN PERFORMANCE
# Accuracy: 0.34615384615384615
# Balanced Accuracy: 0.273015873015873
# Random Balanced Accuracy: 0.1111111111111111
#
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       1.00      0.33      0.50         3
#          1.0       0.00      0.00      0.00         3
#          2.0       0.31      0.57      0.40         7
#          3.0       0.33      0.33      0.33         6
#          4.0       0.40      0.40      0.40         5
#          5.0       0.00      0.00      0.00         2
#
#     accuracy                           0.35        26
#    macro avg       0.34      0.27      0.27        26
# weighted avg       0.35      0.35      0.32        26
#
# Roc Auc: 0.6257128328066542
# CNN PERFORMANCE FOR CONTROL
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Accuracy: 0.1853448275862069
# Balanced Accuracy: 0.29739779135338346
# Random Balanced Accuracy: 0.225437675070028
#
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       0.94      0.10      0.19       320
#          1.0       0.00      0.00      0.00        61
#          2.0       0.22      0.66      0.32        76
#          3.0       0.02      0.43      0.04         7
#          4.0       0.00      0.00      0.00         0
#
#     accuracy                           0.19       464
#    macro avg       0.24      0.24      0.11       464
# weighted avg       0.69      0.19      0.18       464
#
# Roc Auc: 0.554073576131138
# CUDA memory cleared and model deleted.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# MLP PERFORMANCE
# Accuracy: 0.3076923076923077
# Balanced Accuracy: 0.23253968253968252
# Random Balanced Accuracy: 0.125
#
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       0.00      0.00      0.00         3
#          1.0       0.00      0.00      0.00         3
#          2.0       0.27      0.43      0.33         7
#          3.0       0.25      0.17      0.20         6
#          4.0       0.44      0.80      0.57         5
#          5.0       0.00      0.00      0.00         2
#
#     accuracy                           0.31        26
#    macro avg       0.16      0.23      0.18        26
# weighted avg       0.22      0.31      0.25        26
#
# Roc Auc: 0.576383894518906
# MLP PERFORMANCE FOR CONTROL
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Accuracy: 0.15086206896551724
# Balanced Accuracy: 0.23904141116109948
# Random Balanced Accuracy: 0.19806623663820233
#
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       1.00      0.07      0.13       320
#          1.0       0.17      0.03      0.05        61
#          2.0       0.23      0.57      0.32        76
#          3.0       0.01      0.29      0.02         7
#          4.0       0.00      0.00      0.00         0
#
#     accuracy                           0.15       464
#    macro avg       0.28      0.19      0.11       464
# weighted avg       0.75      0.15      0.15       464
#
# Roc Auc: 0.5411531813363951
# CUDA memory cleared and model deleted.
# tabpfn PERFORMANCE
# Accuracy: 0.38461538461538464
# Balanced Accuracy: 0.33809523809523806
# Random Balanced Accuracy: 0.061111111111111116
#
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       0.00      0.00      0.00         3
#          1.0       0.67      0.67      0.67         3
#          2.0       0.43      0.43      0.43         7
#          3.0       0.33      0.33      0.33         6
#          4.0       0.33      0.60      0.43         5
#          5.0       0.00      0.00      0.00         2
#
#     accuracy                           0.38        26
#    macro avg       0.29      0.34      0.31        26
# weighted avg       0.33      0.38      0.35        26
#
# Roc Auc: 0.7960213032581454
# tabpfn PERFORMANCE FOR CONTROL
# Accuracy: 0.13793103448275862
# Balanced Accuracy: 0.1824085379945766
# Random Balanced Accuracy: 0.19787137105318925
#
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       0.81      0.12      0.21       320
#          1.0       0.18      0.10      0.13        61
#          2.0       0.13      0.22      0.17        76
#          3.0       0.01      0.29      0.02         7
#          4.0       0.00      0.00      0.00         0
#
#     accuracy                           0.14       464
#    macro avg       0.23      0.15      0.11       464
# weighted avg       0.61      0.14      0.19       464
#
# Roc Auc: 0.5197962517948751
# CUDA memory cleared and model deleted.
# LGBM PERFORMANCE
# Accuracy: 0.2692307692307692
# Balanced Accuracy: 0.2587301587301587
# Random Balanced Accuracy: 0.14444444444444446
#
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       0.00      0.00      0.00         3
#          1.0       0.67      0.67      0.67         3
#          2.0       0.25      0.29      0.27         7
#          3.0       0.00      0.00      0.00         6
#          4.0       0.38      0.60      0.46         5
#          5.0       0.00      0.00      0.00         2
#
#     accuracy                           0.27        26
#    macro avg       0.22      0.26      0.23        26
# weighted avg       0.22      0.27      0.24        26
#
# Roc Auc: 0.5904993461915659
# LGBM PERFORMANCE FOR CONTROL
# Accuracy: 0.1206896551724138
# Balanced Accuracy: 0.14883173610255146
# Random Balanced Accuracy: 0.18965605713889466
#
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       1.00      0.09      0.16       320
#          1.0       0.09      0.05      0.06        61
#          2.0       0.17      0.32      0.22        76
#          3.0       0.01      0.14      0.01         7
#          4.0       0.00      0.00      0.00         0
#          5.0       0.00      0.00      0.00         0
#
#     accuracy                           0.12       464
#    macro avg       0.21      0.10      0.08       464
# weighted avg       0.73      0.12      0.16       464
#
# Roc Auc: 0.500771208567279
# CUDA memory cleared and model deleted.
#
# Fold 5
# RANDOM PERFORMANCE
# Accuracy: 0.15384615384615385
# Balanced Accuracy: 0.1626984126984127
# Random Balanced Accuracy: 0.10277777777777779
#
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       0.00      0.00      0.00         3
#          1.0       0.40      0.67      0.50         3
#          2.0       0.17      0.14      0.15         7
#          3.0       0.20      0.17      0.18         6
#          4.0       0.00      0.00      0.00         5
#          5.0       0.00      0.00      0.00         2
#
#     accuracy                           0.15        26
#    macro avg       0.13      0.16      0.14        26
# weighted avg       0.14      0.15      0.14        26
#
# Roc Auc: 0.49613390359957865
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step
# CNN PERFORMANCE
# Accuracy: 0.4230769230769231
# Balanced Accuracy: 0.3357142857142857
# Random Balanced Accuracy: 0.3333333333333333
#
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       1.00      0.33      0.50         3
#          1.0       0.00      0.00      0.00         3
#          2.0       0.38      0.71      0.50         7
#          3.0       0.25      0.17      0.20         6
#          4.0       0.57      0.80      0.67         5
#          5.0       0.00      0.00      0.00         2
#
#     accuracy                           0.42        26
#    macro avg       0.37      0.34      0.31        26
# weighted avg       0.39      0.42      0.37        26
#
# Roc Auc: 0.697553212742
# CNN PERFORMANCE FOR CONTROL
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Accuracy: 0.10991379310344827
# Balanced Accuracy: 0.15433158973252803
# Random Balanced Accuracy: 0.19645788212814408
#
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       1.00      0.02      0.04       320
#          1.0       0.12      0.03      0.05        61
#          2.0       0.14      0.57      0.23        76
#          3.0       0.00      0.00      0.00         7
#          4.0       0.00      0.00      0.00         0
#
#     accuracy                           0.11       464
#    macro avg       0.25      0.12      0.06       464
# weighted avg       0.73      0.11      0.07       464
#
# Roc Auc: 0.5880803429427914
# CUDA memory cleared and model deleted.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# MLP PERFORMANCE
# Accuracy: 0.34615384615384615
# Balanced Accuracy: 0.29603174603174603
# Random Balanced Accuracy: 0.09523809523809523
#
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       1.00      0.33      0.50         3
#          1.0       0.00      0.00      0.00         3
#          2.0       0.33      0.14      0.20         7
#          3.0       0.25      0.50      0.33         6
#          4.0       0.57      0.80      0.67         5
#          5.0       0.00      0.00      0.00         2
#
#     accuracy                           0.35        26
#    macro avg       0.36      0.30      0.28        26
# weighted avg       0.37      0.35      0.32        26
#
# Roc Auc: 0.6978399349823835
# MLP PERFORMANCE FOR CONTROL
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Accuracy: 0.05818965517241379
# Balanced Accuracy: 0.22820271092690741
# Random Balanced Accuracy: 0.16762490859615686
#
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       1.00      0.03      0.07       320
#          1.0       0.12      0.10      0.11        61
#          2.0       0.08      0.07      0.07        76
#          3.0       0.02      0.71      0.04         7
#          4.0       0.00      0.00      0.00         0
#
#     accuracy                           0.06       464
#    macro avg       0.24      0.18      0.06       464
# weighted avg       0.72      0.06      0.07       464
#
# Roc Auc: 0.5374237574516637
# CUDA memory cleared and model deleted.
# tabpfn PERFORMANCE
# Accuracy: 0.4230769230769231
# Balanced Accuracy: 0.376984126984127
# Random Balanced Accuracy: 0.041666666666666664
#
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       1.00      0.33      0.50         3
#          1.0       0.50      0.33      0.40         3
#          2.0       0.43      0.43      0.43         7
#          3.0       0.20      0.17      0.18         6
#          4.0       0.45      1.00      0.62         5
#          5.0       0.00      0.00      0.00         2
#
#     accuracy                           0.42        26
#    macro avg       0.43      0.38      0.36        26
# weighted avg       0.42      0.42      0.38        26
#
# Roc Auc: 0.8128770749337111
# tabpfn PERFORMANCE FOR CONTROL
# Accuracy: 0.07112068965517242
# Balanced Accuracy: 0.2478579902625416
# Random Balanced Accuracy: 0.18493044703863712
#
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       0.80      0.04      0.07       320
#          1.0       0.26      0.15      0.19        61
#          2.0       0.05      0.09      0.07        76
#          3.0       0.03      0.71      0.05         7
#          4.0       0.00      0.00      0.00         0
#
#     accuracy                           0.07       464
#    macro avg       0.23      0.20      0.08       464
# weighted avg       0.60      0.07      0.09       464
#
# Roc Auc: 0.5518267760391347
# CUDA memory cleared and model deleted.
# LGBM PERFORMANCE
# Accuracy: 0.5
# Balanced Accuracy: 0.48253968253968255
# Random Balanced Accuracy: 0.17500000000000002
#
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       1.00      0.67      0.80         3
#          1.0       0.00      0.00      0.00         3
#          2.0       0.38      0.43      0.40         7
#          3.0       0.38      0.50      0.43         6
#          4.0       0.67      0.80      0.73         5
#          5.0       1.00      0.50      0.67         2
#
#     accuracy                           0.50        26
#    macro avg       0.57      0.48      0.50        26
# weighted avg       0.51      0.50      0.49        26
#
# Roc Auc: 0.7183481802331917
# LGBM PERFORMANCE FOR CONTROL
# Accuracy: 0.11206896551724138
# Balanced Accuracy: 0.1897822168125231
# Random Balanced Accuracy: 0.18001191708624456
#
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       0.95      0.06      0.12       320
#          1.0       0.11      0.08      0.09        61
#          2.0       0.16      0.33      0.21        76
#          3.0       0.01      0.29      0.03         7
#          4.0       0.00      0.00      0.00         0
#
#     accuracy                           0.11       464
#    macro avg       0.25      0.15      0.09       464
# weighted avg       0.70      0.11      0.13       464
#
# Roc Auc: 0.5207726524537091
# CUDA memory cleared and model deleted.
#
#  Random Classifier Performance Validation:
# Mean Accuracy: 0.2230769230769231
# Std Accuracy: 0.11512791959304433
# Mean Balanced Accuracy: 0.2311111111111111
# Std Balanced Accuracy: 0.11450750084628948
# Mean Random Balanced Accuracy: 0.1705291005291005
# Std Random Balanced Accuracy: 0.079821588311931
# Mean Roc Auc: 0.5253317574238627
# Std Roc Auc: 0.05584197534726202
#
#  TabPFN Classifier Performance Validation:
# Mean Accuracy: 0.4
# Std Accuracy: 0.07133552688842851
# Mean Balanced Accuracy: 0.33452380952380956
# Std Balanced Accuracy: 0.055607685292981185
# Mean Random Balanced Accuracy: 0.15185185185185185
# Std Random Balanced Accuracy: 0.0882169821499429
# Mean Roc Auc: 0.8014663462014721
# Std Roc Auc: 0.016419905974334428
#
#  LGBM Classifier Performance Validation:
# Mean Accuracy: 0.4
# Std Accuracy: 0.10204999354939691
# Mean Balanced Accuracy: 0.36476190476190473
# Std Balanced Accuracy: 0.10387988489726288
# Mean Random Balanced Accuracy: 0.14531746031746035
# Std Random Balanced Accuracy: 0.047942289149969466
# Mean Roc Auc: 0.6587004327353299
# Std Roc Auc: 0.0687810701476788
#
#  MLP Classifier Performance Validation:
# Mean Accuracy: 0.3846153846153846
# Std Accuracy: 0.09730085108210396
# Mean Balanced Accuracy: 0.306984126984127
# Std Balanced Accuracy: 0.07268628165230628
# Mean Random Balanced Accuracy: 0.16206349206349208
# Std Random Balanced Accuracy: 0.06376212406757216
# Mean Roc Auc: 0.6352651267496806
# Std Roc Auc: 0.054817796872543116
#
#  CNN Classifier Performance Validation:
# Mean Accuracy: 0.43076923076923074
# Std Accuracy: 0.09850960365281304
# Mean Balanced Accuracy: 0.35222222222222216
# Std Balanced Accuracy: 0.0990969555594872
# Mean Random Balanced Accuracy: 0.14166666666666666
# Std Random Balanced Accuracy: 0.09695996373710768
# Mean Roc Auc: 0.6916457332395548
# Std Roc Auc: 0.047284792000967316
#
#  TabPFN Classifier Performance Control:
# Mean Accuracy: 0.11508620689655173
# Std Accuracy: 0.023395287491572256
# Mean Balanced Accuracy: 0.23489112766547518
# Std Balanced Accuracy: 0.027100152773288647
# Mean Random Balanced Accuracy: 0.18902518442449978
# Std Random Balanced Accuracy: 0.005174938580436527
# Mean Roc Auc: 0.5431313558621322
# Std Roc Auc: 0.019149188425770132
#
#  LGBM Classifier Performance Control:
# Mean Accuracy: 0.11077586206896553
# Std Accuracy: 0.015930791907393386
# Mean Balanced Accuracy: 0.17153401562307408
# Std Balanced Accuracy: 0.04685074400842235
# Mean Random Balanced Accuracy: 0.18760155929446032
# Std Random Balanced Accuracy: 0.006707437125586997
# Mean Roc Auc: 0.5135139585770216
# Std Roc Auc: 0.046610241623852175
#
#  MLP Classifier Performance Control:
# Mean Accuracy: 0.12543103448275864
# Std Accuracy: 0.039017549940115026
# Mean Balanced Accuracy: 0.23428072614938986
# Std Balanced Accuracy: 0.04193237832929774
# Mean Random Balanced Accuracy: 0.1978016718536685
# Std Random Balanced Accuracy: 0.01875925978850154
# Mean Roc Auc: 0.552925772609296
# Std Roc Auc: 0.017287551711474416
#
#  CNN Classifier Performance Control:
# Mean Accuracy: 0.1543103448275862
# Std Accuracy: 0.039612983554786325
# Mean Balanced Accuracy: 0.21067827098483916
# Std Balanced Accuracy: 0.059662508110428905
# Mean Random Balanced Accuracy: 0.21022390335502825
# Std Random Balanced Accuracy: 0.01157424970831807
# Mean Roc Auc: 0.5710844195064908
# Std Roc Auc: 0.02425769555751484
#
# === Deconfounding Strategy: Correlation_in_Feature ===
#
#  #### TRAINING WITH 0.01 OF THE DATA ####
# Training data shape: (100, 192), length of y: 100
# Training data class distribution: label_age_group
# 2.0    29
# 3.0    27
# 4.0    21
# 1.0    11
# 0.0    10
# 5.0     2
# Name: count, dtype: int64
#
# Fold 1
# RANDOM PERFORMANCE
# Accuracy: 0.19230769230769232
# Balanced Accuracy: 0.1603174603174603
# Random Balanced Accuracy: 0.12962962962962962
#
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       0.17      0.33      0.22         3
#          1.0       0.00      0.00      0.00         3
#          2.0       0.17      0.14      0.15         7
#          3.0       0.50      0.29      0.36         7
#          4.0       0.25      0.20      0.22         5
#          5.0       0.00      0.00      0.00         1
#
#     accuracy                           0.19        26
#    macro avg       0.18      0.16      0.16        26
# weighted avg       0.25      0.19      0.21        26
#
# Roc Auc: 0.36557843885075
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step
# CNN PERFORMANCE
# Accuracy: 0.5
# Balanced Accuracy: 0.39206349206349206
# Random Balanced Accuracy: 0.18333333333333335
#
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       1.00      0.67      0.80         3
#          1.0       0.00      0.00      0.00         3
#          2.0       0.38      0.86      0.52         7
#          3.0       0.50      0.43      0.46         7
#          4.0       1.00      0.40      0.57         5
#          5.0       0.00      0.00      0.00         1
#
#     accuracy                           0.50        26
#    macro avg       0.48      0.39      0.39        26
# weighted avg       0.54      0.50      0.47        26
#
# Roc Auc: 0.5895761141985398
# CNN PERFORMANCE FOR CONTROL
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Accuracy: 0.15301724137931033
# Balanced Accuracy: 0.17667237381363246
# Random Balanced Accuracy: 0.23469896331738438
#
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       0.96      0.07      0.13       320
#          1.0       0.08      0.02      0.03        61
#          2.0       0.21      0.62      0.31        76
#          3.0       0.00      0.00      0.00         7
#          4.0       0.00      0.00      0.00         0
#
#     accuracy                           0.15       464
#    macro avg       0.25      0.14      0.09       464
# weighted avg       0.71      0.15      0.15       464
#
# Roc Auc: 0.54958363717492
# CUDA memory cleared and model deleted.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# MLP PERFORMANCE
# Accuracy: 0.4230769230769231
# Balanced Accuracy: 0.3761904761904762
# Random Balanced Accuracy: 0.20039682539682538
#
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       1.00      0.67      0.80         3
#          1.0       0.33      0.33      0.33         3
#          2.0       0.27      0.43      0.33         7
#          3.0       0.50      0.43      0.46         7
#          4.0       0.50      0.40      0.44         5
#          5.0       0.00      0.00      0.00         1
#
#     accuracy                           0.42        26
#    macro avg       0.43      0.38      0.40        26
# weighted avg       0.46      0.42      0.43        26
#
# Roc Auc: 0.6674773891249863
# MLP PERFORMANCE FOR CONTROL
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Accuracy: 0.1314655172413793
# Balanced Accuracy: 0.2899619052754838
# Random Balanced Accuracy: 0.21342893989782896
#
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       1.00      0.09      0.17       320
#          1.0       0.05      0.05      0.05        61
#          2.0       0.17      0.30      0.22        76
#          3.0       0.03      0.71      0.06         7
#          4.0       0.00      0.00      0.00         0
#
#     accuracy                           0.13       464
#    macro avg       0.25      0.23      0.10       464
# weighted avg       0.72      0.13      0.16       464
#
# Roc Auc: 0.5918868258926426
# CUDA memory cleared and model deleted.
# tabpfn PERFORMANCE
# Accuracy: 0.38461538461538464
# Balanced Accuracy: 0.28571428571428575
# Random Balanced Accuracy: 0.2175925925925926
#
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       0.00      0.00      0.00         3
#          1.0       0.00      0.00      0.00         3
#          2.0       0.33      0.71      0.45         7
#          3.0       0.00      0.00      0.00         7
#          4.0       0.62      1.00      0.77         5
#          5.0       0.00      0.00      0.00         1
#
#     accuracy                           0.38        26
#    macro avg       0.16      0.29      0.20        26
# weighted avg       0.21      0.38      0.27        26
#
# Roc Auc: 0.8375692855326723
# tabpfn PERFORMANCE FOR CONTROL
# Accuracy: 0.05818965517241379
# Balanced Accuracy: 0.1536654135338346
# Random Balanced Accuracy: 0.19727527374586198
#
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       0.00      0.00      0.00       320
#          1.0       0.00      0.00      0.00        61
#          2.0       0.10      0.33      0.15        76
#          3.0       0.02      0.29      0.03         7
#          4.0       0.00      0.00      0.00         0
#
#     accuracy                           0.06       464
#    macro avg       0.02      0.12      0.04       464
# weighted avg       0.02      0.06      0.03       464
#
# Roc Auc: 0.5181640204597742
# CUDA memory cleared and model deleted.
# LGBM PERFORMANCE
# Accuracy: 0.3076923076923077
# Balanced Accuracy: 0.3142857142857143
# Random Balanced Accuracy: 0.05185185185185185
#
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       0.50      0.67      0.57         3
#          1.0       0.20      0.33      0.25         3
#          2.0       0.25      0.29      0.27         7
#          3.0       0.00      0.00      0.00         7
#          4.0       0.60      0.60      0.60         5
#          5.0       0.00      0.00      0.00         1
#
#     accuracy                           0.31        26
#    macro avg       0.26      0.31      0.28        26
# weighted avg       0.26      0.31      0.28        26
#
# Roc Auc: 0.701776906033199
# LGBM PERFORMANCE FOR CONTROL
# Accuracy: 0.16163793103448276
# Balanced Accuracy: 0.2776986010107235
# Random Balanced Accuracy: 0.17957778826547155
#
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       0.98      0.12      0.22       320
#          1.0       0.05      0.03      0.04        61
#          2.0       0.19      0.38      0.26        76
#          3.0       0.03      0.57      0.05         7
#          4.0       0.00      0.00      0.00         0
#          5.0       0.00      0.00      0.00         0
#
#     accuracy                           0.16       464
#    macro avg       0.21      0.19      0.09       464
# weighted avg       0.71      0.16      0.20       464
#
# Roc Auc: 0.5858407258414499
# CUDA memory cleared and model deleted.
#
# Fold 2
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[42], line 91
#      89         X_train, X_test, X_control= feature_extration_with_PCA(X_train_scaled, X_test_scaled, X_control_scaled,  n_components=50)
#      90 elif deconfounding_strategy == "Correlation_in_Feature":
# ---> 91         X_train, X_test, X_control = feature_extraction_with_Pearson(X_train_scaled, X_test_scaled, X_control_scaled, y_train, threshold=0.6, df_columns=df_columns)
#      92 elif deconfounding_strategy == "Correlation_with_target":
#      93         X_train, X_test, X_control = feature_extraction_best_corr_with_target(X_train_scaled, X_test_scaled, X_control_scaled, y_train, threshold=0.6, df_columns=df_columns)
#
# Cell In[36], line 40, in feature_extraction_with_Pearson(X, X_val, X_control, y, threshold, df_columns)
#      38     X_control = pd.DataFrame(X_control)
#      39     if df_columns is not None:
# ---> 40         X_control.columns = df_columns
#      41 correlation_matrix = X.corr().abs()
#      42 upper = correlation_matrix.where(np.triu(np.ones(correlation_matrix.shape), k=1).astype(bool))
#
# File ~/.conda/envs/NAKO_CLIP/lib/python3.11/site-packages/pandas/core/generic.py:6218, in NDFrame.__setattr__(self, name, value)
#    6216 try:
#    6217     object.__getattribute__(self, name)
# -> 6218     return object.__setattr__(self, name, value)
#    6219 except AttributeError:
#    6220     pass
#
# File properties.pyx:69, in pandas._libs.properties.AxisProperty.__set__()
#
# File ~/.conda/envs/NAKO_CLIP/lib/python3.11/site-packages/pandas/core/generic.py:767, in NDFrame._set_axis(self, axis, labels)
#     762 """
#     763 This is called from the cython code when we set the `index` attribute
#     764 directly, e.g. `series.index = [1, 2, 3]`.
#     765 """
#     766 labels = ensure_index(labels)
# --> 767 self._mgr.set_axis(axis, labels)
#     768 self._clear_item_cache()
#
# File ~/.conda/envs/NAKO_CLIP/lib/python3.11/site-packages/pandas/core/internals/managers.py:227, in BaseBlockManager.set_axis(self, axis, new_labels)
#     225 def set_axis(self, axis: AxisInt, new_labels: Index) -> None:
#     226     # Caller is responsible for ensuring we have an Index object.
# --> 227     self._validate_set_axis(axis, new_labels)
#     228     self.axes[axis] = new_labels
#
# File ~/.conda/envs/NAKO_CLIP/lib/python3.11/site-packages/pandas/core/internals/base.py:85, in DataManager._validate_set_axis(self, axis, new_labels)
#      82     pass
#      84 elif new_len != old_len:
# ---> 85     raise ValueError(
#      86         f"Length mismatch: Expected axis has {old_len} elements, new "
#      87         f"values have {new_len} elements"
#      88     )
#
# ValueError: Length mismatch: Expected axis has 77 elements, new values have 192 elements

# %%
for percentage, models in percentage_dict.items():
    print(f"\nResults for {percentage*100:.0f}% of the data:")
    for model, results in models.items():
        print(f"  {model} - Results: {results['results']}")
        if 'results_eval' in results:
            print(f"  {model} - Evaluation Results: {results['results_eval']}")
# Out:
# Results for 1% of the data:
#   TabPFN - Results: {'mean_accuracy': 0.4384615384615385, 'std_accuracy': 0.05217176910096361, 'mean_balanced_accuracy': 0.3692857142857143, 'std_balanced_accuracy': 0.04836166969816029, 'mean_random_balanced_accuracy': 0.11039682539682538, 'std_random_balanced_accuracy': 0.010842559592341622, 'mean_roc_auc': 0.810111207696448, 'std_roc_auc': 0.03102397465316427}
#   TabPFN - Evaluation Results: {'mean_accuracy': 0.09051724137931035, 'std_accuracy': 0.02786763771593899, 'mean_balanced_accuracy': 0.2384368451867373, 'std_balanced_accuracy': 0.03958976135137044, 'mean_random_balanced_accuracy': 0.1960002863992195, 'std_random_balanced_accuracy': 0.01798297888384614, 'mean_roc_auc': 0.5415129034561159, 'std_roc_auc': 0.03607018924889107}
#   LGBM - Results: {'mean_accuracy': 0.36923076923076925, 'std_accuracy': 0.018842228790639848, 'mean_balanced_accuracy': 0.3336507936507936, 'std_balanced_accuracy': 0.03682265999682292, 'mean_random_balanced_accuracy': 0.14527777777777778, 'std_random_balanced_accuracy': 0.0664672944730557, 'mean_roc_auc': 0.6413536567043432, 'std_roc_auc': 0.036912372896314875}
#   LGBM - Evaluation Results: {'mean_accuracy': 0.10043103448275863, 'std_accuracy': 0.014718423343934372, 'mean_balanced_accuracy': 0.17439054218538147, 'std_balanced_accuracy': 0.031173774640224375, 'mean_random_balanced_accuracy': 0.1996903840707246, 'std_random_balanced_accuracy': 0.011782852000437327, 'mean_roc_auc': 0.49068629873420233, 'std_roc_auc': 0.03327142858163014}
#   Random - Results: {'mean_accuracy': 0.2230769230769231, 'std_accuracy': 0.02878197989826108, 'mean_balanced_accuracy': 0.1969047619047619, 'std_balanced_accuracy': 0.05049789889584453, 'mean_random_balanced_accuracy': 0.16817460317460317, 'std_random_balanced_accuracy': 0.07109507684874529, 'mean_roc_auc': 0.49999979774865366, 'std_roc_auc': 0.062376774709205565}
#   Random - Evaluation Results: {'mean_accuracy': 0.2230769230769231, 'std_accuracy': 0.02878197989826108, 'mean_balanced_accuracy': 0.1969047619047619, 'std_balanced_accuracy': 0.05049789889584453, 'mean_random_balanced_accuracy': 0.16817460317460317, 'std_random_balanced_accuracy': 0.07109507684874529, 'mean_roc_auc': 0.49999979774865366, 'std_roc_auc': 0.062376774709205565}
#   MLP - Results: {'mean_accuracy': 0.3846153846153846, 'std_accuracy': 0.0910166120476864, 'mean_balanced_accuracy': 0.3233333333333333, 'std_balanced_accuracy': 0.08977393853626131, 'mean_random_balanced_accuracy': 0.23113997113997115, 'std_random_balanced_accuracy': 0.06549110337050636, 'mean_roc_auc': 0.6831045821074426, 'std_roc_auc': 0.06278898074836058}
#   MLP - Evaluation Results: {'mean_accuracy': 0.15387931034482757, 'std_accuracy': 0.051949938172243096, 'mean_balanced_accuracy': 0.2477887726488352, 'std_balanced_accuracy': 0.031155437649682094, 'mean_random_balanced_accuracy': 0.21033949078831551, 'std_random_balanced_accuracy': 0.015669909206086758, 'mean_roc_auc': 0.5643282323370773, 'std_roc_auc': 0.0488244324669222}
#   CNN - Results: {'mean_accuracy': 0.3615384615384616, 'std_accuracy': 0.10204999354939691, 'mean_balanced_accuracy': 0.3066666666666667, 'std_balanced_accuracy': 0.08323365164364714, 'mean_random_balanced_accuracy': 0.15388888888888888, 'std_random_balanced_accuracy': 0.04936635531449568, 'mean_roc_auc': 0.7112754844951642, 'std_roc_auc': 0.02879781623375072}
#   CNN - Evaluation Results: {'mean_accuracy': 0.13577586206896552, 'std_accuracy': 0.054504987826607176, 'mean_balanced_accuracy': 0.2086283010292124, 'std_balanced_accuracy': 0.08054408061309619, 'mean_random_balanced_accuracy': 0.21042134847128838, 'std_random_balanced_accuracy': 0.039079774249885624, 'mean_roc_auc': 0.5634544066518326, 'std_roc_auc': 0.0350692024273905}

# %%
Feature_extraction_applied = False
Pretraining_applied = False
all_rows = []
for percentage, model in percentage_dict.items():
    for model_name, train_summary in models.items():
        for i, (cv_result, cv_result_eval) in enumerate(zip(train_summary["cv_results"], train_summary["cv_results_eval"])):
            row_train = {
                        "label_col": label_col,
                        "mri_table": mri_table,
                        "test_set_size": f"{(1 - percentage):.2%} (approx. of data left for test)",
                        "Feature_extraction_applied": Feature_extraction_applied,
                        "Pretraining_applied": Pretraining_applied,
                        "model_type": model_name,
                        "Accuracy": cv_result.get("accuracy", None),
                        "AUC": cv_result.get("roc_auc", None),  # or "auc" or whatever your aggregator uses
                        "Balanced_ACC": cv_result.get("balanced_accuracy", None),
                        "Permutation_Balanced_ACC": cv_result.get("random_balanced_accuracy", None), 
                        "number_of_cross_validations": n_splits,
                        "cross_validation_count": i,
                        "search_term": f"{percentage}_{model_name}_train",
                        "percentage_of_data": percentage,  # storing the used fraction
                        "eval_or_train": "train"
                    }
            row_eval = {
                        "label_col": label_col,
                        "mri_table": mri_table,
                        "test_set_size": f"{(1 - percentage):.2%} (approx. of data left for test)",
                        "Feature_extraction_applied": Feature_extraction_applied,
                        "Pretraining_applied": Pretraining_applied,
                        "model_type": model_name,
                        "Accuracy": cv_result_eval.get("accuracy", None),
                        "AUC": cv_result_eval.get("roc_auc", None),  # or "auc" or whatever your aggregator uses
                        "Balanced_ACC": cv_result_eval.get("balanced_accuracy", None),
                        "Permutation_Balanced_ACC": cv_result_eval.get("random_balanced_accuracy", None), 
                        "number_of_cross_validations": n_splits,
                        "cross_validation_count": i,
                        "search_term": f"{percentage}_{model_name}_eval",
                        "percentage_of_data": percentage,  # storing the used fraction
                        "eval_or_train": "eval"
                    }
        all_rows.append(row_eval)
        all_rows.append(row_train)
df_results = pd.DataFrame(all_rows)
df_results.to_csv("results_classification.csv", index=False)

# %%
print(percentage_dict)
# Out:
# {0.01: {'TabPFN': {'results': {'mean_accuracy': 0.4384615384615385, 'std_accuracy': 0.05217176910096361, 'mean_balanced_accuracy': 0.3692857142857143, 'std_balanced_accuracy': 0.04836166969816029, 'mean_random_balanced_accuracy': 0.11039682539682538, 'std_random_balanced_accuracy': 0.010842559592341622, 'mean_roc_auc': 0.810111207696448, 'std_roc_auc': 0.03102397465316427}, 'results_eval': {'mean_accuracy': 0.09051724137931035, 'std_accuracy': 0.02786763771593899, 'mean_balanced_accuracy': 0.2384368451867373, 'std_balanced_accuracy': 0.03958976135137044, 'mean_random_balanced_accuracy': 0.1960002863992195, 'std_random_balanced_accuracy': 0.01798297888384614, 'mean_roc_auc': 0.5415129034561159, 'std_roc_auc': 0.03607018924889107}, 'cv_results': [{'accuracy': 0.5, 'balanced_accuracy': 0.4428571428571429, 'random_balanced_accuracy': 0.1130952380952381, 'classification_report': '              precision    recall  f1-score   support\n\n         0.0       1.00      0.67      0.80         3\n         1.0       0.50      0.33      0.40         3\n         2.0       0.42      0.71      0.53         7\n         3.0       0.20      0.14      0.17         7\n         4.0       0.80      0.80      0.80         5\n         5.0       0.00      0.00      0.00         1\n\n    accuracy                           0.50        26\n   macro avg       0.49      0.44      0.45        26\nweighted avg       0.49      0.50      0.48        26\n', 'roc_auc': 0.8389379245214484}, {'accuracy': 0.46153846153846156, 'balanced_accuracy': 0.3968253968253968, 'random_balanced_accuracy': 0.08888888888888889, 'classification_report': '              precision    recall  f1-score   support\n\n         0.0       0.40      0.67      0.50         3\n         1.0       0.00      0.00      0.00         3\n         2.0       0.27      0.43      0.33         7\n         3.0       0.50      0.29      0.36         7\n         4.0       0.83      1.00      0.91         5\n         5.0       0.00      0.00      0.00         1\n\n    accuracy                           0.46        26\n   macro avg       0.33      0.40      0.35        26\nweighted avg       0.41      0.46      0.42        26\n', 'roc_auc': 0.8310602593440123}, {'accuracy': 0.4230769230769231, 'balanced_accuracy': 0.3194444444444444, 'random_balanced_accuracy': 0.11666666666666665, 'classification_report': '              precision    recall  f1-score   support\n\n         0.0       0.00      0.00      0.00         3\n         1.0       0.50      0.25      0.33         4\n         2.0       0.30      0.50      0.38         6\n         3.0       0.29      0.33      0.31         6\n         4.0       0.71      0.83      0.77         6\n         5.0       0.00      0.00      0.00         1\n\n    accuracy                           0.42        26\n   macro avg       0.30      0.32      0.30        26\nweighted avg       0.38      0.42      0.39        26\n', 'roc_auc': 0.7786089152393499}, {'accuracy': 0.34615384615384615, 'balanced_accuracy': 0.3142857142857143, 'random_balanced_accuracy': 0.11666666666666665, 'classification_report': '              precision    recall  f1-score   support\n\n         0.0       0.00      0.00      0.00         3\n         1.0       0.67      0.67      0.67         3\n         2.0       0.29      0.29      0.29         7\n         3.0       0.33      0.33      0.33         6\n         4.0       0.38      0.60      0.46         5\n         5.0       0.00      0.00      0.00         2\n\n    accuracy                           0.35        26\n   macro avg       0.28      0.31      0.29        26\nweighted avg       0.30      0.35      0.32        26\n', 'roc_auc': 0.7664546329592096}, {'accuracy': 0.46153846153846156, 'balanced_accuracy': 0.373015873015873, 'random_balanced_accuracy': 0.11666666666666665, 'classification_report': '              precision    recall  f1-score   support\n\n         0.0       0.00      0.00      0.00         3\n         1.0       0.20      0.33      0.25    ...

# %%
""" #load a model
import pickle
import os
save_dir = "../98_models/"
with open(os.path.join(save_dir, "tabpfn.pkl"), "rb") as f:
    model = pickle.load(f)
    original_classes = np.unique(y_control)
    results, balanced_accuracy = predict_and_evaluate(model, X_control, y_control, original_classes=original_classes)
    print_model_performance(results) """
# Out:
# ' #load a model\nimport pickle\nimport os\nsave_dir = "../98_models/"\nwith open(os.path.join(save_dir, "tabpfn.pkl"), "rb") as f:\n    model = pickle.load(f)\n    original_classes = np.unique(y_control)\n    results, balanced_accuracy = predict_and_evaluate(model, X_control, y_control, original_classes=original_classes)\n    print_model_performance(results) '

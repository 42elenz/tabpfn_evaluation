# %%
from sklearn.metrics import accuracy_score, roc_auc_score
from sklearn.model_selection import train_test_split, StratifiedKFold
from tabpfn import TabPFNClassifier
import pandas as pd
import os
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from scikeras.wrappers import KerasClassifier
import numpy as np
from sklearn.metrics import balanced_accuracy_score, classification_report
import lightgbm as lgb
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import label_binarize
import gc
import torch
from tensorflow.keras import backend as K
import warnings
warnings.filterwarnings('ignore')
# Out:
# 2025-01-24 19:06:39.368345: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-01-24 19:06:39.383688: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1737741999.402771 2490994 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1737741999.408537 2490994 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-01-24 19:06:39.428587: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
def create_mlp_model(input_shape, num_classes):
    model = Sequential([
        Dense(1024, activation="relu", input_shape=(input_shape,)),
        Dropout(0.3),
        Dense(512, activation="relu"),
        Dropout(0.3),
        Dense(256, activation="relu"),
        Dropout(0.3),
        Dense(128, activation="relu"),
        Dropout(0.3),
        Dense(num_classes, activation="softmax")
    ])
    model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
    return model

# %%
def clean_up_cuda(model):
    # Delete the Keras model
    K.clear_session()
    del model
    
    # Run garbage collection
    gc.collect()
    
    # Free CUDA memory
    if torch.cuda.is_available():
        torch.cuda.empty_cache()
        torch.cuda.ipc_collect()
    
    print("CUDA memory cleared and model deleted.")

# %%
# Example usage
def print_model_performance(results):
    """
    Print model performance metrics
    
    Parameters:
    results (dict): Performance metrics from evaluate_model_performance()
    """
    for metric, value in results.items():
        if metric == 'classification_report':
            print("\nClassification Report:")
            print(value)
        else:
            print(f"{metric.replace('_', ' ').title()}: {value}")
def aggregate_cv_metrics_and_print(all_results, model_name, tag="Validation"):
    """
    Aggregate cross-validation metrics
    
    Parameters:
    all_results (list): List of results dictionaries from each fold
    
    Returns:
    dict: Aggregated metrics with means and standard deviations
    """
    # Initialize aggregation dictionary
    aggregated = {
        'accuracy': [],
        'balanced_accuracy': [],
        'random_balanced_accuracy': [],
        'roc_auc': []
    }
    
    # Collect metrics from each fold
    for result in all_results:
        aggregated['accuracy'].append(result['accuracy'])
        aggregated['balanced_accuracy'].append(result['balanced_accuracy'])
        aggregated['random_balanced_accuracy'].append(result['random_balanced_accuracy'])
        aggregated['roc_auc'].append(result['roc_auc'])
    # Compute mean and standard deviation
    summary = {
        'mean_accuracy': np.mean(aggregated['accuracy']),
        'std_accuracy': np.std(aggregated['accuracy']),
        'mean_balanced_accuracy': np.mean(aggregated['balanced_accuracy']),
        'std_balanced_accuracy': np.std(aggregated['balanced_accuracy']),
        'mean_random_balanced_accuracy': np.mean(aggregated['random_balanced_accuracy']),
        'std_random_balanced_accuracy': np.std(aggregated['random_balanced_accuracy']),
        'mean_roc_auc': np.mean(aggregated['roc_auc']),
        'std_roc_auc': np.std(aggregated['roc_auc'])
    }
    
    print(f"\n {model_name} Classifier Performance {tag}:")
    print_model_performance(summary)
    return summary

# %%
df = pd.read_csv("/zi/home/esra.lenz/Documents/00_HITKIP/09_TABPFN/00_NAKO/00_data/deconfounded_but_age/aparc.thickness_aseg.volume_aparc.volume.csv")
label_df = pd.read_csv("/zi/home/esra.lenz/Documents/00_HITKIP/09_TABPFN/00_NAKO/00_data/age_label/all_ages_all_ids_healthy.csv")
n_splits = 5


label_df = label_df[['ID', 'label_age_group']]
merged_df = pd.merge(df, label_df, on='ID', how='inner')
merged_df.dropna(inplace=True)
df_sampled, _ = train_test_split(merged_df, train_size=10000, stratify=merged_df["label_age_group"], random_state=42)
df_sampled["label_age_group"].value_counts()
# Out:
# label_age_group
# 2.0    2931
# 3.0    2722
# 4.0    2056
# 1.0    1124
# 0.0    1020
# 5.0     147
# Name: count, dtype: int64

# %%
df_control = pd.read_csv("/zi/home/esra.lenz/Documents/00_HITKIP/09_TABPFN/01_Validation_data_set/00_data/final_folder/aparc.thickness_aparc.volume_aseg.volume.csv")
label_df_control = pd.read_csv("/zi/home/esra.lenz/Documents/00_HITKIP/09_TABPFN/01_Validation_data_set/00_data/final_folder/aparc.thickness_aparc.volume_aseg.volume_label.csv")

label_df_control = label_df_control[['ID', 'label_age_group']]
df_control = df_control[df.columns]
merged_df_control = pd.merge(df_control, label_df_control, on='ID', how='inner')
merged_df_control.dropna(inplace=True)

X_control = merged_df_control.drop(["ID", "label_age_group"], axis=1)
y_control = merged_df_control["label_age_group"]

merged_df_control["label_age_group"].value_counts()
# Out:
# label_age_group
# 0.0    320
# 2.0     76
# 1.0     61
# 3.0      7
# Name: count, dtype: int64

# %%
def evaluate_model_performance_train(y_test, y_pred, y_pred_proba, y_val_bin=None):
    # Compute basic metrics
    acc = accuracy_score(y_test, y_pred)
    balanced_acc = balanced_accuracy_score(y_test, y_pred)
    report = classification_report(y_test, y_pred)
    
    # Random comparison
    n_classes = len(np.unique(y_test))
    random_y_test = np.random.randint(0, n_classes, size=y_test.shape)
    random_balanced_acc = balanced_accuracy_score(random_y_test, y_pred)
    
    # ROC AUC (if probabilities provided)
    if y_val_bin is not None:
        y_test = y_val_bin
    auc = roc_auc_score(y_test, y_pred_proba, multi_class='ovr', average='macro')
    
    # Prepare results
    results = {
        'accuracy': acc,
        'balanced_accuracy': balanced_acc,
        'random_balanced_accuracy': random_balanced_acc,
        'classification_report': report
    }
    
    if auc is not None:
        results['roc_auc'] = auc
    
    return results, balanced_acc

# %%
def predict_and_evaluate(model, X_val, y_val, original_classes=None, multi_class=False):
    if multi_class:
        y_pred_proba = model.predict(X_val)
        y_pred = np.argmax(y_pred_proba, axis=1)
        #print(y_pred)
    else:
        y_pred_proba = model.predict_proba(X_val)
        y_pred = model.predict(X_val)
        #print(y_pred)
    
    # Get unique classes present in validation data
    present_classes = np.unique(y_val)
    
    # Get the indices of these classes in the original prediction probabilities
    class_indices = [np.where(original_classes == cls)[0][0] for cls in present_classes]
    
    # Select only the probability columns for present classes
    y_pred_proba_filtered = y_pred_proba[:, class_indices]
    
    # Binarize the true labels using only the present classes
    y_val_bin = label_binarize(y_val, classes=present_classes)

    results, balanced_acc = evaluate_model_performance_train(y_val, y_pred, y_pred_proba_filtered, y_val_bin)
    print_model_performance(results)
    return results, balanced_acc

# %%
percentage_of_the_data = [0.01, 0.03, 0.05, 0.1, 0.15, 0.5, 1]
percentage_dict = {}
for percentage in percentage_of_the_data:

        if percentage == 1:
                print(f"\n #### TRAINING WITH {percentage} OF THE DATA ####")
                df_sampled_subset = df_sampled
        else:
                print(f"\n #### TRAINING WITH {percentage} OF THE DATA ####")
                df_sampled_subset, _ = train_test_split(
                df_sampled,
                train_size=percentage,  # Use train_size to get desired percentage
                stratify=df_sampled["label_age_group"],
                random_state=42
                )

        y = df_sampled_subset["label_age_group"]
        X = df_sampled_subset.drop(["ID", "label_age_group"], axis=1)

        print(f"Training data shape: {X.shape}, length of y: {len(y)}")
        print(f"Training data class distribution: {y.value_counts()}")
        

        skf = StratifiedKFold(n_splits=n_splits, shuffle=True, random_state=42)
        cv_results = {
                'accuracy': [],
                'balanced_accuracy': [],
                'roc_auc': [],
                'classification_reports': []
        }

        tab_pfn = TabPFNClassifier()

        tabpfn_results = []
        tabpfn_results_eval = []
        lgb_results = []
        lgb_results_eval = []
        random_results = []
        mlp_results = []
        mlp_results_eval = []
        model_dict = {}
        model_results = {}


        best_balanced_accuracy_mlp = 0
        best_balanced_accuracy_tabpfn = 0
        best_balanced_accuracy_lgb = 0
        for fold, (train_index, val_index) in enumerate(skf.split(X, y), 1):
                unique_classes = np.unique(y)
                missing_classes = [cls for cls in unique_classes if cls not in y.iloc[val_index]]
                for cls in missing_classes:
                        cls_indices = np.where(y == cls)[0]  # Get all indices of the missing class
                        # Check if removing a sample would leave train set empty for the class
                        train_cls_indices = np.intersect1d(cls_indices, train_index)

                        if len(train_cls_indices) <= 1:
                                # If moving the last one, instead take a duplicate from the whole y array
                                cls_idx_to_move = np.random.choice(cls_indices, 1)[0]
                        else:
                                cls_idx_to_move = np.random.choice(train_cls_indices, 1)[0]
                        # Add to validation set
                        val_index = np.append(val_index, cls_idx_to_move)
                        # Remove only if it's not the last one in train
                        if len(train_cls_indices) > 1:
                                train_index = np.setdiff1d(train_index, cls_idx_to_move)
                print(f"\nFold {fold}")
                X_train, X_test = X.iloc[train_index], X.iloc[val_index]
                y_train, y_test = y.iloc[train_index], y.iloc[val_index]

                #scaler = MinMaxScaler()
                scaler = StandardScaler()
                X_train = scaler.fit_transform(X_train)
                X_test = scaler.transform(X_test)
                
                X_control = scaler.fit_transform(X_control)

                n_classes = len(np.unique(y_test))
                random_y_test = np.random.randint(0, n_classes, size=y_test.shape)
                random_y_pred_proba = np.random.rand(len(y_test), n_classes)
                random_y_pred_proba /= random_y_pred_proba.sum(axis=1)[:, np.newaxis]
                results, balanced_accuracy  = evaluate_model_performance_train(y_test, random_y_test, random_y_pred_proba)
                print("RANDOM PERFORMANCE")
                print_model_performance(results)
                random_results.append(results)

                mlpclf = create_mlp_model(input_shape=X_train.shape[1], num_classes=len(y.unique()))
                mlpclf.fit(X_train, pd.get_dummies(y_train), epochs=10, batch_size=32, verbose=0)
                y_pred_proba = mlpclf.predict(X_test)
                y_pred = np.argmax(y_pred_proba, axis=1)
                results, balanced_accuracy = evaluate_model_performance_train(y_test, y_pred, y_pred_proba)
                print("MLP PERFORMANCE")
                print_model_performance(results)
                mlp_results.append(results)
                #model_dict["mlp"] = mlpclf
                print("MLP PERFORMANCE FOR CONTROL")
                results, balanced_accuracy = predict_and_evaluate(mlpclf, X_control, y_control, original_classes = np.unique(y_train), multi_class=True)
                mlp_results_eval.append(results)
                if balanced_accuracy > best_balanced_accuracy_mlp:
                        best_balanced_accuracy_mlp = balanced_accuracy
                        model_dict["mlp"] = mlpclf
                clean_up_cuda(mlpclf)

                tabclf = TabPFNClassifier()
                tabclf.fit(X_train, y_train)
                y_pred_proba = tabclf.predict_proba(X_test)
                y_pred = tabclf.predict(X_test)
                results, balanced_accuracy = evaluate_model_performance_train(y_test, y_pred, y_pred_proba)
                print("tabpfn PERFORMANCE")
                print_model_performance(results)
                tabpfn_results.append(results)
                #model_dict["tabpfn"] = tabclf
                original_classes = tabclf.classes_
                print("tabpfn PERFORMANCE FOR CONTROL")
                results, balanced_accuracy = predict_and_evaluate(tabclf, X_control, y_control, original_classes=original_classes)
                tabpfn_results_eval.append(results)
                if balanced_accuracy > best_balanced_accuracy_tabpfn:
                        best_balanced_accuracy_tabpfn = balanced_accuracy
                        model_dict["tabpfn"] = tabclf
                clean_up_cuda(tabclf)
                
                lgb_train = lgb.Dataset(X_train, label=y_train)
                lgb_eval = lgb.Dataset(X_test, label=y_test, reference=lgb_train)
                params = {
                'objective': 'multiclass',
                'num_class': len(y.unique()),
                'metric': 'multi_logloss',
                'num_leaves': 31,
                'learning_rate': 0.05,
                'feature_fraction': 0.9,
                'seed': 42,
                'verbose': -1
                }
                lgbclf = lgb.train(params, lgb_train, valid_sets=[lgb_train, lgb_eval], num_boost_round=1000)
                y_pred_proba = lgbclf.predict(X_test)
                y_pred = np.argmax(y_pred_proba, axis=1)
                results, balanced_accuracy = evaluate_model_performance_train(y_test, y_pred, y_pred_proba)
                print("LGBM PERFORMANCE")
                print_model_performance(results)
                lgb_results.append(results)
                print("LGBM PERFORMANCE FOR CONTROL")
                results, balanced_accuracy = predict_and_evaluate(lgbclf, X_control, y_control, original_classes=original_classes, multi_class=True)
                lgb_results_eval.append(results)
                if balanced_accuracy > best_balanced_accuracy_lgb:
                        best_balanced_accuracy_lgb = balanced_accuracy
                        model_dict["lgb"] = lgbclf
                clean_up_cuda(lgbclf)

        random_summary = aggregate_cv_metrics_and_print(random_results, "Random")
        tabpfn_summary = aggregate_cv_metrics_and_print(tabpfn_results, "TabPFN")
        lgb_summary = aggregate_cv_metrics_and_print(lgb_results, "LGBM")
        mlp_summary = aggregate_cv_metrics_and_print(mlp_results, "MLP")

        tabpfn_eval_summary = aggregate_cv_metrics_and_print(tabpfn_results_eval, "TabPFN", "Control")
        lgb_eval_summary = aggregate_cv_metrics_and_print(lgb_results_eval, "LGBM", "Control")
        mlp_eval_summary = aggregate_cv_metrics_and_print(mlp_results_eval, "MLP", "Control")

        percentage_dict[percentage] = {
        "TabPFN": {
                "results": tabpfn_summary,
                "results_eval": tabpfn_eval_summary,
                "cv_results": tabpfn_results,
                "cv_results_eval": tabpfn_results_eval
        },
        "LGBM": {
                "results": lgb_summary,
                "results_eval": lgb_eval_summary,
                "cv_results": lgb_results,
                "cv_results_eval": lgb_results_eval
        },
        "Random": {
                "results": random_summary,
                "cv_results": random_results
        },
        "MLP": {
                "results": mlp_summary,
                "results_eval": mlp_eval_summary,
                "cv_results": mlp_results,
                "cv_results_eval": mlp_results_eval
        }
    }
# Out:
#  #### TRAINING WITH 0.01 OF THE DATA ####
# Training data shape: (100, 192), length of y: 100
# Training data class distribution: label_age_group
# 2.0    29
# 3.0    27
# 4.0    21
# 1.0    11
# 0.0    10
# 5.0     2
# Name: count, dtype: int64
#
# Fold 1
# RANDOM PERFORMANCE
# Accuracy: 0.2692307692307692
# Balanced Accuracy: 0.26190476190476186
# Random Balanced Accuracy: 0.19444444444444445
#
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       0.25      0.33      0.29         3
#          1.0       0.67      0.67      0.67         3
#          2.0       0.33      0.29      0.31         7
#          3.0       0.33      0.29      0.31         7
#          4.0       0.00      0.00      0.00         5
#          5.0       0.00      0.00      0.00         1
#
#     accuracy                           0.27        26
#    macro avg       0.26      0.26      0.26        26
# weighted avg       0.29      0.27      0.28        26
#
# Roc Auc: 0.40174348915767677
# W0000 00:00:1737742005.629677 2490994 gpu_device.cc:2344] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# MLP PERFORMANCE
# Accuracy: 0.3076923076923077
# Balanced Accuracy: 0.2507936507936508
# Random Balanced Accuracy: 0.09999999999999999
#
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       0.50      0.33      0.40         3
#          1.0       0.00      0.00      0.00         3
#          2.0       0.25      0.43      0.32         7
#          3.0       0.20      0.14      0.17         7
#          4.0       0.50      0.60      0.55         5
#          5.0       0.00      0.00      0.00         1
#
#     accuracy                           0.31        26
#    macro avg       0.24      0.25      0.24        26
# weighted avg       0.28      0.31      0.28        26
#
# Roc Auc: 0.6700802731466347
# MLP PERFORMANCE FOR CONTROL
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Accuracy: 0.16163793103448276
# Balanced Accuracy: 0.22136463083939356
# Random Balanced Accuracy: 0.19873343896781398
#
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       1.00      0.07      0.14       320
#          1.0       0.20      0.05      0.08        61
#          2.0       0.26      0.62      0.36        76
#          3.0       0.01      0.14      0.01         7
#          4.0       0.00      0.00      0.00         0
#
#     accuracy                           0.16       464
#    macro avg       0.29      0.18      0.12       464
# weighted avg       0.76      0.16      0.17       464
#
# Roc Auc: 0.5780099039575834
# CUDA memory cleared and model deleted.
# tabpfn PERFORMANCE
# Accuracy: 0.46153846153846156
# Balanced Accuracy: 0.3555555555555556
# Random Balanced Accuracy: 0.13888888888888887
#
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       1.00      0.33      0.50         3
#          1.0       0.00      0.00      0.00         3
#          2.0       0.38      0.71      0.50         7
#          3.0       0.33      0.29      0.31         7
#          4.0       0.67      0.80      0.73         5
#          5.0       0.00      0.00      0.00         1
#
#     accuracy                           0.46        26
#    macro avg       0.40      0.36      0.34        26
# weighted avg       0.44      0.46      0.42        26
#
# Roc Auc: 0.7986117467581999
# tabpfn PERFORMANCE FOR CONTROL
# Accuracy: 0.1314655172413793
# Balanced Accuracy: 0.24009903087637127
# Random Balanced Accuracy: 0.17335102009352998
#
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       0.82      0.04      0.08       320
#          1.0       0.19      0.20      0.20        61
#          2.0       0.24      0.43      0.31        76
#          3.0       0.02      0.29      0.04         7
#          4.0       0.00      0.00      0.00         0
#
#     accuracy                           0.13       464
#    macro avg       0.26      0.19      0.12       464
# weighted avg       0.63      0.13      0.13       464
#
# Roc Auc: 0.6144560488834807
# CUDA memory cleared and model deleted.
# LGBM PERFORMANCE
# Accuracy: 0.3076923076923077
# Balanced Accuracy: 0.273015873015873
# Random Balanced Accuracy: 0.075
#
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       0.50      0.33      0.40         3
#          1.0       0.25      0.33      0.29         3
#          2.0       0.22      0.29      0.25         7
#          3.0       0.33      0.29      0.31         7
#          4.0       0.40      0.40      0.40         5
#          5.0       0.00      0.00      0.00         1
#
#     accuracy                           0.31        26
#    macro avg       0.28      0.27      0.27        26
# weighted avg       0.31      0.31      0.31        26
#
# Roc Auc: 0.5734590098434492
# LGBM PERFORMANCE FOR CONTROL
# Accuracy: 0.1271551724137931
# Balanced Accuracy: 0.25686504298656476
# Random Balanced Accuracy: 0.18084383115218028
#
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       0.93      0.08      0.15       320
#          1.0       0.04      0.02      0.02        61
#          2.0       0.19      0.36      0.25        76
#          3.0       0.03      0.57      0.06         7
#          4.0       0.00      0.00      0.00         0
#
#     accuracy                           0.13       464
#    macro avg       0.24      0.21      0.10       464
# weighted avg       0.68      0.13      0.15       464
#
# Roc Auc: 0.5915933703600429
# CUDA memory cleared and model deleted.
#
# Fold 2
# RANDOM PERFORMANCE
# Accuracy: 0.15384615384615385
# Balanced Accuracy: 0.27936507936507937
# Random Balanced Accuracy: 0.03333333333333333
#
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       0.00      0.00      0.00         3
#          1.0       0.50      0.33      0.40         3
#          2.0       0.20      0.14      0.17         7
#          3.0       0.00      0.00      0.00         7
#          4.0       0.17      0.20      0.18         5
#          5.0       0.33      1.00      0.50         1
#
#     accuracy                           0.15        26
#    macro avg       0.20      0.28      0.21        26
# weighted avg       0.16      0.15      0.15        26
#
# Roc Auc: 0.49718717082561475
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# MLP PERFORMANCE
# Accuracy: 0.4230769230769231
# Balanced Accuracy: 0.38571428571428573
# Random Balanced Accuracy: 0.10833333333333334
#
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       0.33      1.00      0.50         3
#          1.0       0.00      0.00      0.00         3
#          2.0       0.43      0.43      0.43         7
#          3.0       0.50      0.29      0.36         7
#          4.0       0.50      0.60      0.55         5
#          5.0       0.00      0.00      0.00         1
#
#     accuracy                           0.42        26
#    macro avg       0.29      0.39      0.31        26
# weighted avg       0.38      0.42      0.38        26
#
# Roc Auc: 0.7072303948276488
# MLP PERFORMANCE FOR CONTROL
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Accuracy: 0.2650862068965517
# Balanced Accuracy: 0.20645559210526315
# Random Balanced Accuracy: 0.20920518207282915
#
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       0.98      0.25      0.39       320
#          1.0       0.00      0.00      0.00        61
#          2.0       0.22      0.58      0.32        76
#          3.0       0.00      0.00      0.00         7
#          4.0       0.00      0.00      0.00         0
#
#     accuracy                           0.27       464
#    macro avg       0.24      0.17      0.14       464
# weighted avg       0.71      0.27      0.32       464
#
# Roc Auc: 0.5598507115939018
# CUDA memory cleared and model deleted.
# tabpfn PERFORMANCE
# Accuracy: 0.38461538461538464
# Balanced Accuracy: 0.33015873015873015
# Random Balanced Accuracy: 0.22023809523809523
#
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       0.00      0.00      0.00         3
#          1.0       0.50      0.67      0.57         3
#          2.0       0.25      0.43      0.32         7
#          3.0       0.50      0.29      0.36         7
#          4.0       0.75      0.60      0.67         5
#          5.0       0.00      0.00      0.00         1
#
#     accuracy                           0.38        26
#    macro avg       0.33      0.33      0.32        26
# weighted avg       0.40      0.38      0.38        26
#
# Roc Auc: 0.8008237986270023
# tabpfn PERFORMANCE FOR CONTROL
# Accuracy: 0.04741379310344827
# Balanced Accuracy: 0.168670844632072
# Random Balanced Accuracy: 0.22476448846379554
#
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       1.00      0.01      0.01       320
#          1.0       0.21      0.08      0.12        61
#          2.0       0.06      0.16      0.09        76
#          3.0       0.02      0.43      0.03         7
#          4.0       0.00      0.00      0.00         0
#
#     accuracy                           0.05       464
#    macro avg       0.26      0.13      0.05       464
# weighted avg       0.73      0.05      0.04       464
#
# Roc Auc: 0.5337072993835721
# CUDA memory cleared and model deleted.
# LGBM PERFORMANCE
# Accuracy: 0.38461538461538464
# Balanced Accuracy: 0.3523809523809524
# Random Balanced Accuracy: 0.20555555555555557
#
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       0.50      1.00      0.67         3
#          1.0       0.00      0.00      0.00         3
#          2.0       0.38      0.43      0.40         7
#          3.0       0.33      0.29      0.31         7
#          4.0       0.40      0.40      0.40         5
#          5.0       0.00      0.00      0.00         1
#
#     accuracy                           0.38        26
#    macro avg       0.27      0.35      0.30        26
# weighted avg       0.33      0.38      0.34        26
#
# Roc Auc: 0.7221430387563111
# LGBM PERFORMANCE FOR CONTROL
# Accuracy: 0.11422413793103449
# Balanced Accuracy: 0.17972168510415382
# Random Balanced Accuracy: 0.17550632717467904
#
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       0.93      0.08      0.14       320
#          1.0       0.11      0.07      0.08        61
#          2.0       0.15      0.29      0.20        76
#          3.0       0.01      0.29      0.03         7
#          4.0       0.00      0.00      0.00         0
#
#     accuracy                           0.11       464
#    macro avg       0.24      0.14      0.09       464
# weighted avg       0.68      0.11      0.14       464
#
# Roc Auc: 0.4975816183483135
# CUDA memory cleared and model deleted.
#
# Fold 3
# RANDOM PERFORMANCE
# Accuracy: 0.15384615384615385
# Balanced Accuracy: 0.13888888888888887
# Random Balanced Accuracy: 0.23888888888888885
#
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       0.00      0.00      0.00         3
#          1.0       0.50      0.50      0.50         4
#          2.0       0.00      0.00      0.00         6
#          3.0       0.12      0.17      0.14         6
#          4.0       0.50      0.17      0.25         6
#          5.0       0.00      0.00      0.00         1
#
#     accuracy                           0.15        26
#    macro avg       0.19      0.14      0.15        26
# weighted avg       0.22      0.15      0.17        26
#
# Roc Auc: 0.554816644707949
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# MLP PERFORMANCE
# Accuracy: 0.4230769230769231
# Balanced Accuracy: 0.3611111111111111
# Random Balanced Accuracy: 0.3703703703703704
#
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       1.00      0.67      0.80         3
#          1.0       0.00      0.00      0.00         4
#          2.0       0.27      0.67      0.38         6
#          3.0       0.33      0.17      0.22         6
#          4.0       0.67      0.67      0.67         6
#          5.0       0.00      0.00      0.00         1
#
#     accuracy                           0.42        26
#    macro avg       0.38      0.36      0.34        26
# weighted avg       0.41      0.42      0.39        26
#
# Roc Auc: 0.7080050505050505
# MLP PERFORMANCE FOR CONTROL
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Accuracy: 0.11637931034482758
# Balanced Accuracy: 0.1665261386047085
# Random Balanced Accuracy: 0.21594201308107636
#
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       1.00      0.06      0.11       320
#          1.0       0.05      0.03      0.04        61
#          2.0       0.16      0.43      0.23        76
#          3.0       0.01      0.14      0.01         7
#          4.0       0.00      0.00      0.00         0
#
#     accuracy                           0.12       464
#    macro avg       0.24      0.13      0.08       464
# weighted avg       0.72      0.12      0.12       464
#
# Roc Auc: 0.5692450483941011
# CUDA memory cleared and model deleted.
# tabpfn PERFORMANCE
# Accuracy: 0.5
# Balanced Accuracy: 0.375
# Random Balanced Accuracy: 0.0787037037037037
#
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       0.00      0.00      0.00         3
#          1.0       0.33      0.25      0.29         4
#          2.0       0.38      0.83      0.53         6
#          3.0       0.67      0.33      0.44         6
#          4.0       0.71      0.83      0.77         6
#          5.0       0.00      0.00      0.00         1
#
#     accuracy                           0.50        26
#    macro avg       0.35      0.38      0.34        26
# weighted avg       0.46      0.50      0.45        26
#
# Roc Auc: 0.8294707949055775
# tabpfn PERFORMANCE FOR CONTROL
# Accuracy: 0.040948275862068964
# Balanced Accuracy: 0.22866849500801184
# Random Balanced Accuracy: 0.18234294559137992
#
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       0.00      0.00      0.00       320
#          1.0       0.28      0.08      0.13        61
#          2.0       0.06      0.12      0.08        76
#          3.0       0.02      0.71      0.04         7
#          4.0       0.00      0.00      0.00         0
#
#     accuracy                           0.04       464
#    macro avg       0.07      0.18      0.05       464
# weighted avg       0.05      0.04      0.03       464
#
# Roc Auc: 0.501085117561832
# CUDA memory cleared and model deleted.
# LGBM PERFORMANCE
# Accuracy: 0.5384615384615384
# Balanced Accuracy: 0.4444444444444444
# Random Balanced Accuracy: 0.18472222222222223
#
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       1.00      0.67      0.80         3
#          1.0       0.00      0.00      0.00         4
#          2.0       0.45      0.83      0.59         6
#          3.0       0.43      0.50      0.46         6
#          4.0       0.67      0.67      0.67         6
#          5.0       0.00      0.00      0.00         1
#
#     accuracy                           0.54        26
#    macro avg       0.42      0.44      0.42        26
# weighted avg       0.47      0.54      0.49        26
#
# Roc Auc: 0.672854633289416
# LGBM PERFORMANCE FOR CONTROL
# Accuracy: 0.07327586206896551
# Balanced Accuracy: 0.08908599624060151
# Random Balanced Accuracy: 0.18525296367495694
#
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       1.00      0.07      0.13       320
#          1.0       0.00      0.00      0.00        61
#          2.0       0.06      0.14      0.09        76
#          3.0       0.01      0.14      0.01         7
#          4.0       0.00      0.00      0.00         0
#          5.0       0.00      0.00      0.00         0
#
#     accuracy                           0.07       464
#    macro avg       0.18      0.06      0.04       464
# weighted avg       0.70      0.07      0.10       464
#
# Roc Auc: 0.41049799273454235
# CUDA memory cleared and model deleted.
#
# Fold 4
# RANDOM PERFORMANCE
# Accuracy: 0.07692307692307693
# Balanced Accuracy: 0.061111111111111116
# Random Balanced Accuracy: 0.17361111111111108
#
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       0.00      0.00      0.00         3
#          1.0       0.00      0.00      0.00         3
#          2.0       0.00      0.00      0.00         7
#          3.0       0.17      0.17      0.17         6
#          4.0       0.25      0.20      0.22         5
#          5.0       0.00      0.00      0.00         2
#
#     accuracy                           0.08        26
#    macro avg       0.07      0.06      0.06        26
# weighted avg       0.09      0.08      0.08        26
#
# Roc Auc: 0.6615217845337983
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# MLP PERFORMANCE
# Accuracy: 0.3076923076923077
# Balanced Accuracy: 0.2507936507936508
# Random Balanced Accuracy: 0.06666666666666667
#
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       1.00      0.33      0.50         3
#          1.0       0.00      0.00      0.00         3
#          2.0       0.36      0.57      0.44         7
#          3.0       0.00      0.00      0.00         6
#          4.0       0.33      0.60      0.43         5
#          5.0       0.00      0.00      0.00         2
#
#     accuracy                           0.31        26
#    macro avg       0.28      0.25      0.23        26
# weighted avg       0.28      0.31      0.26        26
#
# Roc Auc: 0.5100967999709419
# MLP PERFORMANCE FOR CONTROL
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Accuracy: 0.17672413793103448
# Balanced Accuracy: 0.1601838869715272
# Random Balanced Accuracy: 0.1709805664041616
#
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       1.00      0.14      0.24       320
#          1.0       0.07      0.02      0.03        61
#          2.0       0.23      0.49      0.31        76
#          3.0       0.00      0.00      0.00         7
#          4.0       0.00      0.00      0.00         0
#
#     accuracy                           0.18       464
#    macro avg       0.26      0.13      0.12       464
# weighted avg       0.74      0.18      0.22       464
#
# Roc Auc: 0.5137900358822044
# CUDA memory cleared and model deleted.
# tabpfn PERFORMANCE
# Accuracy: 0.38461538461538464
# Balanced Accuracy: 0.33809523809523806
# Random Balanced Accuracy: 0.1726190476190476
#
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       0.00      0.00      0.00         3
#          1.0       0.67      0.67      0.67         3
#          2.0       0.43      0.43      0.43         7
#          3.0       0.33      0.33      0.33         6
#          4.0       0.33      0.60      0.43         5
#          5.0       0.00      0.00      0.00         2
#
#     accuracy                           0.38        26
#    macro avg       0.29      0.34      0.31        26
# weighted avg       0.33      0.38      0.35        26
#
# Roc Auc: 0.7718408339689805
# tabpfn PERFORMANCE FOR CONTROL
# Accuracy: 0.12931034482758622
# Balanced Accuracy: 0.21502546068038947
# Random Balanced Accuracy: 0.20832797359362437
#
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       0.79      0.11      0.19       320
#          1.0       0.17      0.11      0.14        61
#          2.0       0.14      0.21      0.17        76
#          3.0       0.02      0.43      0.03         7
#          4.0       0.00      0.00      0.00         0
#
#     accuracy                           0.13       464
#    macro avg       0.23      0.17      0.11       464
# weighted avg       0.59      0.13      0.18       464
#
# Roc Auc: 0.5276958991275721
# CUDA memory cleared and model deleted.
# LGBM PERFORMANCE
# Accuracy: 0.3076923076923077
# Balanced Accuracy: 0.2642857142857143
# Random Balanced Accuracy: 0.061111111111111116
#
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       0.00      0.00      0.00         3
#          1.0       0.50      0.33      0.40         3
#          2.0       0.25      0.29      0.27         7
#          3.0       0.20      0.17      0.18         6
#          4.0       0.40      0.80      0.53         5
#          5.0       0.00      0.00      0.00         2
#
#     accuracy                           0.31        26
#    macro avg       0.23      0.26      0.23        26
# weighted avg       0.25      0.31      0.26        26
#
# Roc Auc: 0.5354827285605318
# LGBM PERFORMANCE FOR CONTROL
# Accuracy: 0.10991379310344827
# Balanced Accuracy: 0.13076659373844446
# Random Balanced Accuracy: 0.19734548804786406
#
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       0.93      0.09      0.16       320
#          1.0       0.06      0.02      0.03        61
#          2.0       0.13      0.28      0.18        76
#          3.0       0.01      0.14      0.01         7
#          4.0       0.00      0.00      0.00         0
#          5.0       0.00      0.00      0.00         0
#
#     accuracy                           0.11       464
#    macro avg       0.19      0.09      0.06       464
# weighted avg       0.67      0.11      0.14       464
#
# Roc Auc: 0.4837101444262405
# CUDA memory cleared and model deleted.
#
# Fold 5
# RANDOM PERFORMANCE
# Accuracy: 0.15384615384615385
# Balanced Accuracy: 0.1349206349206349
# Random Balanced Accuracy: 0.11666666666666665
#
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       0.33      0.33      0.33         3
#          1.0       0.00      0.00      0.00         3
#          2.0       0.25      0.14      0.18         7
#          3.0       0.22      0.33      0.27         6
#          4.0       0.00      0.00      0.00         5
#          5.0       0.00      0.00      0.00         2
#
#     accuracy                           0.15        26
#    macro avg       0.13      0.13      0.13        26
# weighted avg       0.16      0.15      0.15        26
#
# Roc Auc: 0.6897215865751335
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# MLP PERFORMANCE
# Accuracy: 0.3076923076923077
# Balanced Accuracy: 0.2349206349206349
# Random Balanced Accuracy: 0.22499999999999998
#
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       0.00      0.00      0.00         3
#          1.0       0.00      0.00      0.00         3
#          2.0       0.14      0.14      0.14         7
#          3.0       0.33      0.67      0.44         6
#          4.0       0.50      0.60      0.55         5
#          5.0       0.00      0.00      0.00         2
#
#     accuracy                           0.31        26
#    macro avg       0.16      0.23      0.19        26
# weighted avg       0.21      0.31      0.25        26
#
# Roc Auc: 0.659915640550652
# MLP PERFORMANCE FOR CONTROL
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Accuracy: 0.07327586206896551
# Balanced Accuracy: 0.1806356310859115
# Random Balanced Accuracy: 0.2138264396151181
#
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       1.00      0.04      0.07       320
#          1.0       0.06      0.03      0.04        61
#          2.0       0.13      0.22      0.17        76
#          3.0       0.02      0.43      0.03         7
#          4.0       0.00      0.00      0.00         0
#
#     accuracy                           0.07       464
#    macro avg       0.24      0.14      0.06       464
# weighted avg       0.72      0.07      0.08       464
#
# Roc Auc: 0.5140934478255768
# CUDA memory cleared and model deleted.
# tabpfn PERFORMANCE
# Accuracy: 0.38461538461538464
# Balanced Accuracy: 0.31984126984126987
# Random Balanced Accuracy: 0.10277777777777779
#
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       0.00      0.00      0.00         3
#          1.0       0.20      0.33      0.25         3
#          2.0       0.33      0.29      0.31         7
#          3.0       0.50      0.50      0.50         6
#          4.0       0.44      0.80      0.57         5
#          5.0       0.00      0.00      0.00         2
#
#     accuracy                           0.38        26
#    macro avg       0.25      0.32      0.27        26
# weighted avg       0.31      0.38      0.34        26
#
# Roc Auc: 0.8054325124405216
# tabpfn PERFORMANCE FOR CONTROL
# Accuracy: 0.04741379310344827
# Balanced Accuracy: 0.24015469000369777
# Random Balanced Accuracy: 0.2174276154613322
#
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       0.00      0.00      0.00       320
#          1.0       0.21      0.11      0.15        61
#          2.0       0.07      0.13      0.09        76
#          3.0       0.03      0.71      0.05         7
#          4.0       0.00      0.00      0.00         0
#
#     accuracy                           0.05       464
#    macro avg       0.06      0.19      0.06       464
# weighted avg       0.04      0.05      0.04       464
#
# Roc Auc: 0.5303356347418452
# CUDA memory cleared and model deleted.
# LGBM PERFORMANCE
# Accuracy: 0.2692307692307692
# Balanced Accuracy: 0.20873015873015874
# Random Balanced Accuracy: 0.13888888888888887
#
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       0.00      0.00      0.00         3
#          1.0       0.00      0.00      0.00         3
#          2.0       0.17      0.29      0.21         7
#          3.0       0.17      0.17      0.17         6
#          4.0       0.67      0.80      0.73         5
#          5.0       0.00      0.00      0.00         2
#
#     accuracy                           0.27        26
#    macro avg       0.17      0.21      0.18        26
# weighted avg       0.21      0.27      0.24        26
#
# Roc Auc: 0.5833696560241183
# LGBM PERFORMANCE FOR CONTROL
# Accuracy: 0.10560344827586207
# Balanced Accuracy: 0.17918647155799333
# Random Balanced Accuracy: 0.16908929636151243
#
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       0.90      0.06      0.11       320
#          1.0       0.03      0.02      0.02        61
#          2.0       0.17      0.36      0.23        76
#          3.0       0.02      0.29      0.03         7
#          4.0       0.00      0.00      0.00         0
#          5.0       0.00      0.00      0.00         0
#
#     accuracy                           0.11       464
#    macro avg       0.19      0.12      0.07       464
# weighted avg       0.66      0.11      0.12       464
#
# Roc Auc: 0.514055262802748
# CUDA memory cleared and model deleted.
#
#  Random Classifier Performance Validation:
# Mean Accuracy: 0.16153846153846152
# Std Accuracy: 0.06153846153846153
# Mean Balanced Accuracy: 0.17523809523809522
# Std Balanced Accuracy: 0.08285562243937386
# Mean Random Balanced Accuracy: 0.15138888888888888
# Std Random Balanced Accuracy: 0.07091770574161518
# Mean Roc Auc: 0.5609981351600345
# Std Roc Auc: 0.10596869659901346
#
#  TabPFN Classifier Performance Validation:
# Mean Accuracy: 0.4230769230769231
# Std Accuracy: 0.04865042554105198
# Mean Balanced Accuracy: 0.3437301587301587
# Std Balanced Accuracy: 0.019515419541972934
# Mean Random Balanced Accuracy: 0.14264550264550263
# Std Random Balanced Accuracy: 0.050221758448862786
# Mean Roc Auc: 0.8012359373400564
# Std Roc Auc: 0.018362716362477795
#
#  LGBM Classifier Performance Validation:
# Mean Accuracy: 0.36153846153846153
# Std Accuracy: 0.09607689228305227
# Mean Balanced Accuracy: 0.30857142857142855
# Std Balanced Accuracy: 0.08194443483608076
# Mean Random Balanced Accuracy: 0.13305555555555554
# Std Random Balanced Accuracy: 0.057456370994879546
# Mean Roc Auc: 0.6174618132947653
# Std Roc Auc: 0.069058838252457
#
#  MLP Classifier Performance Validation:
# Mean Accuracy: 0.35384615384615387
# Std Accuracy: 0.05652668637191949
# Mean Balanced Accuracy: 0.2966666666666667
# Std Balanced Accuracy: 0.06340947008887059
# Mean Random Balanced Accuracy: 0.17407407407407408
# Std Random Balanced Accuracy: 0.11177732371112645
# Mean Roc Auc: 0.6510656318001855
# Std Roc Auc: 0.07308716548902143
#
#  TabPFN Classifier Performance Control:
# Mean Accuracy: 0.07931034482758621
# Std Accuracy: 0.04177700412573597
# Mean Balanced Accuracy: 0.21852370424010842
# Std Balanced Accuracy: 0.02658517016455709
# Mean Random Balanced Accuracy: 0.20124280864073238
# Std Random Balanced Accuracy: 0.020002868032233025
# Mean Roc Auc: 0.5414559999396604
# Std Roc Auc: 0.03829323842811978
#
#  LGBM Classifier Performance Control:
# Mean Accuracy: 0.10603448275862068
# Std Accuracy: 0.017897016803471288
# Mean Balanced Accuracy: 0.16712515792555158
# Std Balanced Accuracy: 0.05615950623091876
# Mean Random Balanced Accuracy: 0.18160758128223856
# Std Random Balanced Accuracy: 0.009544491557493434
# Mean Roc Auc: 0.49948767773437747
# Std Roc Auc: 0.05808166802842396
#
#  MLP Classifier Performance Control:
# Mean Accuracy: 0.15862068965517243
# Std Accuracy: 0.06440468720248874
# Mean Balanced Accuracy: 0.18703317592136076
# Std Balanced Accuracy: 0.023401839772759062
# Mean Random Balanced Accuracy: 0.20173752802819983
# Std Random Balanced Accuracy: 0.01648447921730789
# Mean Roc Auc: 0.5469978295306734
# Std Roc Auc: 0.027594709562315432
#
#  #### TRAINING WITH 0.03 OF THE DATA ####
# Training data shape: (300, 192), length of y: 300
# Training data class distribution: label_age_group
# 2.0    88
# 3.0    82
# 4.0    62
# 1.0    34
# 0.0    30
# 5.0     4
# Name: count, dtype: int64
#
# Fold 1
# RANDOM PERFORMANCE
# Accuracy: 0.18181818181818182
# Balanced Accuracy: 0.14781746031746032
# Random Balanced Accuracy: 0.1675925925925926
#
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       0.08      0.14      0.10         7
#          1.0       0.10      0.12      0.11         8
#          2.0       0.44      0.22      0.30        18
#          3.0       0.25      0.11      0.15        18
#          4.0       0.21      0.29      0.24        14
#          5.0       0.00      0.00      0.00         1
#
#     accuracy                           0.18        66
#    macro avg       0.18      0.15      0.15        66
# weighted avg       0.25      0.18      0.20        66
#
# Roc Auc: 0.6023311678283186
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# MLP PERFORMANCE
# Accuracy: 0.4393939393939394
# Balanced Accuracy: 0.3435846560846561
# Random Balanced Accuracy: 0.14285714285714288
#
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       0.50      0.29      0.36         7
#          1.0       0.20      0.12      0.15         8
#          2.0       0.29      0.33      0.31        18
#          3.0       0.44      0.39      0.41        18
#          4.0       0.65      0.93      0.76        14
#          5.0       0.00      0.00      0.00         1
#
#     accuracy                           0.44        66
#    macro avg       0.35      0.34      0.33        66
# weighted avg       0.41      0.44      0.42        66
#
# Roc Auc: 0.7440274137332388
# MLP PERFORMANCE FOR CONTROL
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Accuracy: 0.1206896551724138
# Balanced Accuracy: 0.1062734962406015
# Random Balanced Accuracy: 0.17498033401480195
#
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       1.00      0.14      0.24       320
#          1.0       0.00      0.00      0.00        61
#          2.0       0.08      0.14      0.10        76
#          3.0       0.01      0.14      0.01         7
#          4.0       0.00      0.00      0.00         0
#
#     accuracy                           0.12       464
#    macro avg       0.22      0.09      0.07       464
# weighted avg       0.70      0.12      0.18       464
#
# Roc Auc: 0.4474771472761617
# CUDA memory cleared and model deleted.
# tabpfn PERFORMANCE
# Accuracy: 0.5909090909090909
# Balanced Accuracy: 0.4715608465608465
# Random Balanced Accuracy: 0.2298701298701299
#
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       0.44      0.57      0.50         7
#          1.0       1.00      0.25      0.40         8
#          2.0       0.52      0.72      0.60        18
#          3.0       0.60      0.50      0.55        18
#          4.0       0.79      0.79      0.79        14
#          5.0       0.00      0.00      0.00         1
#
#     accuracy                           0.59        66
#    macro avg       0.56      0.47      0.47        66
# weighted avg       0.64      0.59      0.58        66
#
# Roc Auc: 0.8785112080918628
# tabpfn PERFORMANCE FOR CONTROL
# Accuracy: 0.125
# Balanced Accuracy: 0.2027843045112782
# Random Balanced Accuracy: 0.20961919250458805
#
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       0.94      0.11      0.19       320
#          1.0       0.00      0.00      0.00        61
#          2.0       0.12      0.28      0.17        76
#          3.0       0.02      0.43      0.03         7
#          4.0       0.00      0.00      0.00         0
#          5.0       0.00      0.00      0.00         0
#
#     accuracy                           0.12       464
#    macro avg       0.18      0.14      0.07       464
# weighted avg       0.67      0.12      0.16       464
#
# Roc Auc: 0.5003160833701383
# CUDA memory cleared and model deleted.
# LGBM PERFORMANCE
# Accuracy: 0.42424242424242425
# Balanced Accuracy: 0.32903439153439157
# Random Balanced Accuracy: 0.1891774891774892
#
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       0.50      0.29      0.36         7
#          1.0       0.17      0.12      0.14         8
#          2.0       0.32      0.50      0.39        18
#          3.0       0.45      0.28      0.34        18
#          4.0       0.65      0.79      0.71        14
#          5.0       0.00      0.00      0.00         1
#
#     accuracy                           0.42        66
#    macro avg       0.35      0.33      0.33        66
# weighted avg       0.42      0.42      0.41        66
#
# Roc Auc: 0.6915619614906094
# LGBM PERFORMANCE FOR CONTROL
# Accuracy: 0.14224137931034483
# Balanced Accuracy: 0.14266743960310613
# Random Balanced Accuracy: 0.1829225579225579
#
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       1.00      0.09      0.17       320
#          1.0       0.04      0.02      0.02        61
#          2.0       0.20      0.46      0.28        76
#          3.0       0.00      0.00      0.00         7
#          4.0       0.00      0.00      0.00         0
#
#     accuracy                           0.14       464
#    macro avg       0.25      0.11      0.09       464
# weighted avg       0.73      0.14      0.17       464
#
# Roc Auc: 0.4946208659558551
# CUDA memory cleared and model deleted.
#
# Fold 2
# RANDOM PERFORMANCE
# Accuracy: 0.19696969696969696
# Balanced Accuracy: 0.20105820105820105
# Random Balanced Accuracy: 0.17407407407407405
#
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       0.10      0.14      0.12         7
#          1.0       0.21      0.57      0.31         7
#          2.0       0.40      0.22      0.29        18
#          3.0       0.10      0.06      0.07        18
#          4.0       0.33      0.21      0.26        14
#          5.0       0.00      0.00      0.00         2
#
#     accuracy                           0.20        66
#    macro avg       0.19      0.20      0.17        66
# weighted avg       0.24      0.20      0.20        66
#
# Roc Auc: 0.5226985901862314
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# MLP PERFORMANCE
# Accuracy: 0.3939393939393939
# Balanced Accuracy: 0.33465608465608465
# Random Balanced Accuracy: 0.07903439153439153
#
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       0.29      0.29      0.29         7
#          1.0       0.38      0.43      0.40         7
#          2.0       0.33      0.28      0.30        18
#          3.0       0.38      0.44      0.41        18
#          4.0       0.53      0.57      0.55        14
#          5.0       0.00      0.00      0.00         2
#
#     accuracy                           0.39        66
#    macro avg       0.32      0.33      0.33        66
# weighted avg       0.38      0.39      0.38        66
#
# Roc Auc: 0.6960911559472648
# MLP PERFORMANCE FOR CONTROL
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Accuracy: 0.11206896551724138
# Balanced Accuracy: 0.118015742481203
# Random Balanced Accuracy: 0.2058456466398427
#
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       1.00      0.15      0.26       320
#          1.0       0.00      0.00      0.00        61
#          2.0       0.05      0.04      0.04        76
#          3.0       0.01      0.29      0.02         7
#          4.0       0.00      0.00      0.00         0
#
#     accuracy                           0.11       464
#    macro avg       0.21      0.09      0.06       464
# weighted avg       0.70      0.11      0.18       464
#
# Roc Auc: 0.4498509779692006
# CUDA memory cleared and model deleted.
# tabpfn PERFORMANCE
# Accuracy: 0.5454545454545454
# Balanced Accuracy: 0.458994708994709
# Random Balanced Accuracy: 0.1265367258014317
#
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       0.67      0.86      0.75         7
#          1.0       0.50      0.14      0.22         7
#          2.0       0.54      0.78      0.64        18
#          3.0       0.50      0.33      0.40        18
#          4.0       0.53      0.64      0.58        14
#          5.0       0.00      0.00      0.00         2
#
#     accuracy                           0.55        66
#    macro avg       0.46      0.46      0.43        66
# weighted avg       0.52      0.55      0.51        66
#
# Roc Auc: 0.8689669590976088
# tabpfn PERFORMANCE FOR CONTROL
# Accuracy: 0.10129310344827586
# Balanced Accuracy: 0.11178336466165413
# Random Balanced Accuracy: 0.20912910055746142
#
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       0.94      0.09      0.17       320
#          1.0       0.00      0.00      0.00        61
#          2.0       0.09      0.21      0.13        76
#          3.0       0.01      0.14      0.01         7
#          4.0       0.00      0.00      0.00         0
#
#     accuracy                           0.10       464
#    macro avg       0.21      0.09      0.06       464
# weighted avg       0.66      0.10      0.14       464
#
# Roc Auc: 0.4897551809365056
# CUDA memory cleared and model deleted.
# LGBM PERFORMANCE
# Accuracy: 0.4090909090909091
# Balanced Accuracy: 0.34656084656084657
# Random Balanced Accuracy: 0.14675925925925926
#
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       0.67      0.29      0.40         7
#          1.0       0.43      0.43      0.43         7
#          2.0       0.40      0.56      0.47        18
#          3.0       0.23      0.17      0.19        18
#          4.0       0.50      0.64      0.56        14
#          5.0       0.00      0.00      0.00         2
#
#     accuracy                           0.41        66
#    macro avg       0.37      0.35      0.34        66
# weighted avg       0.39      0.41      0.39        66
#
# Roc Auc: 0.7788906246047843
# LGBM PERFORMANCE FOR CONTROL
# Accuracy: 0.1271551724137931
# Balanced Accuracy: 0.10459178170836929
# Random Balanced Accuracy: 0.20085997418998414
#
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       0.88      0.11      0.20       320
#          1.0       0.03      0.02      0.02        61
#          2.0       0.16      0.29      0.21        76
#          3.0       0.00      0.00      0.00         7
#          4.0       0.00      0.00      0.00         0
#
#     accuracy                           0.13       464
#    macro avg       0.21      0.08      0.09       464
# weighted avg       0.64      0.13      0.17       464
#
# Roc Auc: 0.44575067345105246
# CUDA memory cleared and model deleted.
#
# Fold 3
# RANDOM PERFORMANCE
# Accuracy: 0.13636363636363635
# Balanced Accuracy: 0.09712133841390806
# Random Balanced Accuracy: 0.22697163947163948
#
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       0.00      0.00      0.00         7
#          1.0       0.08      0.12      0.10         8
#          2.0       0.42      0.26      0.32        19
#          3.0       0.17      0.12      0.14        17
#          4.0       0.10      0.08      0.09        13
#          5.0       0.00      0.00      0.00         2
#
#     accuracy                           0.14        66
#    macro avg       0.13      0.10      0.11        66
# weighted avg       0.19      0.14      0.16        66
#
# Roc Auc: 0.47070222718447824
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# MLP PERFORMANCE
# Accuracy: 0.5
# Balanced Accuracy: 0.41947203982807696
# Random Balanced Accuracy: 0.10978835978835978
#
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       0.80      0.57      0.67         7
#          1.0       0.33      0.25      0.29         8
#          2.0       0.47      0.47      0.47        19
#          3.0       0.50      0.53      0.51        17
#          4.0       0.50      0.69      0.58        13
#          5.0       0.00      0.00      0.00         2
#
#     accuracy                           0.50        66
#    macro avg       0.43      0.42      0.42        66
# weighted avg       0.49      0.50      0.49        66
#
# Roc Auc: 0.6621507190813414
# MLP PERFORMANCE FOR CONTROL
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Accuracy: 0.09267241379310345
# Balanced Accuracy: 0.09360902255639098
# Random Balanced Accuracy: 0.19111841945789762
#
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       1.00      0.10      0.18       320
#          1.0       0.00      0.00      0.00        61
#          2.0       0.07      0.13      0.09        76
#          3.0       0.01      0.14      0.01         7
#          4.0       0.00      0.00      0.00         0
#
#     accuracy                           0.09       464
#    macro avg       0.21      0.07      0.06       464
# weighted avg       0.70      0.09      0.14       464
#
# Roc Auc: 0.43025274044191064
# CUDA memory cleared and model deleted.
# tabpfn PERFORMANCE
# Accuracy: 0.48484848484848486
# Balanced Accuracy: 0.4005829052268681
# Random Balanced Accuracy: 0.1935185185185185
#
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       0.50      0.71      0.59         7
#          1.0       0.00      0.00      0.00         8
#          2.0       0.53      0.53      0.53        19
#          3.0       0.38      0.47      0.42        17
#          4.0       0.56      0.69      0.62        13
#          5.0       0.00      0.00      0.00         2
#
#     accuracy                           0.48        66
#    macro avg       0.33      0.40      0.36        66
# weighted avg       0.41      0.48      0.44        66
#
# Roc Auc: 0.8400735034173907
# tabpfn PERFORMANCE FOR CONTROL
# Accuracy: 0.09913793103448276
# Balanced Accuracy: 0.21078477443609023
# Random Balanced Accuracy: 0.19882738095238095
#
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       0.93      0.09      0.16       320
#          1.0       0.00      0.00      0.00        61
#          2.0       0.09      0.18      0.12        76
#          3.0       0.02      0.57      0.04         7
#          4.0       0.00      0.00      0.00         0
#
#     accuracy                           0.10       464
#    macro avg       0.21      0.17      0.06       464
# weighted avg       0.66      0.10      0.13       464
#
# Roc Auc: 0.5072133080754594
# CUDA memory cleared and model deleted.
# LGBM PERFORMANCE
# Accuracy: 0.42424242424242425
# Balanced Accuracy: 0.3584704124564806
# Random Balanced Accuracy: 0.11842105263157894
#
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       0.57      0.57      0.57         7
#          1.0       0.20      0.12      0.15         8
#          2.0       0.39      0.37      0.38        19
#          3.0       0.44      0.47      0.46        17
#          4.0       0.44      0.62      0.52        13
#          5.0       0.00      0.00      0.00         2
#
#     accuracy                           0.42        66
#    macro avg       0.34      0.36      0.35        66
# weighted avg       0.40      0.42      0.41        66
#
# Roc Auc: 0.6353237287987431
# LGBM PERFORMANCE FOR CONTROL
# Accuracy: 0.15517241379310345
# Balanced Accuracy: 0.1340049342105263
# Random Balanced Accuracy: 0.2204122496273987
#
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       1.00      0.13      0.23       320
#          1.0       0.00      0.00      0.00        61
#          2.0       0.20      0.41      0.27        76
#          3.0       0.00      0.00      0.00         7
#          4.0       0.00      0.00      0.00         0
#
#     accuracy                           0.16       464
#    macro avg       0.24      0.11      0.10       464
# weighted avg       0.72      0.16      0.20       464
#
# Roc Auc: 0.4892034539778033
# CUDA memory cleared and model deleted.
#
# Fold 4
# RANDOM PERFORMANCE
# Accuracy: 0.25757575757575757
# Balanced Accuracy: 0.1824981004547568
# Random Balanced Accuracy: 0.05714285714285714
#
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       0.08      0.14      0.11         7
#          1.0       0.00      0.00      0.00         8
#          2.0       0.44      0.37      0.40        19
#          3.0       0.60      0.35      0.44        17
#          4.0       0.30      0.23      0.26        13
#          5.0       0.00      0.00      0.00         2
#
#     accuracy                           0.26        66
#    macro avg       0.24      0.18      0.20        66
# weighted avg       0.35      0.26      0.29        66
#
# Roc Auc: 0.44146252626750887
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# MLP PERFORMANCE
# Accuracy: 0.3333333333333333
# Balanced Accuracy: 0.2647746345501763
# Random Balanced Accuracy: 0.08686868686868687
#
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       0.20      0.14      0.17         7
#          1.0       0.33      0.12      0.18         8
#          2.0       0.20      0.16      0.18        19
#          3.0       0.27      0.47      0.34        17
#          4.0       0.69      0.69      0.69        13
#          5.0       0.00      0.00      0.00         2
#
#     accuracy                           0.33        66
#    macro avg       0.28      0.26      0.26        66
# weighted avg       0.32      0.33      0.31        66
#
# Roc Auc: 0.626858756219665
# MLP PERFORMANCE FOR CONTROL
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Accuracy: 0.07758620689655173
# Balanced Accuracy: 0.04317434210526316
# Random Balanced Accuracy: 0.1936510824805237
#
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       1.00      0.09      0.17       320
#          1.0       0.00      0.00      0.00        61
#          2.0       0.12      0.08      0.10        76
#          3.0       0.00      0.00      0.00         7
#          4.0       0.00      0.00      0.00         0
#
#     accuracy                           0.08       464
#    macro avg       0.22      0.03      0.05       464
# weighted avg       0.71      0.08      0.13       464
#
# Roc Auc: 0.4062221599274906
# CUDA memory cleared and model deleted.
# tabpfn PERFORMANCE
# Accuracy: 0.4393939393939394
# Balanced Accuracy: 0.33811976207487043
# Random Balanced Accuracy: 0.1416786916786917
#
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       0.40      0.29      0.33         7
#          1.0       0.17      0.12      0.14         8
#          2.0       0.40      0.63      0.49        19
#          3.0       0.42      0.29      0.34        17
#          4.0       0.69      0.69      0.69        13
#          5.0       0.00      0.00      0.00         2
#
#     accuracy                           0.44        66
#    macro avg       0.35      0.34      0.33        66
# weighted avg       0.42      0.44      0.42        66
#
# Roc Auc: 0.8227645771673494
# tabpfn PERFORMANCE FOR CONTROL
# Accuracy: 0.08836206896551724
# Balanced Accuracy: 0.1545700187969925
# Random Balanced Accuracy: 0.201328384305358
#
# Classification Report:
# ...
#          1.0       0.41      0.24      0.30       225
#          2.0       0.56      0.66      0.61       587
#          3.0       0.53      0.57      0.55       546
#          4.0       0.71      0.67      0.69       412
#          5.0       0.00      0.00      0.00        30
#
#     accuracy                           0.59      2005
#    macro avg       0.49      0.47      0.48      2005
# weighted avg       0.57      0.59      0.58      2005
#
# Roc Auc: 0.877863647637569
# tabpfn PERFORMANCE FOR CONTROL
# Accuracy: 0.11637931034482758
# Balanced Accuracy: 0.3060761855971897
# Random Balanced Accuracy: 0.24693611473272487
#
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       0.96      0.08      0.16       320
#          1.0       0.09      0.03      0.05        61
#          2.0       0.10      0.25      0.14        76
#          3.0       0.03      0.86      0.07         7
#          4.0       0.00      0.00      0.00         0
#
#     accuracy                           0.12       464
#    macro avg       0.24      0.24      0.08       464
# weighted avg       0.69      0.12      0.14       464
#
# Roc Auc: 0.6186485326803812
# CUDA memory cleared and model deleted.
# LGBM PERFORMANCE
# Accuracy: 0.5326683291770573
# Balanced Accuracy: 0.420562332148182
# Random Balanced Accuracy: 0.18126066839682228
#
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       0.66      0.57      0.61       205
#          1.0       0.28      0.16      0.20       225
#          2.0       0.50      0.65      0.57       587
#          3.0       0.50      0.46      0.48       546
#          4.0       0.64      0.70      0.67       412
#          5.0       0.00      0.00      0.00        30
#
#     accuracy                           0.53      2005
#    macro avg       0.43      0.42      0.42      2005
# weighted avg       0.51      0.53      0.52      2005
#
# Roc Auc: 0.8355829795405264
# LGBM PERFORMANCE FOR CONTROL
# Accuracy: 0.08189655172413793
# Balanced Accuracy: 0.24941914211758906
# Random Balanced Accuracy: 0.23507703848106265
#
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       1.00      0.05      0.10       320
#          1.0       0.14      0.05      0.07        61
#          2.0       0.09      0.18      0.12        76
#          3.0       0.03      0.71      0.05         7
#          4.0       0.00      0.00      0.00         0
#
#     accuracy                           0.08       464
#    macro avg       0.25      0.20      0.07       464
# weighted avg       0.72      0.08      0.10       464
#
# Roc Auc: 0.5751666170758452
# CUDA memory cleared and model deleted.
#
# Fold 2
# RANDOM PERFORMANCE
# Accuracy: 0.1661676646706587
# Balanced Accuracy: 0.18154290176923096
# Random Balanced Accuracy: 0.16622514711276856
#
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       0.11      0.17      0.13       204
#          1.0       0.10      0.16      0.12       226
#          2.0       0.33      0.18      0.23       587
#          3.0       0.24      0.16      0.19       546
#          4.0       0.20      0.16      0.18       411
#          5.0       0.02      0.27      0.05        30
#
#     accuracy                           0.17      2004
#    macro avg       0.17      0.18      0.15      2004
# weighted avg       0.23      0.17      0.18      2004
#
# Roc Auc: 0.49838047232534155
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# MLP PERFORMANCE
# Accuracy: 0.5568862275449101
# Balanced Accuracy: 0.46712084517370345
# Random Balanced Accuracy: 0.16085482953015282
#
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       0.57      0.78      0.66       204
#          1.0       0.37      0.21      0.27       226
#          2.0       0.56      0.60      0.58       587
#          3.0       0.52      0.43      0.47       546
#          4.0       0.62      0.78      0.69       411
#          5.0       0.00      0.00      0.00        30
#
#     accuracy                           0.56      2004
#    macro avg       0.44      0.47      0.45      2004
# weighted avg       0.53      0.56      0.54      2004
#
# Roc Auc: 0.8722022460226281
# MLP PERFORMANCE FOR CONTROL
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Accuracy: 0.09482758620689655
# Balanced Accuracy: 0.21504760877603846
# Random Balanced Accuracy: 0.17845391527773724
#
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       0.96      0.07      0.14       320
#          1.0       0.03      0.02      0.02        61
#          2.0       0.08      0.20      0.12        76
#          3.0       0.03      0.57      0.06         7
#          4.0       0.00      0.00      0.00         0
#
#     accuracy                           0.09       464
#    macro avg       0.22      0.17      0.07       464
# weighted avg       0.68      0.09      0.12       464
#
# Roc Auc: 0.543672317039563
# CUDA memory cleared and model deleted.
# tabpfn PERFORMANCE
# Accuracy: 0.5653692614770459
# Balanced Accuracy: 0.4560593834718485
# Random Balanced Accuracy: 0.17607179189130076
#
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       0.64      0.70      0.67       204
#          1.0       0.42      0.19      0.27       226
#          2.0       0.54      0.65      0.59       587
#          3.0       0.51      0.55      0.53       546
#          4.0       0.70      0.65      0.67       411
#          5.0       0.00      0.00      0.00        30
#
#     accuracy                           0.57      2004
#    macro avg       0.47      0.46      0.45      2004
# weighted avg       0.55      0.57      0.55      2004
#
# Roc Auc: 0.8825356801612171
# tabpfn PERFORMANCE FOR CONTROL
# Accuracy: 0.12284482758620689
# Balanced Accuracy: 0.3142452699371379
# Random Balanced Accuracy: 0.2520787586004977
#
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       0.97      0.09      0.16       320
#          1.0       0.12      0.05      0.07        61
#          2.0       0.11      0.26      0.15        76
#          3.0       0.03      0.86      0.07         7
#          4.0       0.00      0.00      0.00         0
#
#     accuracy                           0.12       464
#    macro avg       0.25      0.25      0.09       464
# weighted avg       0.70      0.12      0.15       464
#
# Roc Auc: 0.6081797202499728
# CUDA memory cleared and model deleted.
# LGBM PERFORMANCE
# Accuracy: 0.5404191616766467
# Balanced Accuracy: 0.42777497758311284
# Random Balanced Accuracy: 0.17430258322136535
#
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       0.68      0.57      0.62       204
#          1.0       0.39      0.19      0.25       226
#          2.0       0.49      0.67      0.57       587
#          3.0       0.50      0.46      0.48       546
#          4.0       0.67      0.68      0.67       411
#          5.0       0.00      0.00      0.00        30
#
#     accuracy                           0.54      2004
#    macro avg       0.45      0.43      0.43      2004
# weighted avg       0.53      0.54      0.53      2004
#
# Roc Auc: 0.839059214373625
# LGBM PERFORMANCE FOR CONTROL
# Accuracy: 0.07327586206896551
# Balanced Accuracy: 0.23965992080611365
# Random Balanced Accuracy: 0.1951215059260733
#
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       1.00      0.04      0.08       320
#          1.0       0.07      0.02      0.03        61
#          2.0       0.08      0.18      0.11        76
#          3.0       0.03      0.71      0.05         7
#          4.0       0.00      0.00      0.00         0
#
#     accuracy                           0.07       464
#    macro avg       0.24      0.19      0.06       464
# weighted avg       0.71      0.07      0.08       464
#
# Roc Auc: 0.5696926309245812
# CUDA memory cleared and model deleted.
#
# Fold 3
# RANDOM PERFORMANCE
# Accuracy: 0.17597208374875373
# Balanced Accuracy: 0.18156492652824321
# Random Balanced Accuracy: 0.18894768148012264
#
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       0.12      0.19      0.15       205
#          1.0       0.12      0.18      0.15       226
#          2.0       0.31      0.18      0.23       587
#          3.0       0.24      0.15      0.18       545
#          4.0       0.23      0.20      0.21       413
#          5.0       0.02      0.20      0.03        30
#
#     accuracy                           0.18      2006
#    macro avg       0.17      0.18      0.16      2006
# weighted avg       0.23      0.18      0.19      2006
#
# Roc Auc: 0.5028699446727237
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# MLP PERFORMANCE
# Accuracy: 0.540877367896311
# Balanced Accuracy: 0.43440350946305073
# Random Balanced Accuracy: 0.17725922215799197
#
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       0.57      0.78      0.66       205
#          1.0       0.39      0.07      0.12       226
#          2.0       0.52      0.73      0.60       587
#          3.0       0.49      0.42      0.46       545
#          4.0       0.65      0.61      0.62       413
#          5.0       0.00      0.00      0.00        30
#
#     accuracy                           0.54      2006
#    macro avg       0.44      0.43      0.41      2006
# weighted avg       0.52      0.54      0.51      2006
#
# Roc Auc: 0.8673512345238913
# MLP PERFORMANCE FOR CONTROL
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Accuracy: 0.10775862068965517
# Balanced Accuracy: 0.22725977982867002
# Random Balanced Accuracy: 0.20603394132886713
#
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       1.00      0.08      0.16       320
#          1.0       0.20      0.02      0.03        61
#          2.0       0.08      0.24      0.11        76
#          3.0       0.03      0.57      0.05         7
#          4.0       0.00      0.00      0.00         0
#
#     accuracy                           0.11       464
#    macro avg       0.26      0.18      0.07       464
# weighted avg       0.73      0.11      0.13       464
#
# Roc Auc: 0.5673501325792438
# CUDA memory cleared and model deleted.
# tabpfn PERFORMANCE
# Accuracy: 0.5613160518444666
# Balanced Accuracy: 0.44634791056885187
# Random Balanced Accuracy: 0.166223318908399
#
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       0.59      0.62      0.60       205
#          1.0       0.38      0.21      0.27       226
#          2.0       0.56      0.65      0.60       587
#          3.0       0.51      0.56      0.53       545
#          4.0       0.71      0.64      0.67       413
#          5.0       0.00      0.00      0.00        30
#
#     accuracy                           0.56      2006
#    macro avg       0.46      0.45      0.45      2006
# weighted avg       0.55      0.56      0.55      2006
#
# Roc Auc: 0.8821523224738294
# tabpfn PERFORMANCE FOR CONTROL
# Accuracy: 0.10344827586206896
# Balanced Accuracy: 0.29054690388882043
# Random Balanced Accuracy: 0.22816406103341874
#
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       0.96      0.08      0.14       320
#          1.0       0.05      0.02      0.02        61
#          2.0       0.08      0.21      0.12        76
#          3.0       0.03      0.86      0.07         7
#          4.0       0.00      0.00      0.00         0
#
#     accuracy                           0.10       464
#    macro avg       0.23      0.23      0.07       464
# weighted avg       0.68      0.10      0.12       464
#
# Roc Auc: 0.5992295633610892
# CUDA memory cleared and model deleted.
# LGBM PERFORMANCE
# Accuracy: 0.5358923230309073
# Balanced Accuracy: 0.4256817261142751
# Random Balanced Accuracy: 0.165485132791611
#
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       0.60      0.60      0.60       205
#          1.0       0.41      0.16      0.23       226
#          2.0       0.50      0.64      0.56       587
#          3.0       0.49      0.48      0.48       545
#          4.0       0.66      0.68      0.67       413
#          5.0       0.00      0.00      0.00        30
#
#     accuracy                           0.54      2006
#    macro avg       0.44      0.43      0.42      2006
# weighted avg       0.52      0.54      0.52      2006
#
# Roc Auc: 0.848166903972006
# LGBM PERFORMANCE FOR CONTROL
# Accuracy: 0.08836206896551724
# Balanced Accuracy: 0.25435267857142857
# Random Balanced Accuracy: 0.203714884268419
#
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       1.00      0.05      0.10       320
#          1.0       0.00      0.00      0.00        61
#          2.0       0.11      0.25      0.16        76
#          3.0       0.03      0.71      0.06         7
#          4.0       0.00      0.00      0.00         0
#
#     accuracy                           0.09       464
#    macro avg       0.23      0.20      0.06       464
# weighted avg       0.71      0.09      0.10       464
#
# Roc Auc: 0.5750938175546949
# CUDA memory cleared and model deleted.
#
# Fold 4
# RANDOM PERFORMANCE
# Accuracy: 0.16516966067864272
# Balanced Accuracy: 0.165222248291506
# Random Balanced Accuracy: 0.17159237842346065
#
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       0.11      0.19      0.14       205
#          1.0       0.13      0.21      0.16       225
#          2.0       0.29      0.15      0.20       587
#          3.0       0.29      0.18      0.23       545
#          4.0       0.16      0.13      0.14       412
#          5.0       0.01      0.13      0.02        30
#
#     accuracy                           0.17      2004
#    macro avg       0.17      0.17      0.15      2004
# weighted avg       0.22      0.17      0.18      2004
#
# Roc Auc: 0.5041793523971312
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# MLP PERFORMANCE
# Accuracy: 0.5409181636726547
# Balanced Accuracy: 0.4443526274451193
# Random Balanced Accuracy: 0.17791603488186714
#
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       0.63      0.68      0.66       205
#          1.0       0.36      0.20      0.25       225
#          2.0       0.52      0.52      0.52       587
#          3.0       0.48      0.54      0.51       545
#          4.0       0.66      0.74      0.69       412
#          5.0       0.00      0.00      0.00        30
#
#     accuracy                           0.54      2004
#    macro avg       0.44      0.44      0.44      2004
# weighted avg       0.52      0.54      0.53      2004
#
# Roc Auc: 0.8582969704690416
# MLP PERFORMANCE FOR CONTROL
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Accuracy: 0.0625
# Balanced Accuracy: 0.18577129298656475
# Random Balanced Accuracy: 0.2093370739977506
#
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       1.00      0.05      0.10       320
#          1.0       0.04      0.02      0.02        61
#          2.0       0.05      0.11      0.07        76
#          3.0       0.02      0.57      0.04         7
#          4.0       0.00      0.00      0.00         0
#
#     accuracy                           0.06       464
#    macro avg       0.22      0.15      0.05       464
# weighted avg       0.70      0.06      0.08       464
#
# Roc Auc: 0.5042314486328384
# CUDA memory cleared and model deleted.
# tabpfn PERFORMANCE
# Accuracy: 0.5703592814371258
# Balanced Accuracy: 0.460197939910495
# Random Balanced Accuracy: 0.1639524006992452
#
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       0.68      0.68      0.68       205
#          1.0       0.38      0.22      0.28       225
#          2.0       0.54      0.65      0.59       587
#          3.0       0.52      0.54      0.53       545
#          4.0       0.72      0.67      0.69       412
#          5.0       0.00      0.00      0.00        30
#
#     accuracy                           0.57      2004
#    macro avg       0.47      0.46      0.46      2004
# weighted avg       0.56      0.57      0.56      2004
#
# Roc Auc: 0.8754439315525958
# tabpfn PERFORMANCE FOR CONTROL

# %%
for percentage, models in percentage_dict.items():
    print(f"\nResults for {percentage*100:.0f}% of the data:")
    for model, results in models.items():
        print(f"  {model} - Results: {results['results']}")
        if 'results_eval' in results:
            print(f"  {model} - Evaluation Results: {results['results_eval']}")

# %%
""" #load a model
import pickle
import os
save_dir = "../98_models/"
with open(os.path.join(save_dir, "tabpfn.pkl"), "rb") as f:
    model = pickle.load(f)
    original_classes = np.unique(y_control)
    results, balanced_accuracy = predict_and_evaluate(model, X_control, y_control, original_classes=original_classes)
    print_model_performance(results) """
# Out:
# Accuracy: 0.6896551724137931
# Balanced Accuracy: 0.25
# Random Balanced Accuracy: 0.25
#
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       0.69      1.00      0.82       320
#          1.0       0.00      0.00      0.00        61
#          2.0       0.00      0.00      0.00        76
#          3.0       0.00      0.00      0.00         7
#
#     accuracy                           0.69       464
#    macro avg       0.17      0.25      0.20       464
# weighted avg       0.48      0.69      0.56       464
#
# Roc Auc: 0.7635391042080081
# Accuracy: 0.6896551724137931
# Balanced Accuracy: 0.25
# Random Balanced Accuracy: 0.25
#
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       0.69      1.00      0.82       320
#          1.0       0.00      0.00      0.00        61
#          2.0       0.00      0.00      0.00        76
#          3.0       0.00      0.00      0.00         7
#
#     accuracy                           0.69       464
#    macro avg       0.17      0.25      0.20       464
# weighted avg       0.48      0.69      0.56       464
#
# Roc Auc: 0.7635391042080081

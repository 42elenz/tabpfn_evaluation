# %%
from sklearn.metrics import accuracy_score, roc_auc_score
from sklearn.model_selection import train_test_split, StratifiedKFold
from tabpfn import TabPFNClassifier
import pandas as pd
import os
from tensorflow.keras.models import Sequential
from tensorflow.keras import layers
from scikeras.wrappers import KerasClassifier
import numpy as np
from sklearn.metrics import balanced_accuracy_score, classification_report
import lightgbm as lgb
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import label_binarize
import gc
import torch
from tensorflow.keras import backend as K
import  statsmodels.api as sm
from sklearn.decomposition import PCA
import warnings
warnings.filterwarnings('ignore')

# %%
def create_mlp_model(input_shape, num_classes):
    model = Sequential([
        layers.Dense(1024, activation="relu", input_shape=(input_shape,)),
        layers.Dropout(0.3),
        layers.Dense(512, activation="relu"),
        layers.Dropout(0.3),
        layers.Dense(256, activation="relu"),
        layers.Dropout(0.3),
        layers.Dense(128, activation="relu"),
        layers.Dropout(0.3),
        layers.Dense(num_classes, activation="softmax")
    ])
    model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
    return model

def create_cnn_model(input_shape, num_classes):
    model = Sequential([
        layers.Conv1D(128, kernel_size=3, activation='relu', input_shape=(input_shape[0], 1)),
        layers.MaxPooling1D(pool_size=2),
        layers.Conv1D(64, kernel_size=3, activation='relu'),
        layers.MaxPooling1D(pool_size=2),
        layers.Flatten(),
        layers.Dense(128, activation='relu'),
        layers.Dropout(0.3),
        layers.Dense(num_classes, activation='softmax')
    ])
    model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
    return model

# %%
def clean_up_cuda(model):
    # Delete the Keras model
    K.clear_session()
    del model
    
    # Run garbage collection
    gc.collect()
    
    # Free CUDA memory
    if torch.cuda.is_available():
        torch.cuda.empty_cache()
        torch.cuda.ipc_collect()
    
    print("CUDA memory cleared and model deleted.")

# %%
def feature_extraction_best_corr_with_target(X,X_val, X_control, y, threshold=0.6, df_columns=None, number_of_features=40):
    if isinstance(X, np.ndarray):
        X = pd.DataFrame(X)
        if df_columns is not None:
            X.columns = df_columns
    if isinstance(y, np.ndarray):
        y = pd.Series(y)
    if isinstance(X_val, np.ndarray):
        X_val = pd.DataFrame(X_val)
        if df_columns is not None:
            X_val.columns = df_columns
    if isinstance(X_control, np.ndarray):
        X_control = pd.DataFrame(X_control)
        if df_columns is not None:
            X_control.columns = df_columns
    correlation_matrix = X.corrwith(y).abs()
    to_keep = correlation_matrix.sort_values(ascending=False).head(number_of_features).index
    X = X[to_keep]
    X_val = X_val[to_keep]
    X_control = X_control[to_keep]
    X_ret = X.to_numpy().copy()
    X_val_ret = X_val.to_numpy().copy()
    X_control_ret = X_control.to_numpy().copy()
    return X_ret, X_val_ret, X_control_ret


def feature_extraction_with_Pearson(X, X_val, X_control, y, threshold=0.6, df_columns=None):
    if isinstance(X, np.ndarray):
        X = pd.DataFrame(X)
        if df_columns is not None:
            X.columns = df_columns
    if isinstance(X_val, np.ndarray):
        X_val = pd.DataFrame(X_val)
        if df_columns is not None:
            X_val.columns = df_columns
    if isinstance(X_control, np.ndarray):
        X_control = pd.DataFrame(X_control)
        if df_columns is not None:
            X_control.columns = df_columns
    correlation_matrix = X.corr().abs()
    upper = correlation_matrix.where(np.triu(np.ones(correlation_matrix.shape), k=1).astype(bool))
    to_drop = [column for column in upper.columns if any(upper[column] > threshold)]
    X = X.drop(columns=to_drop)
    X_val = X_val.drop(columns=to_drop)
    X_control = X_control.drop(columns=to_drop)
    X_ret = X.to_numpy().copy()
    X_val_ret = X_val.to_numpy().copy()
    X_control_ret = X_control.to_numpy().copy()
    return X_ret, X_val_ret, X_control_ret

def feature_extration_with_PCA(X, X_val, X_control, n_components):
    pca = PCA(n_components=n_components)
    X_pca = pca.fit_transform(X)
    X_val_pca = pca.transform(X_val)
    X_control_pca = pca.transform(X_control)
    return X_pca, X_val_pca, X_control_pca

def feature_extration_with_BE(X, X_val, X_control, y, significance_level=0.05, df_columns=None):
    if isinstance(X, np.ndarray):
        X = pd.DataFrame(X)
        if df_columns is not None:
            X.columns = df_columns
    if isinstance(X_val, np.ndarray):
        X_val = pd.DataFrame(X_val)
        if df_columns is not None:
            X_val.columns = df_columns
    if isinstance(X_control, np.ndarray):
        X_control = pd.DataFrame(X_control)
        if df_columns is not None:
            X_control.columns = df_columns
    # Add constant for intercept
    X = X.reset_index(drop=True)
    y = y.reset_index(drop=True)
    X = sm.add_constant(X)

    while True:
        # Fit the OLS model
        model = sm.OLS(y, X).fit()
        
        # Get the p-values for each feature
        p_values = model.pvalues
        
        # Find the feature with the highest p-value
        max_p_value = p_values.max()
        
        if max_p_value > significance_level:
            # Remove the feature with the highest p-value
            feature_to_remove = p_values.idxmax()
            print(f"Removing {feature_to_remove} with p-value {max_p_value:.4f}")
            X = X.drop(columns=[feature_to_remove])
            X_val = X_val.drop(columns=[feature_to_remove])
            X_control = X_control.drop(columns=[feature_to_remove])
        else:
            break
        print("Final Feature lengthe: ", len(X.columns))
    # Return the final selected feature set (excluding the intercept)
    X_ret = X.drop(columns=['const']).to_numpy().copy()
    X_val_ret = X_val.to_numpy().copy()
    X_control_ret = X_control.to_numpy().copy()
    return X_ret, X_val_ret, X_control_ret

# %%
# Example usage
def print_model_performance(results):
    """
    Print model performance metrics
    
    Parameters:
    results (dict): Performance metrics from evaluate_model_performance()
    """
    for metric, value in results.items():
        if metric == 'classification_report':
            print("\nClassification Report:")
            print(value)
        else:
            print(f"{metric.replace('_', ' ').title()}: {value}")
def aggregate_cv_metrics_and_print(all_results, model_name, tag="Validation"):
    """
    Aggregate cross-validation metrics
    
    Parameters:
    all_results (list): List of results dictionaries from each fold
    
    Returns:
    dict: Aggregated metrics with means and standard deviations
    """
    # Initialize aggregation dictionary
    aggregated = {
        'accuracy': [],
        'balanced_accuracy': [],
        'random_balanced_accuracy': [],
        'roc_auc': []
    }
    
    # Collect metrics from each fold
    for result in all_results:
        aggregated['accuracy'].append(result['accuracy'])
        aggregated['balanced_accuracy'].append(result['balanced_accuracy'])
        aggregated['random_balanced_accuracy'].append(result['random_balanced_accuracy'])
        aggregated['roc_auc'].append(result['roc_auc'])
    # Compute mean and standard deviation
    summary = {
        'mean_accuracy': np.mean(aggregated['accuracy']),
        'std_accuracy': np.std(aggregated['accuracy']),
        'mean_balanced_accuracy': np.mean(aggregated['balanced_accuracy']),
        'std_balanced_accuracy': np.std(aggregated['balanced_accuracy']),
        'mean_random_balanced_accuracy': np.mean(aggregated['random_balanced_accuracy']),
        'std_random_balanced_accuracy': np.std(aggregated['random_balanced_accuracy']),
        'mean_roc_auc': np.mean(aggregated['roc_auc']),
        'std_roc_auc': np.std(aggregated['roc_auc'])
    }
    
    print(f"\n {model_name} Classifier Performance {tag}:")
    print_model_performance(summary)
    return summary

# %%
mri_table = "aparc.thickness_aseg.volume_aparc.volume.csv"
df = pd.read_csv(f"/zi/home/esra.lenz/Documents/00_HITKIP/09_TABPFN/00_NAKO/00_data/deconfounded_but_age/{mri_table}")
label_df = pd.read_csv("/zi/home/esra.lenz/Documents/00_HITKIP/09_TABPFN/00_NAKO/00_data/age_label/all_ages_all_ids_healthy.csv")
n_splits = 5
label_col= "label_age_group"

label_df = label_df[['ID', 'label_age_group']]
merged_df = pd.merge(df, label_df, on='ID', how='inner')
merged_df.dropna(inplace=True)
df_sampled, _ = train_test_split(merged_df, train_size=10000, stratify=merged_df["label_age_group"], random_state=42)
df_sampled["label_age_group"].value_counts()
# Out:
# label_age_group
# 2.0    2931
# 3.0    2722
# 4.0    2056
# 1.0    1124
# 0.0    1020
# 5.0     147
# Name: count, dtype: int64

# %%
df_control = pd.read_csv("/zi/home/esra.lenz/Documents/00_HITKIP/09_TABPFN/01_Validation_data_set/00_data/final_folder/aparc.thickness_aparc.volume_aseg.volume.csv")
label_df_control = pd.read_csv("/zi/home/esra.lenz/Documents/00_HITKIP/09_TABPFN/01_Validation_data_set/00_data/final_folder/aparc.thickness_aparc.volume_aseg.volume_label.csv")

label_df_control = label_df_control[['ID', 'label_age_group']]
df_control = df_control[df.columns]
merged_df_control = pd.merge(df_control, label_df_control, on='ID', how='inner')
merged_df_control.dropna(inplace=True)

X_control_source = merged_df_control.drop(["ID", "label_age_group"], axis=1)
y_control_source = merged_df_control["label_age_group"]

merged_df_control["label_age_group"].value_counts()
# Out:
# label_age_group
# 0.0    320
# 2.0     76
# 1.0     61
# 3.0      7
# Name: count, dtype: int64

# %%
def evaluate_model_performance_train(y_test, y_pred, y_pred_proba, y_val_bin=None):
    # Compute basic metrics
    acc = accuracy_score(y_test, y_pred)
    balanced_acc = balanced_accuracy_score(y_test, y_pred)
    report = classification_report(y_test, y_pred)
    
    # Random comparison
    n_classes = len(np.unique(y_test))
    random_y_test = np.random.randint(0, n_classes, size=y_test.shape)
    random_balanced_acc = balanced_accuracy_score(random_y_test, y_pred)
    
    # ROC AUC (if probabilities provided)
    if y_val_bin is not None:
        y_test = y_val_bin
    auc = roc_auc_score(y_test, y_pred_proba, multi_class='ovr', average='macro')
    
    # Prepare results
    results = {
        'accuracy': acc,
        'balanced_accuracy': balanced_acc,
        'random_balanced_accuracy': random_balanced_acc,
        'classification_report': report
    }
    
    if auc is not None:
        results['roc_auc'] = auc
    
    return results, balanced_acc

# %%
def predict_and_evaluate(model, X_val, y_val, original_classes=None, multi_class=False):
    if multi_class:
        y_pred_proba = model.predict(X_val)
        y_pred = np.argmax(y_pred_proba, axis=1)
        #print(y_pred)
    else:
        y_pred_proba = model.predict_proba(X_val)
        y_pred = model.predict(X_val)
        #print(y_pred)
    
    # Get unique classes present in validation data
    present_classes = np.unique(y_val)
    
    # Get the indices of these classes in the original prediction probabilities
    class_indices = [np.where(original_classes == cls)[0][0] for cls in present_classes]
    
    # Select only the probability columns for present classes
    y_pred_proba_filtered = y_pred_proba[:, class_indices]
    
    # Binarize the true labels using only the present classes
    y_val_bin = label_binarize(y_val, classes=present_classes)

    results, balanced_acc = evaluate_model_performance_train(y_val, y_pred, y_pred_proba_filtered, y_val_bin)
    print_model_performance(results)
    return results, balanced_acc

# %%
percentage_of_the_data = [0.01, 0.05, 0.1, 0.25, 0.5, 0.7, 0.9, 1]
data = []
percentage_dict = {}
best_mse_mlp = float('inf')
best_mse_lgb = float('inf')
best_mse_tab = float('inf')
deconfounding_strategies = ["BE", "Correlation_in_Feature","Correlation_with_target", "PCA","Nothing"]
for percentage in percentage_of_the_data:
        percentage_dict[percentage] = {}
        for deconfounding_strategy in deconfounding_strategies:
                print(f"\n=== Deconfounding Strategy: {deconfounding_strategy} ===")
                if percentage == 1:
                        print(f"\n #### TRAINING WITH {percentage} OF THE DATA ####")
                        df_sampled_subset = df_sampled
                else:
                        print(f"\n #### TRAINING WITH {percentage} OF THE DATA ####")
                        df_sampled_subset, _ = train_test_split(
                        df_sampled,
                        train_size=percentage,  # Use train_size to get desired percentage
                        stratify=df_sampled["label_age_group"],
                        random_state=42
                        )

                y = df_sampled_subset["label_age_group"]
                X = df_sampled_subset.drop(["ID", "label_age_group"], axis=1)

                print(f"Training data shape: {X.shape}, length of y: {len(y)}")
                print(f"Training data class distribution: {y.value_counts()}")
                

                skf = StratifiedKFold(n_splits=n_splits, shuffle=True, random_state=42)
                cv_results = {
                        'accuracy': [],
                        'balanced_accuracy': [],
                        'roc_auc': [],
                        'classification_reports': []
                }

                tab_pfn = TabPFNClassifier()

                tabpfn_results = []
                tabpfn_results_eval = []
                lgb_results = []
                lgb_results_eval = []
                random_results = []
                mlp_results = []
                mlp_results_eval = []
                cnn_results = []
                cnn_results_eval = []
                model_dict = {}
                model_results = {}


                best_balanced_accuracy_mlp = 0
                best_balanced_accuracy_tabpfn = 0
                best_balanced_accuracy_lgb = 0
                for fold, (train_index, val_index) in enumerate(skf.split(X, y), 1):
                        unique_classes = np.unique(y)
                        missing_classes = [cls for cls in unique_classes if cls not in y.iloc[val_index]]
                        for cls in missing_classes:
                                cls_indices = np.where(y == cls)[0]  # Get all indices of the missing class
                                # Check if removing a sample would leave train set empty for the class
                                train_cls_indices = np.intersect1d(cls_indices, train_index)

                                if len(train_cls_indices) <= 1:
                                        # If moving the last one, instead take a duplicate from the whole y array
                                        cls_idx_to_move = np.random.choice(cls_indices, 1)[0]
                                else:
                                        cls_idx_to_move = np.random.choice(train_cls_indices, 1)[0]
                                # Add to validation set
                                val_index = np.append(val_index, cls_idx_to_move)
                                # Remove only if it's not the last one in train
                                if len(train_cls_indices) > 1:
                                        train_index = np.setdiff1d(train_index, cls_idx_to_move)
                        print(f"\nFold {fold}")
                        X_train, X_test = X.iloc[train_index], X.iloc[val_index]
                        y_train, y_test = y.iloc[train_index], y.iloc[val_index]
                        X_control = X_control_source.copy()
                        y_control = y_control_source.copy()

                        #scaler = MinMaxScaler()
                        df_columns = X.columns
                        scaler = StandardScaler()
                        X_train_scaled = scaler.fit_transform(X_train)
                        X_test_scaled = scaler.transform(X_test)
                        X_control_scaled = scaler.fit_transform(X_control)
                        if deconfounding_strategy == "BE":
                                X_train, X_test, X_control = feature_extration_with_BE(X_train_scaled, X_test_scaled, X_control_scaled, y_train, df_columns=df_columns)
                        elif deconfounding_strategy == "PCA":
                                X_train, X_test, X_control= feature_extration_with_PCA(X_train_scaled, X_test_scaled, X_control_scaled,  n_components=50)
                        elif deconfounding_strategy == "Correlation_in_Feature":
                                X_train, X_test, X_control = feature_extraction_with_Pearson(X_train_scaled, X_test_scaled, X_control_scaled, y_train, threshold=0.6, df_columns=df_columns)
                        elif deconfounding_strategy == "Correlation_with_target":
                                X_train, X_test, X_control = feature_extraction_best_corr_with_target(X_train_scaled, X_test_scaled, X_control_scaled, y_train, threshold=0.6, df_columns=df_columns)
                        elif deconfounding_strategy == "Nothing":
                                X_train, X_test, X_control = X_train_scaled, X_test_scaled, X_control_scaled
                        n_classes = len(np.unique(y_test))
                        random_y_test = np.random.randint(0, n_classes, size=y_test.shape)
                        random_y_pred_proba = np.random.rand(len(y_test), n_classes)
                        random_y_pred_proba /= random_y_pred_proba.sum(axis=1)[:, np.newaxis]
                        results, balanced_accuracy  = evaluate_model_performance_train(y_test, random_y_test, random_y_pred_proba)
                        print("RANDOM PERFORMANCE")
                        print_model_performance(results)
                        random_results.append(results)

                        cnnclf = create_cnn_model(input_shape=(X_train.shape[1], 1), num_classes=len(y.unique()))
                        X_train_cnn = X_train.reshape(X_train.shape[0], X_train.shape[1], 1)
                        X_test_cnn = X_test.reshape(X_test.shape[0], X_test.shape[1], 1)
                        X_control_cnn = X_control.reshape(X_control.shape[0], X_control.shape[1], 1)
                        cnnclf.fit(X_train_cnn, pd.get_dummies(y_train), epochs=10, batch_size=32, verbose=0)
                        y_pred_proba = cnnclf.predict(X_test_cnn)
                        y_pred = np.argmax(y_pred_proba, axis=1)
                        results, balanced_accuracy = evaluate_model_performance_train(y_test, y_pred, y_pred_proba)
                        print("CNN PERFORMANCE")
                        print_model_performance(results)
                        cnn_results.append(results)
                        print("CNN PERFORMANCE FOR CONTROL")
                        results, balanced_accuracy = predict_and_evaluate(cnnclf, X_control_cnn, y_control, original_classes = np.unique(y_train), multi_class=True)
                        cnn_results_eval.append(results)
                        clean_up_cuda(cnnclf)

                        mlpclf = create_mlp_model(input_shape=X_train.shape[1], num_classes=len(y.unique()))
                        mlpclf.fit(X_train, pd.get_dummies(y_train), epochs=10, batch_size=32, verbose=0)
                        y_pred_proba = mlpclf.predict(X_test)
                        y_pred = np.argmax(y_pred_proba, axis=1)
                        results, balanced_accuracy = evaluate_model_performance_train(y_test, y_pred, y_pred_proba)
                        print("MLP PERFORMANCE")
                        print_model_performance(results)
                        mlp_results.append(results)
                        #model_dict["mlp"] = mlpclf
                        print("MLP PERFORMANCE FOR CONTROL")
                        results, balanced_accuracy = predict_and_evaluate(mlpclf, X_control, y_control, original_classes = np.unique(y_train), multi_class=True)
                        mlp_results_eval.append(results)
                        if balanced_accuracy > best_balanced_accuracy_mlp:
                                best_balanced_accuracy_mlp = balanced_accuracy
                                model_dict["mlp"] = mlpclf
                        clean_up_cuda(mlpclf)

                        tabclf = TabPFNClassifier()
                        tabclf.fit(X_train, y_train)
                        y_pred_proba = tabclf.predict_proba(X_test)
                        y_pred = tabclf.predict(X_test)
                        results, balanced_accuracy = evaluate_model_performance_train(y_test, y_pred, y_pred_proba)
                        print("tabpfn PERFORMANCE")
                        print_model_performance(results)
                        tabpfn_results.append(results)
                        #model_dict["tabpfn"] = tabclf
                        original_classes = tabclf.classes_
                        print("tabpfn PERFORMANCE FOR CONTROL")
                        results, balanced_accuracy = predict_and_evaluate(tabclf, X_control, y_control, original_classes=original_classes)
                        tabpfn_results_eval.append(results)
                        if balanced_accuracy > best_balanced_accuracy_tabpfn:
                                best_balanced_accuracy_tabpfn = balanced_accuracy
                                model_dict["tabpfn"] = tabclf
                        clean_up_cuda(tabclf)
                        
                        lgb_train = lgb.Dataset(X_train, label=y_train)
                        lgb_eval = lgb.Dataset(X_test, label=y_test, reference=lgb_train)
                        params = {
                        'objective': 'multiclass',
                        'num_class': len(y.unique()),
                        'metric': 'multi_logloss',
                        'num_leaves': 31,
                        'learning_rate': 0.05,
                        'feature_fraction': 0.9,
                        'seed': 42,
                        'verbose': -1
                        }
                        lgbclf = lgb.train(params, lgb_train, valid_sets=[lgb_train, lgb_eval], num_boost_round=1000)
                        y_pred_proba = lgbclf.predict(X_test)
                        y_pred = np.argmax(y_pred_proba, axis=1)
                        results, balanced_accuracy = evaluate_model_performance_train(y_test, y_pred, y_pred_proba)
                        print("LGBM PERFORMANCE")
                        print_model_performance(results)
                        lgb_results.append(results)
                        print("LGBM PERFORMANCE FOR CONTROL")
                        results, balanced_accuracy = predict_and_evaluate(lgbclf, X_control, y_control, original_classes=original_classes, multi_class=True)
                        lgb_results_eval.append(results)
                        if balanced_accuracy > best_balanced_accuracy_lgb:
                                best_balanced_accuracy_lgb = balanced_accuracy
                                model_dict["lgb"] = lgbclf
                        clean_up_cuda(lgbclf)

                random_summary = aggregate_cv_metrics_and_print(random_results, "Random")
                tabpfn_summary = aggregate_cv_metrics_and_print(tabpfn_results, "TabPFN")
                lgb_summary = aggregate_cv_metrics_and_print(lgb_results, "LGBM")
                mlp_summary = aggregate_cv_metrics_and_print(mlp_results, "MLP")
                cnn_summary = aggregate_cv_metrics_and_print(cnn_results, "CNN")

                tabpfn_eval_summary = aggregate_cv_metrics_and_print(tabpfn_results_eval, "TabPFN", "Control")
                lgb_eval_summary = aggregate_cv_metrics_and_print(lgb_results_eval, "LGBM", "Control")
                mlp_eval_summary = aggregate_cv_metrics_and_print(mlp_results_eval, "MLP", "Control")
                cnn_eval_summary = aggregate_cv_metrics_and_print(cnn_results_eval, "CNN", "Control")

                percentage_dict[percentage][deconfounding_strategy] = {
                "TabPFN": {
                        "results": tabpfn_summary,
                        "results_eval": tabpfn_eval_summary,
                        "cv_results": tabpfn_results,
                        "cv_results_eval": tabpfn_results_eval
                },
                "LGBM": {
                        "results": lgb_summary,
                        "results_eval": lgb_eval_summary,
                        "cv_results": lgb_results,
                        "cv_results_eval": lgb_results_eval
                },
                "Random": {
                        "results": random_summary,
                        "results_eval": random_summary,
                        "cv_results": random_results,
                        "cv_results_eval": random_results,

                },
                "MLP": {
                        "results": mlp_summary,
                        "results_eval": mlp_eval_summary,
                        "cv_results": mlp_results,
                        "cv_results_eval": mlp_results_eval
                },
                "CNN": {
                        "results": cnn_summary,
                        "results_eval": cnn_eval_summary,
                        "cv_results": cnn_results,
                        "cv_results_eval": cnn_results_eval
                }
        }
# Out:
# === Deconfounding Strategy: BE ===
#
#  #### TRAINING WITH 0.01 OF THE DATA ####
# Training data shape: (100, 192), length of y: 100
# Training data class distribution: label_age_group
# 2.0    29
# 3.0    27
# 4.0    21
# 1.0    11
# 0.0    10
# 5.0     2
# Name: count, dtype: int64
#
# Fold 1
# RANDOM PERFORMANCE
# Accuracy: 0.23076923076923078
# Balanced Accuracy: 0.30476190476190473
# Random Balanced Accuracy: 0.08095238095238096
#
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       0.00      0.00      0.00         3
#          1.0       0.00      0.00      0.00         3
#          2.0       0.33      0.14      0.20         7
#          3.0       0.50      0.29      0.36         7
#          4.0       0.67      0.40      0.50         5
#          5.0       0.17      1.00      0.29         1
#
#     accuracy                           0.23        26
#    macro avg       0.28      0.30      0.22        26
# weighted avg       0.36      0.23      0.26        26
#
# Roc Auc: 0.6385674330754423
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# CNN PERFORMANCE
# Accuracy: 0.5
# Balanced Accuracy: 0.38888888888888884
# Random Balanced Accuracy: 0.15
#
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       1.00      0.33      0.50         3
#          1.0       0.00      0.00      0.00         3
#          2.0       0.50      0.57      0.53         7
#          3.0       0.38      0.43      0.40         7
#          4.0       0.56      1.00      0.71         5
#          5.0       0.00      0.00      0.00         1
#
#     accuracy                           0.50        26
#    macro avg       0.41      0.39      0.36        26
# weighted avg       0.46      0.50      0.45        26
#
# Roc Auc: 0.6257680432966474
# CNN PERFORMANCE FOR CONTROL
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Accuracy: 0.05172413793103448
# Balanced Accuracy: 0.04634046052631579
# Random Balanced Accuracy: 0.11614349373716724
#
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       1.00      0.04      0.08       320
#          1.0       0.00      0.00      0.00        61
#          2.0       0.10      0.14      0.12        76
#          3.0       0.00      0.00      0.00         7
#          4.0       0.00      0.00      0.00         0
#
#     accuracy                           0.05       464
#    macro avg       0.22      0.04      0.04       464
# weighted avg       0.71      0.05      0.07       464
#
# Roc Auc: 0.48956837791406227
# CUDA memory cleared and model deleted.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# MLP PERFORMANCE
# Accuracy: 0.34615384615384615
# Balanced Accuracy: 0.2841269841269841
# Random Balanced Accuracy: 0.19444444444444445
#
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       0.50      0.33      0.40         3
#          1.0       0.00      0.00      0.00         3
#          2.0       0.17      0.14      0.15         7
#          3.0       0.30      0.43      0.35         7
#          4.0       0.57      0.80      0.67         5
#          5.0       0.00      0.00      0.00         1
#
#     accuracy                           0.35        26
#    macro avg       0.26      0.28      0.26        26
# weighted avg       0.29      0.35      0.31        26
#
# Roc Auc: 0.5758156260215757
# MLP PERFORMANCE FOR CONTROL
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Accuracy: 0.14439655172413793
# Balanced Accuracy: 0.14998237781954887
# Random Balanced Accuracy: 0.17668850252691715
#
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       1.00      0.13      0.23       320
#          1.0       0.00      0.00      0.00        61
#          2.0       0.22      0.33      0.26        76
#          3.0       0.01      0.14      0.01         7
#          4.0       0.00      0.00      0.00         0
#
#     accuracy                           0.14       464
#    macro avg       0.24      0.12      0.10       464
# weighted avg       0.73      0.14      0.20       464
#
# Roc Auc: 0.545596528100618
# CUDA memory cleared and model deleted.
# tabpfn PERFORMANCE
# Accuracy: 0.5769230769230769
# Balanced Accuracy: 0.48095238095238096
# Random Balanced Accuracy: 0.2708333333333333
#
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       1.00      0.67      0.80         3
#          1.0       1.00      0.33      0.50         3
#          2.0       0.47      1.00      0.64         7
#          3.0       0.50      0.29      0.36         7
#          4.0       0.75      0.60      0.67         5
#          5.0       0.00      0.00      0.00         1
#
#     accuracy                           0.58        26
#    macro avg       0.62      0.48      0.49        26
# weighted avg       0.64      0.58      0.55        26
#
# Roc Auc: 0.8484544695071011
# tabpfn PERFORMANCE FOR CONTROL
# Accuracy: 0.14655172413793102
# Balanced Accuracy: 0.2588988159435474
# Random Balanced Accuracy: 0.18775024141252455
#
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       0.77      0.08      0.15       320
#          1.0       0.18      0.11      0.14        61
#          2.0       0.22      0.41      0.28        76
#          3.0       0.03      0.43      0.05         7
#          4.0       0.00      0.00      0.00         0
#
#     accuracy                           0.15       464
#    macro avg       0.24      0.21      0.13       464
# weighted avg       0.59      0.15      0.17       464
#
# Roc Auc: 0.5831823198109808
# CUDA memory cleared and model deleted.
# LGBM PERFORMANCE
# Accuracy: 0.34615384615384615
# Balanced Accuracy: 0.3190476190476191
# Random Balanced Accuracy: 0.03333333333333333
#
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       1.00      0.33      0.50         3
#          1.0       0.50      0.67      0.57         3
#          2.0       0.21      0.43      0.29         7
#          3.0       0.40      0.29      0.33         7
#          4.0       0.50      0.20      0.29         5
#          5.0       0.00      0.00      0.00         1
#
#     accuracy                           0.35        26
#    macro avg       0.44      0.32      0.33        26
# weighted avg       0.43      0.35      0.35        26
#
# Roc Auc: 0.7628731248410882
# LGBM PERFORMANCE FOR CONTROL
# Accuracy: 0.10344827586206896
# Balanced Accuracy: 0.1834216689264144
# Random Balanced Accuracy: 0.177083763541854
#
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       1.00      0.05      0.10       320
#          1.0       0.09      0.02      0.03        61
#          2.0       0.17      0.38      0.24        76
#          3.0       0.01      0.29      0.03         7
#          4.0       0.00      0.00      0.00         0
#          5.0       0.00      0.00      0.00         0
#
#     accuracy                           0.10       464
#    macro avg       0.21      0.12      0.06       464
# weighted avg       0.73      0.10      0.11       464
#
# Roc Auc: 0.5763287818358604
# CUDA memory cleared and model deleted.
#
# Fold 2
# RANDOM PERFORMANCE
# Accuracy: 0.15384615384615385
# Balanced Accuracy: 0.17777777777777778
# Random Balanced Accuracy: 0.023809523809523808
#
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       0.00      0.00      0.00         3
#          1.0       0.33      0.67      0.44         3
#          2.0       0.00      0.00      0.00         7
#          3.0       0.00      0.00      0.00         7
#          4.0       0.33      0.40      0.36         5
#          5.0       0.00      0.00      0.00         1
#
#     accuracy                           0.15        26
#    macro avg       0.11      0.18      0.13        26
# weighted avg       0.10      0.15      0.12        26
#
# Roc Auc: 0.4369082125603865
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# CNN PERFORMANCE
# Accuracy: 0.46153846153846156
# Balanced Accuracy: 0.3682539682539683
# Random Balanced Accuracy: 0.09722222222222221
#
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       0.50      0.67      0.57         3
#          1.0       0.00      0.00      0.00         3
#          2.0       0.36      0.71      0.48         7
#          3.0       0.60      0.43      0.50         7
#          4.0       0.67      0.40      0.50         5
#          5.0       0.00      0.00      0.00         1
#
#     accuracy                           0.46        26
#    macro avg       0.35      0.37      0.34        26
# weighted avg       0.44      0.46      0.42        26
#
# Roc Auc: 0.6863521121644691
# CNN PERFORMANCE FOR CONTROL
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Accuracy: 0.16163793103448276
# Balanced Accuracy: 0.22977975163318132
# Random Balanced Accuracy: 0.20354988478515254
#
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       1.00      0.06      0.12       320
#          1.0       1.00      0.02      0.03        61
#          2.0       0.18      0.70      0.29        76
#          3.0       0.01      0.14      0.02         7
#          4.0       0.00      0.00      0.00         0
#
#     accuracy                           0.16       464
#    macro avg       0.44      0.18      0.09       464
# weighted avg       0.85      0.16      0.13       464
#
# Roc Auc: 0.573950032467913
# CUDA memory cleared and model deleted.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# MLP PERFORMANCE
# Accuracy: 0.34615384615384615
# Balanced Accuracy: 0.3603174603174603
# Random Balanced Accuracy: 0.18055555555555555
#
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       0.43      1.00      0.60         3
#          1.0       0.20      0.33      0.25         3
#          2.0       0.25      0.14      0.18         7
#          3.0       0.33      0.29      0.31         7
#          4.0       0.50      0.40      0.44         5
#          5.0       0.00      0.00      0.00         1
#
#     accuracy                           0.35        26
#    macro avg       0.29      0.36      0.30        26
# weighted avg       0.33      0.35      0.32        26
#
# Roc Auc: 0.6197457411645054
# MLP PERFORMANCE FOR CONTROL
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Accuracy: 0.1939655172413793
# Balanced Accuracy: 0.26433511416861827
# Random Balanced Accuracy: 0.22407513479939
#
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       1.00      0.20      0.34       320
#          1.0       0.05      0.03      0.04        61
#          2.0       0.16      0.25      0.20        76
#          3.0       0.02      0.57      0.04         7
#          4.0       0.00      0.00      0.00         0
#
#     accuracy                           0.19       464
#    macro avg       0.25      0.21      0.12       464
# weighted avg       0.72      0.19      0.27       464
#
# Roc Auc: 0.5949161026821181
# CUDA memory cleared and model deleted.
# tabpfn PERFORMANCE
# Accuracy: 0.4230769230769231
# Balanced Accuracy: 0.3761904761904762
# Random Balanced Accuracy: 0.3
#
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       0.50      0.33      0.40         3
#          1.0       0.67      0.67      0.67         3
#          2.0       0.27      0.43      0.33         7
#          3.0       0.43      0.43      0.43         7
#          4.0       0.67      0.40      0.50         5
#          5.0       0.00      0.00      0.00         1
#
#     accuracy                           0.42        26
#    macro avg       0.42      0.38      0.39        26
# weighted avg       0.45      0.42      0.42        26
#
# Roc Auc: 0.8123562529512186
# tabpfn PERFORMANCE FOR CONTROL
# Accuracy: 0.0603448275862069
# Balanced Accuracy: 0.2581921953962776
# Random Balanced Accuracy: 0.2356001425620436
#
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       1.00      0.00      0.01       320
#          1.0       0.25      0.13      0.17        61
#          2.0       0.08      0.18      0.11        76
#          3.0       0.03      0.71      0.06         7
#          4.0       0.00      0.00      0.00         0
#
#     accuracy                           0.06       464
#    macro avg       0.27      0.21      0.07       464
# weighted avg       0.74      0.06      0.05       464
#
# Roc Auc: 0.5467239103648422
# CUDA memory cleared and model deleted.
# LGBM PERFORMANCE
# Accuracy: 0.46153846153846156
# Balanced Accuracy: 0.40952380952380957
# Random Balanced Accuracy: 0.35000000000000003
#
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       0.50      1.00      0.67         3
#          1.0       0.00      0.00      0.00         3
#          2.0       0.43      0.43      0.43         7
#          3.0       0.50      0.43      0.46         7
#          4.0       0.60      0.60      0.60         5
#          5.0       0.00      0.00      0.00         1
#
#     accuracy                           0.46        26
#    macro avg       0.34      0.41      0.36        26
# weighted avg       0.42      0.46      0.43        26
#
# Roc Auc: 0.6891199012022812
# LGBM PERFORMANCE FOR CONTROL
# Accuracy: 0.10775862068965517
# Balanced Accuracy: 0.12496889637002341
# Random Balanced Accuracy: 0.19142412872120662
#
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       0.97      0.09      0.17       320
#          1.0       0.03      0.02      0.02        61
#          2.0       0.14      0.25      0.18        76
#          3.0       0.01      0.14      0.01         7
#          4.0       0.00      0.00      0.00         0
#          5.0       0.00      0.00      0.00         0
#
#     accuracy                           0.11       464
#    macro avg       0.19      0.08      0.06       464
# weighted avg       0.69      0.11      0.15       464
#
# Roc Auc: 0.5058137105807411
# CUDA memory cleared and model deleted.
#
# Fold 3
# RANDOM PERFORMANCE
# Accuracy: 0.11538461538461539
# Balanced Accuracy: 0.09722222222222221
# Random Balanced Accuracy: 0.19999999999999998
#
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       0.00      0.00      0.00         3
#          1.0       0.33      0.25      0.29         4
#          2.0       0.25      0.17      0.20         6
#          3.0       0.20      0.17      0.18         6
#          4.0       0.00      0.00      0.00         6
#          5.0       0.00      0.00      0.00         1
#
#     accuracy                           0.12        26
#    macro avg       0.13      0.10      0.11        26
# weighted avg       0.16      0.12      0.13        26
#
# Roc Auc: 0.47893939393939394
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# CNN PERFORMANCE
# Accuracy: 0.38461538461538464
# Balanced Accuracy: 0.3055555555555555
# Random Balanced Accuracy: 0.027777777777777776
#
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       0.50      0.33      0.40         3
#          1.0       0.00      0.00      0.00         4
#          2.0       0.31      0.67      0.42         6
#          3.0       0.43      0.50      0.46         6
#          4.0       0.50      0.33      0.40         6
#          5.0       0.00      0.00      0.00         1
#
#     accuracy                           0.38        26
#    macro avg       0.29      0.31      0.28        26
# weighted avg       0.34      0.38      0.34        26
#
# Roc Auc: 0.7146058410188845
# CNN PERFORMANCE FOR CONTROL
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Accuracy: 0.1896551724137931
# Balanced Accuracy: 0.2721787177985948
# Random Balanced Accuracy: 0.21761312824777662
#
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       0.96      0.14      0.25       320
#          1.0       0.12      0.02      0.03        61
#          2.0       0.16      0.50      0.25        76
#          3.0       0.02      0.43      0.04         7
#          4.0       0.00      0.00      0.00         0
#
#     accuracy                           0.19       464
#    macro avg       0.25      0.22      0.11       464
# weighted avg       0.70      0.19      0.22       464
#
# Roc Auc: 0.5795127940084073
# CUDA memory cleared and model deleted.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# MLP PERFORMANCE
# Accuracy: 0.46153846153846156
# Balanced Accuracy: 0.3611111111111111
# Random Balanced Accuracy: 0.1880952380952381
#
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       1.00      0.33      0.50         3
#          1.0       0.00      0.00      0.00         4
#          2.0       0.36      0.83      0.50         6
#          3.0       0.50      0.33      0.40         6
#          4.0       0.67      0.67      0.67         6
#          5.0       0.00      0.00      0.00         1
#
#     accuracy                           0.46        26
#    macro avg       0.42      0.36      0.34        26
# weighted avg       0.47      0.46      0.42        26
#
# Roc Auc: 0.58655248133509
# MLP PERFORMANCE FOR CONTROL
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Accuracy: 0.10775862068965517
# Balanced Accuracy: 0.14189967105263157
# Random Balanced Accuracy: 0.19103163992869876
#
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       1.00      0.03      0.05       320
#          1.0       0.00      0.00      0.00        61
#          2.0       0.15      0.54      0.23        76
#          3.0       0.00      0.00      0.00         7
#          4.0       0.00      0.00      0.00         0
#
#     accuracy                           0.11       464
#    macro avg       0.23      0.11      0.06       464
# weighted avg       0.71      0.11      0.08       464
#
# Roc Auc: 0.5064581296035991
# CUDA memory cleared and model deleted.
# tabpfn PERFORMANCE
# Accuracy: 0.46153846153846156
# Balanced Accuracy: 0.3611111111111111
# Random Balanced Accuracy: 0.14166666666666666
#
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       0.00      0.00      0.00         3
#          1.0       0.50      0.50      0.50         4
#          2.0       0.33      0.67      0.44         6
#          3.0       0.33      0.17      0.22         6
#          4.0       0.71      0.83      0.77         6
#          5.0       0.00      0.00      0.00         1
#
#     accuracy                           0.46        26
#    macro avg       0.31      0.36      0.32        26
# weighted avg       0.40      0.46      0.41        26
#
# Roc Auc: 0.8234947299077734
# tabpfn PERFORMANCE FOR CONTROL
# Accuracy: 0.03879310344827586
# Balanced Accuracy: 0.22618790829532848
# Random Balanced Accuracy: 0.2159591338098593
#
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       0.00      0.00      0.00       320
#          1.0       0.32      0.10      0.15        61
#          2.0       0.04      0.09      0.06        76
#          3.0       0.03      0.71      0.05         7
#          4.0       0.00      0.00      0.00         0
#
#     accuracy                           0.04       464
#    macro avg       0.08      0.18      0.05       464
# weighted avg       0.05      0.04      0.03       464
#
# Roc Auc: 0.49162495729833716
# CUDA memory cleared and model deleted.
# LGBM PERFORMANCE
# Accuracy: 0.46153846153846156
# Balanced Accuracy: 0.3611111111111111
# Random Balanced Accuracy: 0.30277777777777776
#
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       1.00      0.33      0.50         3
#          1.0       0.00      0.00      0.00         4
#          2.0       0.36      0.67      0.47         6
#          3.0       0.57      0.67      0.62         6
#          4.0       0.50      0.50      0.50         6
#          5.0       0.00      0.00      0.00         1
#
#     accuracy                           0.46        26
#    macro avg       0.41      0.36      0.35        26
# weighted avg       0.45      0.46      0.42        26
#
# Roc Auc: 0.6620223978919632
# LGBM PERFORMANCE FOR CONTROL
# Accuracy: 0.08405172413793104
# Balanced Accuracy: 0.11969225702576113
# Random Balanced Accuracy: 0.21335899332143723
#
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       0.89      0.05      0.10       320
#          1.0       0.06      0.03      0.04        61
#          2.0       0.10      0.25      0.14        76
#          3.0       0.01      0.14      0.01         7
#          4.0       0.00      0.00      0.00         0
#          5.0       0.00      0.00      0.00         0
#
#     accuracy                           0.08       464
#    macro avg       0.18      0.08      0.05       464
# weighted avg       0.64      0.08      0.10       464
#
# Roc Auc: 0.43164985735014016
# CUDA memory cleared and model deleted.
#
# Fold 4
# RANDOM PERFORMANCE
# Accuracy: 0.15384615384615385
# Balanced Accuracy: 0.1126984126984127
# Random Balanced Accuracy: 0.18333333333333335
#
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       0.00      0.00      0.00         3
#          1.0       0.00      0.00      0.00         3
#          2.0       0.14      0.14      0.14         7
#          3.0       0.20      0.33      0.25         6
#          4.0       0.17      0.20      0.18         5
#          5.0       0.00      0.00      0.00         2
#
#     accuracy                           0.15        26
#    macro avg       0.08      0.11      0.10        26
# weighted avg       0.12      0.15      0.13        26
#
# Roc Auc: 0.501407958301551
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# CNN PERFORMANCE
# Accuracy: 0.2692307692307692
# Balanced Accuracy: 0.21746031746031744
# Random Balanced Accuracy: 0.11904761904761905
#
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       0.00      0.00      0.00         3
#          1.0       1.00      0.33      0.50         3
#          2.0       0.25      0.57      0.35         7
#          3.0       0.00      0.00      0.00         6
#          4.0       0.25      0.40      0.31         5
#          5.0       0.00      0.00      0.00         2
#
#     accuracy                           0.27        26
#    macro avg       0.25      0.22      0.19        26
# weighted avg       0.23      0.27      0.21        26
#
# Roc Auc: 0.6182180995968182
# CNN PERFORMANCE FOR CONTROL
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Accuracy: 0.15732758620689655
# Balanced Accuracy: 0.2571428571428571
# Random Balanced Accuracy: 0.21203224052889497
#
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       0.91      0.10      0.18       320
#          1.0       0.00      0.00      0.00        61
#          2.0       0.15      0.50      0.23        76
#          3.0       0.03      0.43      0.06         7
#          4.0       0.00      0.00      0.00         0
#
#     accuracy                           0.16       464
#    macro avg       0.22      0.21      0.09       464
# weighted avg       0.65      0.16      0.16       464
#
# Roc Auc: 0.5560727416298334
# CUDA memory cleared and model deleted.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# MLP PERFORMANCE
# Accuracy: 0.2692307692307692
# Balanced Accuracy: 0.2571428571428571
# Random Balanced Accuracy: 0.08333333333333333
#
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       0.00      0.00      0.00         3
#          1.0       1.00      0.67      0.80         3
#          2.0       0.17      0.14      0.15         7
#          3.0       0.20      0.33      0.25         6
#          4.0       0.25      0.40      0.31         5
#          5.0       0.00      0.00      0.00         2
#
#     accuracy                           0.27        26
#    macro avg       0.27      0.26      0.25        26
# weighted avg       0.25      0.27      0.25        26
#
# Roc Auc: 0.5301333042751808
# MLP PERFORMANCE FOR CONTROL
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Accuracy: 0.0668103448275862
# Balanced Accuracy: 0.23060038672500924
# Random Balanced Accuracy: 0.21731791600212652
#
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       1.00      0.04      0.08       320
#          1.0       0.08      0.03      0.05        61
#          2.0       0.09      0.13      0.11        76
#          3.0       0.02      0.71      0.05         7
#          4.0       0.00      0.00      0.00         0
#
#     accuracy                           0.07       464
#    macro avg       0.24      0.18      0.06       464
# weighted avg       0.72      0.07      0.08       464
#
# Roc Auc: 0.5275961147895032
# CUDA memory cleared and model deleted.
# tabpfn PERFORMANCE
# Accuracy: 0.5
# Balanced Accuracy: 0.476984126984127
# Random Balanced Accuracy: 0.19444444444444442
#
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       1.00      0.33      0.50         3
#          1.0       0.60      1.00      0.75         3
#          2.0       0.60      0.43      0.50         7
#          3.0       0.43      0.50      0.46         6
#          4.0       0.38      0.60      0.46         5
#          5.0       0.00      0.00      0.00         2
#
#     accuracy                           0.50        26
#    macro avg       0.50      0.48      0.45        26
# weighted avg       0.52      0.50      0.47        26
#
# Roc Auc: 0.798744142966111
# tabpfn PERFORMANCE FOR CONTROL
# Accuracy: 0.09051724137931035
# Balanced Accuracy: 0.16101347759768272
# Random Balanced Accuracy: 0.183179844803267
#
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       0.86      0.06      0.11       320
#          1.0       0.17      0.11      0.14        61
#          2.0       0.10      0.18      0.13        76
#          3.0       0.01      0.29      0.02         7
#          4.0       0.00      0.00      0.00         0
#
#     accuracy                           0.09       464
#    macro avg       0.23      0.13      0.08       464
# weighted avg       0.63      0.09      0.12       464
#
# Roc Auc: 0.5375906700605816
# CUDA memory cleared and model deleted.
# LGBM PERFORMANCE
# Accuracy: 0.4230769230769231
# Balanced Accuracy: 0.37936507936507935
# Random Balanced Accuracy: 0.12222222222222223
#
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       0.00      0.00      0.00         3
#          1.0       0.40      0.67      0.50         3
#          2.0       0.25      0.14      0.18         7
#          3.0       0.50      0.67      0.57         6
#          4.0       0.44      0.80      0.57         5
#          5.0       0.00      0.00      0.00         2
#
#     accuracy                           0.42        26
#    macro avg       0.27      0.38      0.30        26
# weighted avg       0.31      0.42      0.35        26
#
# Roc Auc: 0.6114598089426465
# LGBM PERFORMANCE FOR CONTROL
# Accuracy: 0.09482758620689655
# Balanced Accuracy: 0.08284013697152717
# Random Balanced Accuracy: 0.1566170813884057
#
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       1.00      0.08      0.14       320
#          1.0       0.03      0.02      0.02        61
#          2.0       0.14      0.24      0.18        76
#          3.0       0.00      0.00      0.00         7
#          4.0       0.00      0.00      0.00         0
#
#     accuracy                           0.09       464
#    macro avg       0.23      0.07      0.07       464
# weighted avg       0.72      0.09      0.13       464
#
# Roc Auc: 0.4714954850147125
# CUDA memory cleared and model deleted.
#
# Fold 5
# RANDOM PERFORMANCE
# Accuracy: 0.19230769230769232
# Balanced Accuracy: 0.2333333333333333
# Random Balanced Accuracy: 0.09722222222222221
#
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       0.00      0.00      0.00         3
#          1.0       0.25      0.33      0.29         3
#          2.0       0.00      0.00      0.00         7
#          3.0       0.33      0.17      0.22         6
#          4.0       0.40      0.40      0.40         5
#          5.0       0.11      0.50      0.18         2
#
#     accuracy                           0.19        26
#    macro avg       0.18      0.23      0.18        26
# weighted avg       0.19      0.19      0.18        26
#
# Roc Auc: 0.5186530638189678
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# CNN PERFORMANCE
# Accuracy: 0.34615384615384615
# Balanced Accuracy: 0.2841269841269841
# Random Balanced Accuracy: 0.125
#
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       1.00      0.33      0.50         3
#          1.0       0.00      0.00      0.00         3
#          2.0       0.31      0.57      0.40         7
#          3.0       0.00      0.00      0.00         6
#          4.0       0.50      0.80      0.62         5
#          5.0       0.00      0.00      0.00         2
#
#     accuracy                           0.35        26
#    macro avg       0.30      0.28      0.25        26
# weighted avg       0.29      0.35      0.28        26
#
# Roc Auc: 0.6215329991645782
# CNN PERFORMANCE FOR CONTROL
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Accuracy: 0.1271551724137931
# Balanced Accuracy: 0.23439156292370267
# Random Balanced Accuracy: 0.18680028638147045
#
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       0.96      0.07      0.14       320
#          1.0       0.10      0.07      0.08        61
#          2.0       0.15      0.37      0.21        76
#          3.0       0.03      0.43      0.06         7
#          4.0       0.00      0.00      0.00         0
#
#     accuracy                           0.13       464
#    macro avg       0.25      0.19      0.10       464
# weighted avg       0.70      0.13      0.14       464
#
# Roc Auc: 0.6170767358989763
# CUDA memory cleared and model deleted.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# MLP PERFORMANCE
# Accuracy: 0.4230769230769231
# Balanced Accuracy: 0.34920634920634913
# Random Balanced Accuracy: 0.10416666666666667
#
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       1.00      0.33      0.50         3
#          1.0       0.00      0.00      0.00         3
#          2.0       0.38      0.43      0.40         7
#          3.0       0.29      0.33      0.31         6
#          4.0       0.56      1.00      0.71         5
#          5.0       0.00      0.00      0.00         2
#
#     accuracy                           0.42        26
#    macro avg       0.37      0.35      0.32        26
# weighted avg       0.39      0.42      0.37        26
#
# Roc Auc: 0.6954996186117467
# MLP PERFORMANCE FOR CONTROL
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Accuracy: 0.1724137931034483
# Balanced Accuracy: 0.24165536792801678
# Random Balanced Accuracy: 0.2554351497498134
#
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       1.00      0.15      0.26       320
#          1.0       0.07      0.03      0.05        61
#          2.0       0.16      0.36      0.23        76
#          3.0       0.02      0.43      0.03         7
#          4.0       0.00      0.00      0.00         0
#
#     accuracy                           0.17       464
#    macro avg       0.25      0.19      0.11       464
# weighted avg       0.73      0.17      0.22       464
#
# Roc Auc: 0.5673143755175882
# CUDA memory cleared and model deleted.
# tabpfn PERFORMANCE
# Accuracy: 0.5
# Balanced Accuracy: 0.40079365079365076
# Random Balanced Accuracy: 0.14583333333333331
#
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       0.00      0.00      0.00         3
#          1.0       0.33      0.33      0.33         3
#          2.0       0.57      0.57      0.57         7
#          3.0       0.43      0.50      0.46         6
#          4.0       0.56      1.00      0.71         5
#          5.0       0.00      0.00      0.00         2
#
#     accuracy                           0.50        26
#    macro avg       0.31      0.40      0.35        26
# weighted avg       0.40      0.50      0.44        26
#
# Roc Auc: 0.8134502923976608
# tabpfn PERFORMANCE FOR CONTROL
# Accuracy: 0.08189655172413793
# Balanced Accuracy: 0.255181884013312
# Random Balanced Accuracy: 0.1788319396316787
#
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       0.80      0.01      0.02       320
#          1.0       0.18      0.21      0.19        61
#          2.0       0.14      0.22      0.17        76
#          3.0       0.03      0.57      0.05         7
#          4.0       0.00      0.00      0.00         0
#
#     accuracy                           0.08       464
#    macro avg       0.23      0.20      0.09       464
# weighted avg       0.60      0.08      0.07       464
#
# Roc Auc: 0.5832135970220436
# CUDA memory cleared and model deleted.
# LGBM PERFORMANCE
# Accuracy: 0.34615384615384615
# Balanced Accuracy: 0.26031746031746034
# Random Balanced Accuracy: 0.16666666666666666
#
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       0.00      0.00      0.00         3
#          1.0       0.00      0.00      0.00         3
#          2.0       0.27      0.43      0.33         7
#          3.0       0.29      0.33      0.31         6
#          4.0       0.80      0.80      0.80         5
#          5.0       0.00      0.00      0.00         2
#
#     accuracy                           0.35        26
#    macro avg       0.23      0.26      0.24        26
# weighted avg       0.29      0.35      0.31        26
#
# Roc Auc: 0.64247847880571
# LGBM PERFORMANCE FOR CONTROL
# Accuracy: 0.08836206896551724
# Balanced Accuracy: 0.15861445365462837
# Random Balanced Accuracy: 0.17839901216870518
#
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       1.00      0.06      0.11       320
#          1.0       0.15      0.08      0.11        61
#          2.0       0.10      0.21      0.14        76
#          3.0       0.01      0.29      0.02         7
#          4.0       0.00      0.00      0.00         0
#
#     accuracy                           0.09       464
#    macro avg       0.25      0.13      0.07       464
# weighted avg       0.73      0.09      0.11       464
#
# Roc Auc: 0.48820994096520975
# CUDA memory cleared and model deleted.
#
#  Random Classifier Performance Validation:
# Mean Accuracy: 0.16923076923076924
# Std Accuracy: 0.03922322702763681
# Mean Balanced Accuracy: 0.18515873015873013
# Std Balanced Accuracy: 0.07702404463380945
# Mean Random Balanced Accuracy: 0.11706349206349205
# Std Random Balanced Accuracy: 0.06582423131391299
# Mean Roc Auc: 0.5148952123391484
# Std Roc Auc: 0.06762490467624246
#
#  TabPFN Classifier Performance Validation:
# Mean Accuracy: 0.49230769230769234
# Std Accuracy: 0.05102499677469844
# Mean Balanced Accuracy: 0.41920634920634925
# Std Balanced Accuracy: 0.05042874879434813
# Mean Random Balanced Accuracy: 0.21055555555555552
# Std Random Balanced Accuracy: 0.06454135433776616
# Mean Roc Auc: 0.8192999775459728
# Std Roc Auc: 0.016568384421814627
#
#  LGBM Classifier Performance Validation:
# Mean Accuracy: 0.4076923076923077
# Std Accuracy: 0.05217176910096361
# Mean Balanced Accuracy: 0.3458730158730159
# Std Balanced Accuracy: 0.05185498316859692
# Mean Random Balanced Accuracy: 0.195
# Std Random Balanced Accuracy: 0.11651312647927405
# Mean Roc Auc: 0.6735907423367378
# Std Roc Auc: 0.05133137640929277
#
#  MLP Classifier Performance Validation:
# Mean Accuracy: 0.3692307692307692
# Std Accuracy: 0.0670599837467796
# Mean Balanced Accuracy: 0.3223809523809523
# Std Balanced Accuracy: 0.04330861554469371
# Mean Random Balanced Accuracy: 0.15011904761904762
# Std Random Balanced Accuracy: 0.04670174688387516
# Mean Roc Auc: 0.6015493542816197
# Std Roc Auc: 0.055036612959285046
#
#  CNN Classifier Performance Validation:
# Mean Accuracy: 0.39230769230769236
# Std Accuracy: 0.08213137116947164
# Mean Balanced Accuracy: 0.31285714285714283
# Std Balanced Accuracy: 0.061365990845512294
# Mean Random Balanced Accuracy: 0.1038095238095238
# Std Random Balanced Accuracy: 0.041566849448100684
# Mean Roc Auc: 0.6532954190482794
# Std Roc Auc: 0.039620042590919904
#
#  TabPFN Classifier Performance Control:
# Mean Accuracy: 0.08362068965517241
# Std Accuracy: 0.03622741618870808
# Mean Balanced Accuracy: 0.23189485624922962
# Std Balanced Accuracy: 0.03746942391327854
# Mean Random Balanced Accuracy: 0.20026426044387463
# Std Random Balanced Accuracy: 0.021921568924410245
# Mean Roc Auc: 0.548467090911357
# Std Roc Auc: 0.033955353530995915
#
#  LGBM Classifier Performance Control:
# Mean Accuracy: 0.09568965517241379
# Std Accuracy: 0.008896451482995815
# Mean Balanced Accuracy: 0.1339074825896709
# Std Balanced Accuracy: 0.034501982023403384
# Mean Random Balanced Accuracy: 0.18337659582832172
# Std Random Balanced Accuracy: 0.018677016011298005
# Mean Roc Auc: 0.4946995551493328
# Std Roc Auc: 0.047629116002786964
#
#  MLP Classifier Performance Control:
# Mean Accuracy: 0.13706896551724138
# Std Accuracy: 0.04546545512791123
# Mean Balanced Accuracy: 0.20569458353876496
# Std Balanced Accuracy: 0.05005163254881229
# Mean Random Balanced Accuracy: 0.21290966860138916
# Std Random Balanced Accuracy: 0.027361059328422716
# Mean Roc Auc: 0.5483762501386853
# Std Roc Auc: 0.030728749328811856
#
#  CNN Classifier Performance Control:
# Mean Accuracy: 0.1375
# Std Accuracy: 0.04724499734446472
# Mean Balanced Accuracy: 0.20796667000493035
# Std Balanced Accuracy: 0.08226615531261268
# Mean Random Balanced Accuracy: 0.18722780673609235
# Std Random Balanced Accuracy: 0.03703538918162554
# Mean Roc Auc: 0.5632361363838385
# Std Roc Auc: 0.04184920589746054
#
# === Deconfounding Strategy: Correlation_in_Feature ===
#
#  #### TRAINING WITH 0.01 OF THE DATA ####
# Training data shape: (100, 192), length of y: 100
# Training data class distribution: label_age_group
# 2.0    29
# 3.0    27
# 4.0    21
# 1.0    11
# 0.0    10
# 5.0     2
# Name: count, dtype: int64
#
# Fold 1
# RANDOM PERFORMANCE
# Accuracy: 0.07692307692307693
# Balanced Accuracy: 0.05714285714285714
# Random Balanced Accuracy: 0.15833333333333333
#
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       0.00      0.00      0.00         3
#          1.0       0.00      0.00      0.00         3
#          2.0       0.17      0.14      0.15         7
#          3.0       0.00      0.00      0.00         7
#          4.0       0.20      0.20      0.20         5
#          5.0       0.00      0.00      0.00         1
#
#     accuracy                           0.08        26
#    macro avg       0.06      0.06      0.06        26
# weighted avg       0.08      0.08      0.08        26
#
# Roc Auc: 0.498290654171661
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# CNN PERFORMANCE
# Accuracy: 0.34615384615384615
# Balanced Accuracy: 0.2650793650793651
# Random Balanced Accuracy: 0.16666666666666666
#
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       0.50      0.33      0.40         3
#          1.0       0.00      0.00      0.00         3
#          2.0       0.29      0.29      0.29         7
#          3.0       0.29      0.57      0.38         7
#          4.0       0.67      0.40      0.50         5
#          5.0       0.00      0.00      0.00         1
#
#     accuracy                           0.35        26
#    macro avg       0.29      0.27      0.26        26
# weighted avg       0.34      0.35      0.32        26
#
# Roc Auc: 0.5456271112564018
# CNN PERFORMANCE FOR CONTROL
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Accuracy: 0.09482758620689655
# Balanced Accuracy: 0.19678168911007027
# Random Balanced Accuracy: 0.22200697372930142
#
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       0.95      0.06      0.11       320
#          1.0       0.20      0.05      0.08        61
#          2.0       0.15      0.25      0.19        76
#          3.0       0.01      0.43      0.03         7
#          4.0       0.00      0.00      0.00         0
#
#     accuracy                           0.09       464
#    macro avg       0.26      0.16      0.08       464
# weighted avg       0.71      0.09      0.12       464
#
# Roc Auc: 0.515376925556314
# CUDA memory cleared and model deleted.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# MLP PERFORMANCE
# Accuracy: 0.38461538461538464
# Balanced Accuracy: 0.3523809523809524
# Random Balanced Accuracy: 0.1111111111111111
#
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       0.50      0.67      0.57         3
#          1.0       1.00      0.33      0.50         3
#          2.0       0.29      0.57      0.38         7
#          3.0       0.33      0.14      0.20         7
#          4.0       0.50      0.40      0.44         5
#          5.0       0.00      0.00      0.00         1
#
#     accuracy                           0.38        26
#    macro avg       0.44      0.35      0.35        26
# weighted avg       0.44      0.38      0.37        26
#
# Roc Auc: 0.6563393992226945
# MLP PERFORMANCE FOR CONTROL
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Accuracy: 0.14870689655172414
# Balanced Accuracy: 0.1741188909774436
# Random Balanced Accuracy: 0.20172735760971056
#
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       0.97      0.11      0.19       320
#          1.0       0.00      0.00      0.00        61
#          2.0       0.12      0.45      0.19        76
#          3.0       0.01      0.14      0.02         7
#          4.0       0.00      0.00      0.00         0
#
#     accuracy                           0.15       464
#    macro avg       0.22      0.14      0.08       464
# weighted avg       0.69      0.15      0.16       464
#
# Roc Auc: 0.5392939549299451
# CUDA memory cleared and model deleted.
# tabpfn PERFORMANCE
# Accuracy: 0.4230769230769231
# Balanced Accuracy: 0.36349206349206353
# Random Balanced Accuracy: 0.2222222222222222
#
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       0.00      0.00      0.00         3
#          1.0       0.67      0.67      0.67         3
#          2.0       0.30      0.43      0.35         7
#          3.0       0.25      0.29      0.27         7
#          4.0       0.80      0.80      0.80         5
#          5.0       0.00      0.00      0.00         1
#
#     accuracy                           0.42        26
#    macro avg       0.34      0.36      0.35        26
# weighted avg       0.38      0.42      0.40        26
#
# Roc Auc: 0.7052246558425049
# tabpfn PERFORMANCE FOR CONTROL
# Accuracy: 0.032327586206896554
# Balanced Accuracy: 0.10415883458646616
# Random Balanced Accuracy: 0.20246672018683404
#
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       0.80      0.01      0.02       320
#          1.0       0.00      0.00      0.00        61
#          2.0       0.05      0.12      0.07        76
#          3.0       0.01      0.29      0.02         7
#          4.0       0.00      0.00      0.00         0
#
#     accuracy                           0.03       464
#    macro avg       0.17      0.08      0.02       464
# weighted avg       0.56      0.03      0.03       464
#
# Roc Auc: 0.4412768972298692
# CUDA memory cleared and model deleted.
# LGBM PERFORMANCE
# Accuracy: 0.38461538461538464
# Balanced Accuracy: 0.3523809523809524
# Random Balanced Accuracy: 0.2583333333333333
#
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       0.67      0.67      0.67         3
#          1.0       0.50      0.33      0.40         3
#          2.0       0.33      0.43      0.38         7
#          3.0       0.22      0.29      0.25         7
#          4.0       0.67      0.40      0.50         5
#          5.0       0.00      0.00      0.00         1
#
#     accuracy                           0.38        26
#    macro avg       0.40      0.35      0.37        26
# weighted avg       0.41      0.38      0.39        26
#
# Roc Auc: 0.6685474555955104
# LGBM PERFORMANCE FOR CONTROL
# Accuracy: 0.10129310344827586
# Balanced Accuracy: 0.21579255515838774
# Random Balanced Accuracy: 0.21257100188468836
#
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       0.94      0.05      0.09       320
#          1.0       0.19      0.08      0.11        61
#          2.0       0.12      0.30      0.17        76
#          3.0       0.02      0.43      0.04         7
#          4.0       0.00      0.00      0.00         0
#
#     accuracy                           0.10       464
#    macro avg       0.25      0.17      0.08       464
# weighted avg       0.69      0.10      0.11       464
#
# Roc Auc: 0.5075321368153454
# CUDA memory cleared and model deleted.
#
# Fold 2
# RANDOM PERFORMANCE
# Accuracy: 0.07692307692307693
# Balanced Accuracy: 0.06666666666666667
# Random Balanced Accuracy: 0.08928571428571429
#
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       0.00      0.00      0.00         3
#          1.0       0.00      0.00      0.00         3
#          2.0       0.00      0.00      0.00         7
#          3.0       0.00      0.00      0.00         7
#          4.0       0.40      0.40      0.40         5
#          5.0       0.00      0.00      0.00         1
#
#     accuracy                           0.08        26
#    macro avg       0.07      0.07      0.07        26
# weighted avg       0.08      0.08      0.08        26
#
# Roc Auc: 0.5543169517997893
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# CNN PERFORMANCE
# Accuracy: 0.38461538461538464
# Balanced Accuracy: 0.2571428571428571
# Random Balanced Accuracy: 0.1722222222222222
#
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       0.00      0.00      0.00         3
#          1.0       0.00      0.00      0.00         3
#          2.0       0.38      0.71      0.50         7
#          3.0       0.50      0.43      0.46         7
#          4.0       0.50      0.40      0.44         5
#          5.0       0.00      0.00      0.00         1
#
#     accuracy                           0.38        26
#    macro avg       0.23      0.26      0.23        26
# weighted avg       0.33      0.38      0.34        26
#
# Roc Auc: 0.6832646834477498
# CNN PERFORMANCE FOR CONTROL
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Accuracy: 0.15301724137931033
# Balanced Accuracy: 0.20068206504991987
# Random Balanced Accuracy: 0.193339016297274
#
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       1.00      0.08      0.16       320
#          1.0       0.14      0.05      0.07        61
#          2.0       0.19      0.53      0.28        76
#          3.0       0.01      0.14      0.01         7
#          4.0       0.00      0.00      0.00         0
#
#     accuracy                           0.15       464
#    macro avg       0.27      0.16      0.10       464
# weighted avg       0.74      0.15      0.16       464
#
# Roc Auc: 0.5469077688443718
# CUDA memory cleared and model deleted.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# MLP PERFORMANCE
# Accuracy: 0.3076923076923077
# Balanced Accuracy: 0.2634920634920635
# Random Balanced Accuracy: 0.2333333333333333
#
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       0.25      0.33      0.29         3
#          1.0       0.50      0.33      0.40         3
#          2.0       0.22      0.29      0.25         7
#          3.0       0.30      0.43      0.35         7
#          4.0       1.00      0.20      0.33         5
#          5.0       0.00      0.00      0.00         1
#
#     accuracy                           0.31        26
#    macro avg       0.38      0.26      0.27        26
# weighted avg       0.42      0.31      0.31        26
#
# Roc Auc: 0.5619970215393556
# MLP PERFORMANCE FOR CONTROL
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Accuracy: 0.1724137931034483
# Balanced Accuracy: 0.217746209786762
# Random Balanced Accuracy: 0.20682487669478486
#
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       1.00      0.10      0.18       320
#          1.0       0.11      0.05      0.07        61
#          2.0       0.20      0.58      0.30        76
#          3.0       0.01      0.14      0.01         7
#          4.0       0.00      0.00      0.00         0
#
#     accuracy                           0.17       464
#    macro avg       0.26      0.17      0.11       464
# weighted avg       0.74      0.17      0.18       464
#
# Roc Auc: 0.554375916284916
# CUDA memory cleared and model deleted.
# tabpfn PERFORMANCE
# Accuracy: 0.38461538461538464
# Balanced Accuracy: 0.26666666666666666
# Random Balanced Accuracy: 0.08333333333333333
#
# Classification Report:
#               precision    recall  f1-score   support
#
# ...
#
# Roc Auc: 0.4424993643529113
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# CNN PERFORMANCE
# Accuracy: 0.4230769230769231
# Balanced Accuracy: 0.3436507936507936
# Random Balanced Accuracy: 0.15277777777777776
#
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       1.00      0.33      0.50         3
#          1.0       0.00      0.00      0.00         3
#          2.0       0.75      0.43      0.55         7
#          3.0       0.30      0.50      0.38         6
#          4.0       0.40      0.80      0.53         5
#          5.0       0.00      0.00      0.00         2
#
#     accuracy                           0.42        26
#    macro avg       0.41      0.34      0.33        26
# weighted avg       0.46      0.42      0.39        26
#
# Roc Auc: 0.630165994696887
# CNN PERFORMANCE FOR CONTROL
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Accuracy: 0.10991379310344827
# Balanced Accuracy: 0.10999245038826574
# Random Balanced Accuracy: 0.1619383641512577
#
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       0.92      0.07      0.14       320
#          1.0       0.15      0.05      0.07        61
#          2.0       0.20      0.32      0.24        76
#          3.0       0.00      0.00      0.00         7
#          4.0       0.00      0.00      0.00         0
#
#     accuracy                           0.11       464
#    macro avg       0.25      0.09      0.09       464
# weighted avg       0.69      0.11      0.15       464
#
# Roc Auc: 0.5199695363086293
# CUDA memory cleared and model deleted.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# MLP PERFORMANCE
# Accuracy: 0.3076923076923077
# Balanced Accuracy: 0.2722222222222222
# Random Balanced Accuracy: 0.28095238095238095
#
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       0.00      0.00      0.00         3
#          1.0       0.14      0.33      0.20         3
#          2.0       0.00      0.00      0.00         7
#          3.0       0.38      0.50      0.43         6
#          4.0       0.40      0.80      0.53         5
#          5.0       0.00      0.00      0.00         2
#
#     accuracy                           0.31        26
#    macro avg       0.15      0.27      0.19        26
# weighted avg       0.18      0.31      0.22        26
#
# Roc Auc: 0.5218639896843559
# MLP PERFORMANCE FOR CONTROL
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Accuracy: 0.15948275862068967
# Balanced Accuracy: 0.12124541630716135
# Random Balanced Accuracy: 0.2146413209552596
#
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       0.93      0.16      0.27       320
#          1.0       0.06      0.07      0.06        61
#          2.0       0.24      0.26      0.25        76
#          3.0       0.00      0.00      0.00         7
#          4.0       0.00      0.00      0.00         0
#
#     accuracy                           0.16       464
#    macro avg       0.25      0.10      0.12       464
# weighted avg       0.69      0.16      0.23       464
#
# Roc Auc: 0.5131281794108746
# CUDA memory cleared and model deleted.
# tabpfn PERFORMANCE
# Accuracy: 0.5
# Balanced Accuracy: 0.4492063492063492
# Random Balanced Accuracy: 0.15555555555555556
#
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       0.50      0.33      0.40         3
#          1.0       0.67      0.67      0.67         3
#          2.0       0.50      0.43      0.46         7
#          3.0       0.50      0.67      0.57         6
#          4.0       0.43      0.60      0.50         5
#          5.0       0.00      0.00      0.00         2
#
#     accuracy                           0.50        26
#    macro avg       0.43      0.45      0.43        26
# weighted avg       0.47      0.50      0.48        26
#
# Roc Auc: 0.8087029167120701
# tabpfn PERFORMANCE FOR CONTROL
# Accuracy: 0.11206896551724138
# Balanced Accuracy: 0.2095843476519167
# Random Balanced Accuracy: 0.21648546040104374
#
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       0.81      0.08      0.15       320
#          1.0       0.19      0.13      0.15        61
#          2.0       0.14      0.20      0.16        76
#          3.0       0.02      0.43      0.03         7
#          4.0       0.00      0.00      0.00         0
#
#     accuracy                           0.11       464
#    macro avg       0.23      0.17      0.10       464
# weighted avg       0.61      0.11      0.15       464
#
# Roc Auc: 0.5317964459755797
# CUDA memory cleared and model deleted.
# LGBM PERFORMANCE
# Accuracy: 0.3076923076923077
# Balanced Accuracy: 0.23650793650793653
# Random Balanced Accuracy: 0.11666666666666665
#
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       0.00      0.00      0.00         3
#          1.0       0.00      0.00      0.00         3
#          2.0       0.29      0.29      0.29         7
#          3.0       0.25      0.33      0.29         6
#          4.0       0.44      0.80      0.57         5
#          5.0       0.00      0.00      0.00         2
#
#     accuracy                           0.31        26
#    macro avg       0.16      0.24      0.19        26
# weighted avg       0.22      0.31      0.25        26
#
# Roc Auc: 0.5680619120264429
# LGBM PERFORMANCE FOR CONTROL
# Accuracy: 0.07112068965517242
# Balanced Accuracy: 0.10667119900160237
# Random Balanced Accuracy: 0.1790329516744611
#
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       1.00      0.04      0.08       320
#          1.0       0.07      0.02      0.03        61
#          2.0       0.12      0.22      0.15        76
#          3.0       0.01      0.14      0.01         7
#          4.0       0.00      0.00      0.00         0
#
#     accuracy                           0.07       464
#    macro avg       0.24      0.09      0.05       464
# weighted avg       0.72      0.07      0.09       464
#
# Roc Auc: 0.4702773857514628
# CUDA memory cleared and model deleted.
#
# Fold 5
# RANDOM PERFORMANCE
# Accuracy: 0.11538461538461539
# Balanced Accuracy: 0.11666666666666665
# Random Balanced Accuracy: 0.19999999999999998
#
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       0.00      0.00      0.00         3
#          1.0       0.20      0.33      0.25         3
#          2.0       0.00      0.00      0.00         7
#          3.0       0.50      0.17      0.25         6
#          4.0       0.14      0.20      0.17         5
#          5.0       0.00      0.00      0.00         2
#
#     accuracy                           0.12        26
#    macro avg       0.14      0.12      0.11        26
# weighted avg       0.17      0.12      0.12        26
#
# Roc Auc: 0.49921361374450623
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# CNN PERFORMANCE
# Accuracy: 0.46153846153846156
# Balanced Accuracy: 0.3992063492063492
# Random Balanced Accuracy: 0.13333333333333333
#
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       1.00      0.67      0.80         3
#          1.0       0.00      0.00      0.00         3
#          2.0       0.43      0.43      0.43         7
#          3.0       0.33      0.50      0.40         6
#          4.0       0.50      0.80      0.62         5
#          5.0       0.00      0.00      0.00         2
#
#     accuracy                           0.46        26
#    macro avg       0.38      0.40      0.37        26
# weighted avg       0.40      0.46      0.42        26
#
# Roc Auc: 0.7574704424103738
# CNN PERFORMANCE FOR CONTROL
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Accuracy: 0.10344827586206896
# Balanced Accuracy: 0.2515884036423025
# Random Balanced Accuracy: 0.21491182091565725
#
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       1.00      0.05      0.09       320
#          1.0       0.17      0.03      0.05        61
#          2.0       0.19      0.36      0.25        76
#          3.0       0.02      0.57      0.03         7
#          4.0       0.00      0.00      0.00         0
#
#     accuracy                           0.10       464
#    macro avg       0.28      0.20      0.09       464
# weighted avg       0.74      0.10      0.11       464
#
# Roc Auc: 0.5625617373178476
# CUDA memory cleared and model deleted.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# MLP PERFORMANCE
# Accuracy: 0.46153846153846156
# Balanced Accuracy: 0.3674603174603175
# Random Balanced Accuracy: 0.1722222222222222
#
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       1.00      0.33      0.50         3
#          1.0       0.00      0.00      0.00         3
#          2.0       0.36      0.57      0.44         7
#          3.0       0.43      0.50      0.46         6
#          4.0       0.57      0.80      0.67         5
#          5.0       0.00      0.00      0.00         2
#
#     accuracy                           0.46        26
#    macro avg       0.39      0.37      0.35        26
# weighted avg       0.42      0.46      0.41        26
#
# Roc Auc: 0.7624212251643602
# MLP PERFORMANCE FOR CONTROL
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Accuracy: 0.11206896551724138
# Balanced Accuracy: 0.1284128289473684
# Random Balanced Accuracy: 0.21617371261114682
#
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       1.00      0.05      0.10       320
#          1.0       0.00      0.00      0.00        61
#          2.0       0.13      0.46      0.20        76
#          3.0       0.00      0.00      0.00         7
#          4.0       0.00      0.00      0.00         0
#
#     accuracy                           0.11       464
#    macro avg       0.23      0.10      0.06       464
# weighted avg       0.71      0.11      0.10       464
#
# Roc Auc: 0.4897308977020507
# CUDA memory cleared and model deleted.
# tabpfn PERFORMANCE
# Accuracy: 0.5
# Balanced Accuracy: 0.40079365079365076
# Random Balanced Accuracy: 0.16666666666666666
#
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       0.00      0.00      0.00         3
#          1.0       0.33      0.33      0.33         3
#          2.0       0.50      0.57      0.53         7
#          3.0       0.60      0.50      0.55         6
#          4.0       0.50      1.00      0.67         5
#          5.0       0.00      0.00      0.00         2
#
#     accuracy                           0.50        26
#    macro avg       0.32      0.40      0.35        26
# weighted avg       0.41      0.50      0.44        26
#
# Roc Auc: 0.7961588754494934
# tabpfn PERFORMANCE FOR CONTROL
# Accuracy: 0.05172413793103448
# Balanced Accuracy: 0.2151177123135708
# Random Balanced Accuracy: 0.19985306652898216
#
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       0.00      0.00      0.00       320
#          1.0       0.28      0.13      0.18        61
#          2.0       0.08      0.16      0.11        76
#          3.0       0.02      0.57      0.04         7
#          4.0       0.00      0.00      0.00         0
#
#     accuracy                           0.05       464
#    macro avg       0.08      0.17      0.06       464
# weighted avg       0.05      0.05      0.04       464
#
# Roc Auc: 0.5514795709219774
# CUDA memory cleared and model deleted.
# LGBM PERFORMANCE
# Accuracy: 0.34615384615384615
# Balanced Accuracy: 0.3142857142857143
# Random Balanced Accuracy: 0.05555555555555555
#
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       0.00      0.00      0.00         3
#          1.0       0.00      0.00      0.00         3
#          2.0       0.20      0.29      0.24         7
#          3.0       0.33      0.50      0.40         6
#          4.0       0.60      0.60      0.60         5
#          5.0       1.00      0.50      0.67         2
#
#     accuracy                           0.35        26
#    macro avg       0.36      0.31      0.32        26
# weighted avg       0.32      0.35      0.32        26
#
# Roc Auc: 0.6671715520685774
# LGBM PERFORMANCE FOR CONTROL
# Accuracy: 0.09051724137931035
# Balanced Accuracy: 0.15616015576851966
# Random Balanced Accuracy: 0.18514286523347953
#
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       0.86      0.06      0.11       320
#          1.0       0.05      0.02      0.03        61
#          2.0       0.12      0.26      0.17        76
#          3.0       0.01      0.29      0.02         7
#          4.0       0.00      0.00      0.00         0
#          5.0       0.00      0.00      0.00         0
#
#     accuracy                           0.09       464
#    macro avg       0.17      0.10      0.05       464
# weighted avg       0.62      0.09      0.11       464
#
# Roc Auc: 0.4873722514567158
# CUDA memory cleared and model deleted.
#
#  Random Classifier Performance Validation:
# Mean Accuracy: 0.14615384615384616
# Std Accuracy: 0.03768445758127967
# Mean Balanced Accuracy: 0.14452380952380955
# Std Balanced Accuracy: 0.027857482022083997
# Mean Random Balanced Accuracy: 0.1886904761904762
# Std Random Balanced Accuracy: 0.08925854965955239
# Mean Roc Auc: 0.4460495226868225
# Std Roc Auc: 0.03991682664218206
#
#  TabPFN Classifier Performance Validation:
# Mean Accuracy: 0.45384615384615384
# Std Accuracy: 0.06153846153846154
# Mean Balanced Accuracy: 0.3671428571428571
# Std Balanced Accuracy: 0.0615160772902511
# Mean Random Balanced Accuracy: 0.13198412698412698
# Std Random Balanced Accuracy: 0.03230909393685326
# Mean Roc Auc: 0.8084788734022144
# Std Roc Auc: 0.01767952982422138
#
#  LGBM Classifier Performance Validation:
# Mean Accuracy: 0.3769230769230769
# Std Accuracy: 0.08213137116947161
# Mean Balanced Accuracy: 0.3152380952380952
# Std Balanced Accuracy: 0.06957090526332453
# Mean Random Balanced Accuracy: 0.10888888888888888
# Std Random Balanced Accuracy: 0.0396512575112344
# Mean Roc Auc: 0.6768125617072985
# Std Roc Auc: 0.061244312788428915
#
#  MLP Classifier Performance Validation:
# Mean Accuracy: 0.39230769230769236
# Std Accuracy: 0.10986812966988997
# Mean Balanced Accuracy: 0.3373015873015873
# Std Balanced Accuracy: 0.07720717157039057
# Mean Random Balanced Accuracy: 0.2265079365079365
# Std Random Balanced Accuracy: 0.07217354019485256
# Mean Roc Auc: 0.6977048228278206
# Std Roc Auc: 0.09108417186708581
#
#  CNN Classifier Performance Validation:
# Mean Accuracy: 0.46923076923076923
# Std Accuracy: 0.02878197989826109
# Mean Balanced Accuracy: 0.38142857142857134
# Std Balanced Accuracy: 0.030477017184554422
# Mean Random Balanced Accuracy: 0.1561111111111111
# Std Random Balanced Accuracy: 0.03363979492311355
# Mean Roc Auc: 0.7315032665656236
# Std Roc Auc: 0.06556949084519094
#
#  TabPFN Classifier Performance Control:
# Mean Accuracy: 0.08017241379310344
# Std Accuracy: 0.025368860292348555
# Mean Balanced Accuracy: 0.23284583769875508
# Std Balanced Accuracy: 0.019815077830288328
# Mean Random Balanced Accuracy: 0.21126717546140447
# Std Random Balanced Accuracy: 0.03567530683892258
# Mean Roc Auc: 0.5372754806622132
# Std Roc Auc: 0.021377100810200122
#
#  LGBM Classifier Performance Control:
# Mean Accuracy: 0.0875
# Std Accuracy: 0.017057205980525326
# Mean Balanced Accuracy: 0.15458486765068408
# Std Balanced Accuracy: 0.04716823092537115
# Mean Random Balanced Accuracy: 0.1968585477069241
# Std Random Balanced Accuracy: 0.01799649933261571
# Mean Roc Auc: 0.48887896387344687
# Std Roc Auc: 0.03671084711796375
#
#  MLP Classifier Performance Control:
# Mean Accuracy: 0.1418103448275862
# Std Accuracy: 0.017845035814210736
# Mean Balanced Accuracy: 0.2046130438801923
# Std Balanced Accuracy: 0.08739533883655527
# Mean Random Balanced Accuracy: 0.2051126217840591
# Std Random Balanced Accuracy: 0.01578775391307111
# Mean Roc Auc: 0.5411179337435358
# Std Roc Auc: 0.053895438010876165
#
#  CNN Classifier Performance Control:
# Mean Accuracy: 0.12112068965517239
# Std Accuracy: 0.029215108970397488
# Mean Balanced Accuracy: 0.1792446536423025
# Std Balanced Accuracy: 0.04681050715641683
# Mean Random Balanced Accuracy: 0.2094550690985812
# Std Random Balanced Accuracy: 0.029429057433840937
# Mean Roc Auc: 0.5410478730573839
# Std Roc Auc: 0.0226830963347967

# %%
Feature_extraction_applied = False
Pretraining_applied = False
all_rows = []

# Iterate over percentages and their associated models
for percentage, models in percentage_dict.items():
    for feature_extraction, feature_summary_dict in models.items():
        for model_name, train_summary in feature_summary_dict.items():
            for i, (cv_result, cv_result_eval) in enumerate(zip(train_summary["cv_results"], train_summary["cv_results_eval"])):
            # Prepare training row
                row_train = {
                    "label_col": label_col,
                    "mri_table": mri_table,
                    "test_set_size": f"{(1 - percentage):.2%} (approx. of data left for test)",
                    "Feature_extraction_applied": Feature_extraction_applied,
                    "Pretraining_applied": Pretraining_applied,
                    "model_type": model_name,
                    "Accuracy": cv_result.get("accuracy", None),
                    "AUC": cv_result.get("roc_auc", None),  # Adjust the key if your aggregator uses a different one
                    "Balanced_ACC": cv_result.get("balanced_accuracy", None),
                    "Permutation_Balanced_ACC": cv_result.get("random_balanced_accuracy", None),
                    "number_of_cross_validations": n_splits,
                    "cross_validation_count": i,
                    "search_term": f"{percentage}_{feature_extraction}_{model_name}_train",
                    "percentage_of_data": percentage,  # Storing the used fraction
                    "eval_or_train": "train"
                }

                # Prepare evaluation row
                row_eval = {
                    "label_col": label_col,
                    "mri_table": mri_table,
                    "test_set_size": f"{(1 - percentage):.2%} (approx. of data left for test)",
                    "Feature_extraction_applied": Feature_extraction_applied,
                    "Pretraining_applied": Pretraining_applied,
                    "model_type": model_name,
                    "Accuracy": cv_result_eval.get("accuracy", None),
                    "AUC": cv_result_eval.get("roc_auc", None),  # Adjust the key if your aggregator uses a different one
                    "Balanced_ACC": cv_result_eval.get("balanced_accuracy", None),
                    "Permutation_Balanced_ACC": cv_result_eval.get("random_balanced_accuracy", None),
                    "number_of_cross_validations": n_splits,
                    "cross_validation_count": i,
                    "search_term": f"{percentage}_{feature_extraction}_{model_name}_eval",
                    "percentage_of_data": percentage,  # Storing the used fraction
                    "eval_or_train": "eval"
                }

                # Append both rows to the main list
                all_rows.append(row_train)
                all_rows.append(row_eval)

# Convert the list of dictionaries to a DataFrame
df_results = pd.DataFrame(all_rows)

# Save the DataFrame to a CSV file
df_results.to_csv("results_classification.csv", index=False)

# %%
df_results
# Out:
#            label_col                                     mri_table  \
# 0    label_age_group  aparc.thickness_aseg.volume_aparc.volume.csv
# 1    label_age_group  aparc.thickness_aseg.volume_aparc.volume.csv
# 2    label_age_group  aparc.thickness_aseg.volume_aparc.volume.csv
# 3    label_age_group  aparc.thickness_aseg.volume_aparc.volume.csv
# 4    label_age_group  aparc.thickness_aseg.volume_aparc.volume.csv
# ..               ...                                           ...
# 245  label_age_group  aparc.thickness_aseg.volume_aparc.volume.csv
# 246  label_age_group  aparc.thickness_aseg.volume_aparc.volume.csv
# 247  label_age_group  aparc.thickness_aseg.volume_aparc.volume.csv
# 248  label_age_group  aparc.thickness_aseg.volume_aparc.volume.csv
# 249  label_age_group  aparc.thickness_aseg.volume_aparc.volume.csv
#
#                               test_set_size  Feature_extraction_applied  \
# 0    99.00% (approx. of data left for test)                       False
# 1    99.00% (approx. of data left for test)                       False
# 2    99.00% (approx. of data left for test)                       False
# 3    99.00% (approx. of data left for test)                       False
# 4    99.00% (approx. of data left for test)                       False
# ..                                      ...                         ...
# 245  99.00% (approx. of data left for test)                       False
# 246  99.00% (approx. of data left for test)                       False
# 247  99.00% (approx. of data left for test)                       False
# 248  99.00% (approx. of data left for test)                       False
# 249  99.00% (approx. of data left for test)                       False
#
#      Pretraining_applied model_type  Accuracy       AUC  Balanced_ACC  \
# 0                  False     TabPFN  0.576923  0.848454      0.480952
# 1                  False     TabPFN  0.146552  0.583182      0.258899
# 2                  False     TabPFN  0.423077  0.812356      0.376190
# 3                  False     TabPFN  0.060345  0.546724      0.258192
# 4                  False     TabPFN  0.461538  0.823495      0.361111
# ..                   ...        ...       ...       ...           ...
# 245                False        CNN  0.127155  0.517956      0.154756
# 246                False        CNN  0.423077  0.630166      0.343651
# 247                False        CNN  0.109914  0.519970      0.109992
# 248                False        CNN  0.461538  0.757470      0.399206
# 249                False        CNN  0.103448  0.562562      0.251588
#
#      Permutation_Balanced_ACC  number_of_cross_validations  \
# 0                    0.270833                            5
# 1                    0.187750                            5
# 2                    0.300000                            5
# 3                    0.235600                            5
# 4                    0.141667                            5
# ..                        ...                          ...
# 245                  0.219716                            5
# 246                  0.152778                            5
# 247                  0.161938                            5
# 248                  0.133333                            5
# 249                  0.214912                            5
#
#      cross_validation_count             search_term  percentage_of_data  \
# 0                         0    0.01_BE_TabPFN_train                0.01
# 1                         0     0.01_BE_TabPFN_eval                0.01
# 2                         1    0.01_BE_TabPFN_train                0.01
# 3                         1     0.01_BE_TabPFN_eval                0.01
# 4                         2    0.01_BE_TabPFN_train                0.01
# ..                      ...                     ...                 ...
# 245                       2   0.01_Nothing_CNN_eval                0.01
# 246                       3  0.01_Nothing_CNN_train                0.01
# 247                       3   0.01_Nothing_CNN_eval                0.01
# 248                       4  0.01_Nothing_CNN_train                0.01
# 249                       4   0.01_Nothing_CNN_eval                0.01
#
#     eval_or_train
# 0           train
# 1            eval
# 2           train
# 3            eval
# 4           train
# ..            ...
# 245          eval
# 246         train
# 247          eval
# 248         train
# 249          eval
#
# [250 rows x 15 columns]
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
""" #load a model
import pickle
import os
save_dir = "../98_models/"
with open(os.path.join(save_dir, "tabpfn.pkl"), "rb") as f:
    model = pickle.load(f)
    original_classes = np.unique(y_control)
    results, balanced_accuracy = predict_and_evaluate(model, X_control, y_control, original_classes=original_classes)
    print_model_performance(results) """
# Out:
# ' #load a model\nimport pickle\nimport os\nsave_dir = "../98_models/"\nwith open(os.path.join(save_dir, "tabpfn.pkl"), "rb") as f:\n    model = pickle.load(f)\n    original_classes = np.unique(y_control)\n    results, balanced_accuracy = predict_and_evaluate(model, X_control, y_control, original_classes=original_classes)\n    print_model_performance(results) '

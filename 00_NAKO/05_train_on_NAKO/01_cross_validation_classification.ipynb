# %%
from sklearn.metrics import accuracy_score, roc_auc_score
from sklearn.model_selection import train_test_split, StratifiedKFold
from tabpfn import TabPFNClassifier
import pandas as pd
import os
from tensorflow.keras.models import Sequential
from tensorflow.keras import layers
from scikeras.wrappers import KerasClassifier
import numpy as np
from sklearn.metrics import balanced_accuracy_score, classification_report
import lightgbm as lgb
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import label_binarize
import gc
import torch
from tensorflow.keras import backend as K
import  statsmodels.api as sm
from sklearn.decomposition import PCA
import warnings
warnings.filterwarnings('ignore')

# %%
def create_mlp_model(input_shape, num_classes):
    model = Sequential([
        layers.Dense(1024, activation="relu", input_shape=(input_shape,)),
        layers.Dropout(0.3),
        layers.Dense(512, activation="relu"),
        layers.Dropout(0.3),
        layers.Dense(256, activation="relu"),
        layers.Dropout(0.3),
        layers.Dense(128, activation="relu"),
        layers.Dropout(0.3),
        layers.Dense(num_classes, activation="softmax")
    ])
    model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
    return model

def create_cnn_model(input_shape, num_classes):
    model = Sequential([
        layers.Conv1D(128, kernel_size=3, activation='relu', input_shape=(input_shape[0], 1)),
        layers.MaxPooling1D(pool_size=2),
        layers.Conv1D(64, kernel_size=3, activation='relu'),
        layers.MaxPooling1D(pool_size=2),
        layers.Flatten(),
        layers.Dense(128, activation='relu'),
        layers.Dropout(0.3),
        layers.Dense(num_classes, activation='softmax')
    ])
    model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
    return model

# %%
def clean_up_cuda(model):
    # Delete the Keras model
    K.clear_session()
    del model
    
    # Run garbage collection
    gc.collect()
    
    # Free CUDA memory
    if torch.cuda.is_available():
        torch.cuda.empty_cache()
        torch.cuda.ipc_collect()
    
    print("CUDA memory cleared and model deleted.")

# %%
def feature_extraction_best_corr_with_target(X,X_val, X_control, y, threshold=0.6, df_columns=None, number_of_features=40):
    if isinstance(X, np.ndarray):
        X = pd.DataFrame(X)
        if df_columns is not None:
            X.columns = df_columns
    if isinstance(y, np.ndarray):
        y = pd.Series(y)
    if isinstance(X_val, np.ndarray):
        X_val = pd.DataFrame(X_val)
        if df_columns is not None:
            X_val.columns = df_columns
    if isinstance(X_control, np.ndarray):
        X_control = pd.DataFrame(X_control)
        if df_columns is not None:
            X_control.columns = df_columns
    correlation_matrix = X.corrwith(y).abs()
    to_keep = correlation_matrix.sort_values(ascending=False).head(number_of_features).index
    X = X[to_keep]
    X_val = X_val[to_keep]
    X_control = X_control[to_keep]
    X_ret = X.to_numpy().copy()
    X_val_ret = X_val.to_numpy().copy()
    X_control_ret = X_control.to_numpy().copy()
    return X_ret, X_val_ret, X_control_ret


def feature_extraction_with_Pearson(X, X_val, X_control, y, threshold=0.6, df_columns=None):
    if isinstance(X, np.ndarray):
        X = pd.DataFrame(X)
        if df_columns is not None:
            X.columns = df_columns
    if isinstance(X_val, np.ndarray):
        X_val = pd.DataFrame(X_val)
        if df_columns is not None:
            X_val.columns = df_columns
    if isinstance(X_control, np.ndarray):
        X_control = pd.DataFrame(X_control)
        if df_columns is not None:
            X_control.columns = df_columns
    correlation_matrix = X.corr().abs()
    upper = correlation_matrix.where(np.triu(np.ones(correlation_matrix.shape), k=1).astype(bool))
    to_drop = [column for column in upper.columns if any(upper[column] > threshold)]
    X = X.drop(columns=to_drop)
    X_val = X_val.drop(columns=to_drop)
    X_control = X_control.drop(columns=to_drop)
    X_ret = X.to_numpy().copy()
    X_val_ret = X_val.to_numpy().copy()
    X_control_ret = X_control.to_numpy().copy()
    return X_ret, X_val_ret, X_control_ret

def feature_extration_with_PCA(X, X_val, X_control, n_components):
    pca = PCA(n_components=n_components)
    X_pca = pca.fit_transform(X)
    X_val_pca = pca.transform(X_val)
    X_control_pca = pca.transform(X_control)
    return X_pca, X_val_pca, X_control_pca

def feature_extration_with_BE(X, X_val, X_control, y, significance_level=0.05, df_columns=None):
    if isinstance(X, np.ndarray):
        X = pd.DataFrame(X)
        if df_columns is not None:
            X.columns = df_columns
    if isinstance(X_val, np.ndarray):
        X_val = pd.DataFrame(X_val)
        if df_columns is not None:
            X_val.columns = df_columns
    if isinstance(X_control, np.ndarray):
        X_control = pd.DataFrame(X_control)
        if df_columns is not None:
            X_control.columns = df_columns
    # Add constant for intercept
    X = X.reset_index(drop=True)
    y = y.reset_index(drop=True)
    X = sm.add_constant(X)

    while True:
        # Fit the OLS model
        model = sm.OLS(y, X).fit()
        
        # Get the p-values for each feature
        p_values = model.pvalues
        
        # Find the feature with the highest p-value
        max_p_value = p_values.max()
        
        if max_p_value > significance_level:
            # Remove the feature with the highest p-value
            feature_to_remove = p_values.idxmax()
            print(f"Removing {feature_to_remove} with p-value {max_p_value:.4f}")
            X = X.drop(columns=[feature_to_remove])
            X_val = X_val.drop(columns=[feature_to_remove])
            X_control = X_control.drop(columns=[feature_to_remove])
        else:
            break
        print("Final Feature lengthe: ", len(X.columns))
    # Return the final selected feature set (excluding the intercept)
    X_ret = X.drop(columns=['const']).to_numpy().copy()
    X_val_ret = X_val.to_numpy().copy()
    X_control_ret = X_control.to_numpy().copy()
    return X_ret, X_val_ret, X_control_ret

# %%
# Example usage
def print_model_performance(results):
    """
    Print model performance metrics
    
    Parameters:
    results (dict): Performance metrics from evaluate_model_performance()
    """
    for metric, value in results.items():
        if metric == 'classification_report':
            print("\nClassification Report:")
            print(value)
        else:
            print(f"{metric.replace('_', ' ').title()}: {value}")
def aggregate_cv_metrics_and_print(all_results, model_name, tag="Validation"):
    """
    Aggregate cross-validation metrics
    
    Parameters:
    all_results (list): List of results dictionaries from each fold
    
    Returns:
    dict: Aggregated metrics with means and standard deviations
    """
    # Initialize aggregation dictionary
    aggregated = {
        'accuracy': [],
        'balanced_accuracy': [],
        'random_balanced_accuracy': [],
        'roc_auc': []
    }
    
    # Collect metrics from each fold
    for result in all_results:
        aggregated['accuracy'].append(result['accuracy'])
        aggregated['balanced_accuracy'].append(result['balanced_accuracy'])
        aggregated['random_balanced_accuracy'].append(result['random_balanced_accuracy'])
        aggregated['roc_auc'].append(result['roc_auc'])
    # Compute mean and standard deviation
    summary = {
        'mean_accuracy': np.mean(aggregated['accuracy']),
        'std_accuracy': np.std(aggregated['accuracy']),
        'mean_balanced_accuracy': np.mean(aggregated['balanced_accuracy']),
        'std_balanced_accuracy': np.std(aggregated['balanced_accuracy']),
        'mean_random_balanced_accuracy': np.mean(aggregated['random_balanced_accuracy']),
        'std_random_balanced_accuracy': np.std(aggregated['random_balanced_accuracy']),
        'mean_roc_auc': np.mean(aggregated['roc_auc']),
        'std_roc_auc': np.std(aggregated['roc_auc'])
    }
    
    print(f"\n {model_name} Classifier Performance {tag}:")
    print_model_performance(summary)
    return summary

# %%
mri_table = "aparc.thickness_aseg.volume_aparc.volume.csv"
df = pd.read_csv(f"/zi/home/esra.lenz/Documents/00_HITKIP/09_TABPFN/00_NAKO/00_data/deconfounded_but_age/{mri_table}")
label_df = pd.read_csv("/zi/home/esra.lenz/Documents/00_HITKIP/09_TABPFN/00_NAKO/00_data/age_label/all_ages_all_ids_healthy.csv")
n_splits = 5
label_col= "label_age_group"

label_df = label_df[['ID', 'label_age_group']]
merged_df = pd.merge(df, label_df, on='ID', how='inner')
merged_df.dropna(inplace=True)
df_sampled, _ = train_test_split(merged_df, train_size=10000, stratify=merged_df["label_age_group"], random_state=42)
df_sampled["label_age_group"].value_counts()
# Out:
# label_age_group
# 2.0    2931
# 3.0    2722
# 4.0    2056
# 1.0    1124
# 0.0    1020
# 5.0     147
# Name: count, dtype: int64

# %%
df_control = pd.read_csv("/zi/home/esra.lenz/Documents/00_HITKIP/09_TABPFN/01_Validation_data_set/00_data/final_folder/aparc.thickness_aparc.volume_aseg.volume.csv")
label_df_control = pd.read_csv("/zi/home/esra.lenz/Documents/00_HITKIP/09_TABPFN/01_Validation_data_set/00_data/final_folder/aparc.thickness_aparc.volume_aseg.volume_label.csv")

label_df_control = label_df_control[['ID', 'label_age_group']]
df_control = df_control[df.columns]
merged_df_control = pd.merge(df_control, label_df_control, on='ID', how='inner')
merged_df_control.dropna(inplace=True)

X_control_source = merged_df_control.drop(["ID", "label_age_group"], axis=1)
y_control_source = merged_df_control["label_age_group"]

merged_df_control["label_age_group"].value_counts()
# Out:
# label_age_group
# 0.0    320
# 2.0     76
# 1.0     61
# 3.0      7
# Name: count, dtype: int64

# %%
def evaluate_model_performance_train(y_test, y_pred, y_pred_proba, y_val_bin=None):
    # Compute basic metrics
    acc = accuracy_score(y_test, y_pred)
    balanced_acc = balanced_accuracy_score(y_test, y_pred)
    report = classification_report(y_test, y_pred)
    
    # Random comparison
    n_classes = len(np.unique(y_test))
    random_y_test = np.random.randint(0, n_classes, size=y_test.shape)
    random_balanced_acc = balanced_accuracy_score(random_y_test, y_pred)
    
    # ROC AUC (if probabilities provided)
    if y_val_bin is not None:
        y_test = y_val_bin
    auc = roc_auc_score(y_test, y_pred_proba, multi_class='ovr', average='macro')
    
    # Prepare results
    results = {
        'accuracy': acc,
        'balanced_accuracy': balanced_acc,
        'random_balanced_accuracy': random_balanced_acc,
        'classification_report': report
    }
    
    if auc is not None:
        results['roc_auc'] = auc
    
    return results, balanced_acc

# %%
def predict_and_evaluate(model, X_val, y_val, original_classes=None, multi_class=False):
    if multi_class:
        y_pred_proba = model.predict(X_val)
        y_pred = np.argmax(y_pred_proba, axis=1)
        #print(y_pred)
    else:
        y_pred_proba = model.predict_proba(X_val)
        y_pred = model.predict(X_val)
        #print(y_pred)
    
    # Get unique classes present in validation data
    present_classes = np.unique(y_val)
    
    # Get the indices of these classes in the original prediction probabilities
    class_indices = [np.where(original_classes == cls)[0][0] for cls in present_classes]
    
    # Select only the probability columns for present classes
    y_pred_proba_filtered = y_pred_proba[:, class_indices]
    
    # Binarize the true labels using only the present classes
    y_val_bin = label_binarize(y_val, classes=present_classes)

    results, balanced_acc = evaluate_model_performance_train(y_val, y_pred, y_pred_proba_filtered, y_val_bin)
    print_model_performance(results)
    return results, balanced_acc

# %%
percentage_of_the_data = [0.01]
data = []
percentage_dict = {}
best_mse_mlp = float('inf')
best_mse_lgb = float('inf')
best_mse_tab = float('inf')
deconfounding_strategies = ["BE", "Correlation_in_Feature","Correlation_with_target", "PCA" "Nothing"]
for percentage in percentage_of_the_data:
        percentage_dict[percentage] = {}
        for deconfounding_strategy in deconfounding_strategies:
                print(f"\n=== Deconfounding Strategy: {deconfounding_strategy} ===")
                if percentage == 1:
                        print(f"\n #### TRAINING WITH {percentage} OF THE DATA ####")
                        df_sampled_subset = df_sampled
                else:
                        print(f"\n #### TRAINING WITH {percentage} OF THE DATA ####")
                        df_sampled_subset, _ = train_test_split(
                        df_sampled,
                        train_size=percentage,  # Use train_size to get desired percentage
                        stratify=df_sampled["label_age_group"],
                        random_state=42
                        )

                y = df_sampled_subset["label_age_group"]
                X = df_sampled_subset.drop(["ID", "label_age_group"], axis=1)

                print(f"Training data shape: {X.shape}, length of y: {len(y)}")
                print(f"Training data class distribution: {y.value_counts()}")
                

                skf = StratifiedKFold(n_splits=n_splits, shuffle=True, random_state=42)
                cv_results = {
                        'accuracy': [],
                        'balanced_accuracy': [],
                        'roc_auc': [],
                        'classification_reports': []
                }

                tab_pfn = TabPFNClassifier()

                tabpfn_results = []
                tabpfn_results_eval = []
                lgb_results = []
                lgb_results_eval = []
                random_results = []
                mlp_results = []
                mlp_results_eval = []
                cnn_results = []
                cnn_results_eval = []
                model_dict = {}
                model_results = {}


                best_balanced_accuracy_mlp = 0
                best_balanced_accuracy_tabpfn = 0
                best_balanced_accuracy_lgb = 0
                for fold, (train_index, val_index) in enumerate(skf.split(X, y), 1):
                        unique_classes = np.unique(y)
                        missing_classes = [cls for cls in unique_classes if cls not in y.iloc[val_index]]
                        for cls in missing_classes:
                                cls_indices = np.where(y == cls)[0]  # Get all indices of the missing class
                                # Check if removing a sample would leave train set empty for the class
                                train_cls_indices = np.intersect1d(cls_indices, train_index)

                                if len(train_cls_indices) <= 1:
                                        # If moving the last one, instead take a duplicate from the whole y array
                                        cls_idx_to_move = np.random.choice(cls_indices, 1)[0]
                                else:
                                        cls_idx_to_move = np.random.choice(train_cls_indices, 1)[0]
                                # Add to validation set
                                val_index = np.append(val_index, cls_idx_to_move)
                                # Remove only if it's not the last one in train
                                if len(train_cls_indices) > 1:
                                        train_index = np.setdiff1d(train_index, cls_idx_to_move)
                        print(f"\nFold {fold}")
                        X_train, X_test = X.iloc[train_index], X.iloc[val_index]
                        y_train, y_test = y.iloc[train_index], y.iloc[val_index]
                        X_control = X_control_source.copy()
                        y_control = y_control_source.copy()

                        #scaler = MinMaxScaler()
                        df_columns = X.columns
                        scaler = StandardScaler()
                        X_train_scaled = scaler.fit_transform(X_train)
                        X_test_scaled = scaler.transform(X_test)
                        X_control_scaled = scaler.fit_transform(X_control)
                        if deconfounding_strategy == "BE":
                                X_train, X_test, X_control = feature_extration_with_BE(X_train_scaled, X_test_scaled, X_control_scaled, y_train, df_columns=df_columns)
                        elif deconfounding_strategy == "PCA":
                                X_train, X_test, X_control= feature_extration_with_PCA(X_train_scaled, X_test_scaled, X_control_scaled,  n_components=50)
                        elif deconfounding_strategy == "Correlation_in_Feature":
                                X_train, X_test, X_control = feature_extraction_with_Pearson(X_train_scaled, X_test_scaled, X_control_scaled, y_train, threshold=0.6, df_columns=df_columns)
                        elif deconfounding_strategy == "Correlation_with_target":
                                X_train, X_test, X_control = feature_extraction_best_corr_with_target(X_train_scaled, X_test_scaled, X_control_scaled, y_train, threshold=0.6, df_columns=df_columns)
                        n_classes = len(np.unique(y_test))
                        random_y_test = np.random.randint(0, n_classes, size=y_test.shape)
                        random_y_pred_proba = np.random.rand(len(y_test), n_classes)
                        random_y_pred_proba /= random_y_pred_proba.sum(axis=1)[:, np.newaxis]
                        results, balanced_accuracy  = evaluate_model_performance_train(y_test, random_y_test, random_y_pred_proba)
                        print("RANDOM PERFORMANCE")
                        print_model_performance(results)
                        random_results.append(results)

                        cnnclf = create_cnn_model(input_shape=(X_train.shape[1], 1), num_classes=len(y.unique()))
                        X_train_cnn = X_train.reshape(X_train.shape[0], X_train.shape[1], 1)
                        X_test_cnn = X_test.reshape(X_test.shape[0], X_test.shape[1], 1)
                        X_control_cnn = X_control.reshape(X_control.shape[0], X_control.shape[1], 1)
                        cnnclf.fit(X_train_cnn, pd.get_dummies(y_train), epochs=10, batch_size=32, verbose=0)
                        y_pred_proba = cnnclf.predict(X_test_cnn)
                        y_pred = np.argmax(y_pred_proba, axis=1)
                        results, balanced_accuracy = evaluate_model_performance_train(y_test, y_pred, y_pred_proba)
                        print("CNN PERFORMANCE")
                        print_model_performance(results)
                        cnn_results.append(results)
                        print("CNN PERFORMANCE FOR CONTROL")
                        results, balanced_accuracy = predict_and_evaluate(cnnclf, X_control_cnn, y_control, original_classes = np.unique(y_train), multi_class=True)
                        cnn_results_eval.append(results)
                        clean_up_cuda(cnnclf)

                        mlpclf = create_mlp_model(input_shape=X_train.shape[1], num_classes=len(y.unique()))
                        mlpclf.fit(X_train, pd.get_dummies(y_train), epochs=10, batch_size=32, verbose=0)
                        y_pred_proba = mlpclf.predict(X_test)
                        y_pred = np.argmax(y_pred_proba, axis=1)
                        results, balanced_accuracy = evaluate_model_performance_train(y_test, y_pred, y_pred_proba)
                        print("MLP PERFORMANCE")
                        print_model_performance(results)
                        mlp_results.append(results)
                        #model_dict["mlp"] = mlpclf
                        print("MLP PERFORMANCE FOR CONTROL")
                        results, balanced_accuracy = predict_and_evaluate(mlpclf, X_control, y_control, original_classes = np.unique(y_train), multi_class=True)
                        mlp_results_eval.append(results)
                        if balanced_accuracy > best_balanced_accuracy_mlp:
                                best_balanced_accuracy_mlp = balanced_accuracy
                                model_dict["mlp"] = mlpclf
                        clean_up_cuda(mlpclf)

                        tabclf = TabPFNClassifier()
                        tabclf.fit(X_train, y_train)
                        y_pred_proba = tabclf.predict_proba(X_test)
                        y_pred = tabclf.predict(X_test)
                        results, balanced_accuracy = evaluate_model_performance_train(y_test, y_pred, y_pred_proba)
                        print("tabpfn PERFORMANCE")
                        print_model_performance(results)
                        tabpfn_results.append(results)
                        #model_dict["tabpfn"] = tabclf
                        original_classes = tabclf.classes_
                        print("tabpfn PERFORMANCE FOR CONTROL")
                        results, balanced_accuracy = predict_and_evaluate(tabclf, X_control, y_control, original_classes=original_classes)
                        tabpfn_results_eval.append(results)
                        if balanced_accuracy > best_balanced_accuracy_tabpfn:
                                best_balanced_accuracy_tabpfn = balanced_accuracy
                                model_dict["tabpfn"] = tabclf
                        clean_up_cuda(tabclf)
                        
                        lgb_train = lgb.Dataset(X_train, label=y_train)
                        lgb_eval = lgb.Dataset(X_test, label=y_test, reference=lgb_train)
                        params = {
                        'objective': 'multiclass',
                        'num_class': len(y.unique()),
                        'metric': 'multi_logloss',
                        'num_leaves': 31,
                        'learning_rate': 0.05,
                        'feature_fraction': 0.9,
                        'seed': 42,
                        'verbose': -1
                        }
                        lgbclf = lgb.train(params, lgb_train, valid_sets=[lgb_train, lgb_eval], num_boost_round=1000)
                        y_pred_proba = lgbclf.predict(X_test)
                        y_pred = np.argmax(y_pred_proba, axis=1)
                        results, balanced_accuracy = evaluate_model_performance_train(y_test, y_pred, y_pred_proba)
                        print("LGBM PERFORMANCE")
                        print_model_performance(results)
                        lgb_results.append(results)
                        print("LGBM PERFORMANCE FOR CONTROL")
                        results, balanced_accuracy = predict_and_evaluate(lgbclf, X_control, y_control, original_classes=original_classes, multi_class=True)
                        lgb_results_eval.append(results)
                        if balanced_accuracy > best_balanced_accuracy_lgb:
                                best_balanced_accuracy_lgb = balanced_accuracy
                                model_dict["lgb"] = lgbclf
                        clean_up_cuda(lgbclf)

                random_summary = aggregate_cv_metrics_and_print(random_results, "Random")
                tabpfn_summary = aggregate_cv_metrics_and_print(tabpfn_results, "TabPFN")
                lgb_summary = aggregate_cv_metrics_and_print(lgb_results, "LGBM")
                mlp_summary = aggregate_cv_metrics_and_print(mlp_results, "MLP")
                cnn_summary = aggregate_cv_metrics_and_print(cnn_results, "CNN")

                tabpfn_eval_summary = aggregate_cv_metrics_and_print(tabpfn_results_eval, "TabPFN", "Control")
                lgb_eval_summary = aggregate_cv_metrics_and_print(lgb_results_eval, "LGBM", "Control")
                mlp_eval_summary = aggregate_cv_metrics_and_print(mlp_results_eval, "MLP", "Control")
                cnn_eval_summary = aggregate_cv_metrics_and_print(cnn_results_eval, "CNN", "Control")

                percentage_dict[percentage][deconfounding_strategy] = {
                "TabPFN": {
                        "results": tabpfn_summary,
                        "results_eval": tabpfn_eval_summary,
                        "cv_results": tabpfn_results,
                        "cv_results_eval": tabpfn_results_eval
                },
                "LGBM": {
                        "results": lgb_summary,
                        "results_eval": lgb_eval_summary,
                        "cv_results": lgb_results,
                        "cv_results_eval": lgb_results_eval
                },
                "Random": {
                        "results": random_summary,
                        "results_eval": random_summary,
                        "cv_results": random_results,
                        "cv_results_eval": random_results,

                },
                "MLP": {
                        "results": mlp_summary,
                        "results_eval": mlp_eval_summary,
                        "cv_results": mlp_results,
                        "cv_results_eval": mlp_results_eval
                },
                "CNN": {
                        "results": cnn_summary,
                        "results_eval": cnn_eval_summary,
                        "cv_results": cnn_results,
                        "cv_results_eval": cnn_results_eval
                }
        }
# Out:
# === Deconfounding Strategy: BE ===
#
#  #### TRAINING WITH 0.01 OF THE DATA ####
# Training data shape: (100, 192), length of y: 100
# Training data class distribution: label_age_group
# 2.0    29
# 3.0    27
# 4.0    21
# 1.0    11
# 0.0    10
# 5.0     2
# Name: count, dtype: int64
#
# Fold 1
# RANDOM PERFORMANCE
# Accuracy: 0.15384615384615385
# Balanced Accuracy: 0.10476190476190476
# Random Balanced Accuracy: 0.1111111111111111
#
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       0.00      0.00      0.00         3
#          1.0       0.00      0.00      0.00         3
#          2.0       0.00      0.00      0.00         7
#          3.0       0.60      0.43      0.50         7
#          4.0       0.50      0.20      0.29         5
#          5.0       0.00      0.00      0.00         1
#
#     accuracy                           0.15        26
#    macro avg       0.18      0.10      0.13        26
# weighted avg       0.26      0.15      0.19        26
#
# Roc Auc: 0.5150223384548328
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# CNN PERFORMANCE
# Accuracy: 0.4230769230769231
# Balanced Accuracy: 0.33174603174603173
# Random Balanced Accuracy: 0.15
#
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       1.00      0.33      0.50         3
#          1.0       0.00      0.00      0.00         3
#          2.0       0.30      0.43      0.35         7
#          3.0       0.43      0.43      0.43         7
#          4.0       0.50      0.80      0.62         5
#          5.0       0.00      0.00      0.00         1
#
#     accuracy                           0.42        26
#    macro avg       0.37      0.33      0.32        26
# weighted avg       0.41      0.42      0.39        26
#
# Roc Auc: 0.6531190294577022
# CNN PERFORMANCE FOR CONTROL
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Accuracy: 0.09698275862068965
# Balanced Accuracy: 0.09114605802415876
# Random Balanced Accuracy: 0.16865693645879404
#
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       1.00      0.07      0.13       320
#          1.0       0.50      0.02      0.03        61
#          2.0       0.14      0.28      0.19        76
#          3.0       0.00      0.00      0.00         7
#          4.0       0.00      0.00      0.00         0
#
#     accuracy                           0.10       464
#    macro avg       0.33      0.07      0.07       464
# weighted avg       0.78      0.10      0.13       464
#
# Roc Auc: 0.5349723195083764
# CUDA memory cleared and model deleted.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# MLP PERFORMANCE
# Accuracy: 0.4230769230769231
# Balanced Accuracy: 0.3126984126984127
# Random Balanced Accuracy: 0.16666666666666666
#
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       1.00      0.33      0.50         3
#          1.0       0.00      0.00      0.00         3
#          2.0       0.40      0.86      0.55         7
#          3.0       0.33      0.29      0.31         7
#          4.0       0.50      0.40      0.44         5
#          5.0       0.00      0.00      0.00         1
#
#     accuracy                           0.42        26
#    macro avg       0.37      0.31      0.30        26
# weighted avg       0.41      0.42      0.37        26
#
# Roc Auc: 0.5974392502996622
# MLP PERFORMANCE FOR CONTROL
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Accuracy: 0.1400862068965517
# Balanced Accuracy: 0.19375
# Random Balanced Accuracy: 0.2436209645406209
#
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       1.00      0.03      0.05       320
#          1.0       0.00      0.00      0.00        61
#          2.0       0.22      0.75      0.35        76
#          3.0       0.00      0.00      0.00         7
#          4.0       0.00      0.00      0.00         0
#
#     accuracy                           0.14       464
#    macro avg       0.24      0.15      0.08       464
# weighted avg       0.73      0.14      0.09       464
#
# Roc Auc: 0.5340608754586642
# CUDA memory cleared and model deleted.
# tabpfn PERFORMANCE
# Accuracy: 0.46153846153846156
# Balanced Accuracy: 0.38730158730158726
# Random Balanced Accuracy: 0.18333333333333335
#
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       0.00      0.00      0.00         3
#          1.0       0.67      0.67      0.67         3
#          2.0       0.30      0.43      0.35         7
#          3.0       0.38      0.43      0.40         7
#          4.0       0.80      0.80      0.80         5
#          5.0       0.00      0.00      0.00         1
#
#     accuracy                           0.46        26
#    macro avg       0.36      0.39      0.37        26
# weighted avg       0.41      0.46      0.43        26
#
# Roc Auc: 0.8109483854563947
# tabpfn PERFORMANCE FOR CONTROL
# Accuracy: 0.11637931034482758
# Balanced Accuracy: 0.32106293525822754
# Random Balanced Accuracy: 0.21823856069715425
#
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       0.85      0.03      0.07       320
#          1.0       0.24      0.18      0.21        61
#          2.0       0.18      0.36      0.24        76
#          3.0       0.03      0.71      0.05         7
#          4.0       0.00      0.00      0.00         0
#
#     accuracy                           0.12       464
#    macro avg       0.26      0.26      0.11       464
# weighted avg       0.65      0.12      0.11       464
#
# Roc Auc: 0.5551386318328041
# CUDA memory cleared and model deleted.
# LGBM PERFORMANCE
# Accuracy: 0.3076923076923077
# Balanced Accuracy: 0.2634920634920635
# Random Balanced Accuracy: 0.20833333333333334
#
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       0.50      0.33      0.40         3
#          1.0       0.50      0.33      0.40         3
#          2.0       0.25      0.43      0.32         7
#          3.0       0.25      0.29      0.27         7
#          4.0       0.50      0.20      0.29         5
#          5.0       0.00      0.00      0.00         1
#
#     accuracy                           0.31        26
#    macro avg       0.33      0.26      0.28        26
# weighted avg       0.35      0.31      0.30        26
#
# Roc Auc: 0.7436831208455922
# LGBM PERFORMANCE FOR CONTROL
# Accuracy: 0.10344827586206896
# Balanced Accuracy: 0.23653906153703932
# Random Balanced Accuracy: 0.17682273369674945
#
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       0.95      0.07      0.12       320
#          1.0       0.10      0.03      0.05        61
#          2.0       0.15      0.28      0.20        76
#          3.0       0.02      0.57      0.05         7
#          4.0       0.00      0.00      0.00         0
#          5.0       0.00      0.00      0.00         0
#
#     accuracy                           0.10       464
#    macro avg       0.20      0.16      0.07       464
# weighted avg       0.70      0.10      0.12       464
#
# Roc Auc: 0.5825693337403437
# CUDA memory cleared and model deleted.
#
# Fold 2
# RANDOM PERFORMANCE
# Accuracy: 0.07692307692307693
# Balanced Accuracy: 0.047619047619047616
# Random Balanced Accuracy: 0.15277777777777776
#
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       0.00      0.00      0.00         3
#          1.0       0.00      0.00      0.00         3
#          2.0       0.00      0.00      0.00         7
#          3.0       0.67      0.29      0.40         7
#          4.0       0.00      0.00      0.00         5
#          5.0       0.00      0.00      0.00         1
#
#     accuracy                           0.08        26
#    macro avg       0.11      0.05      0.07        26
# weighted avg       0.18      0.08      0.11        26
#
# Roc Auc: 0.5052413642802659
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# CNN PERFORMANCE
# Accuracy: 0.38461538461538464
# Balanced Accuracy: 0.2984126984126984
# Random Balanced Accuracy: 0.30357142857142855
#
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       0.33      0.33      0.33         3
#          1.0       0.00      0.00      0.00         3
#          2.0       0.30      0.43      0.35         7
#          3.0       0.38      0.43      0.40         7
#          4.0       0.60      0.60      0.60         5
#          5.0       0.00      0.00      0.00         1
#
#     accuracy                           0.38        26
#    macro avg       0.27      0.30      0.28        26
# weighted avg       0.34      0.38      0.36        26
#
# Roc Auc: 0.6702865860302931
# CNN PERFORMANCE FOR CONTROL
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Accuracy: 0.09482758620689655
# Balanced Accuracy: 0.22928806390977444
# Random Balanced Accuracy: 0.2000449977501125
#
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       1.00      0.06      0.11       320
#          1.0       0.00      0.00      0.00        61
#          2.0       0.13      0.29      0.18        76
#          3.0       0.02      0.57      0.04         7
#          4.0       0.00      0.00      0.00         0
#
#     accuracy                           0.09       464
#    macro avg       0.23      0.18      0.06       464
# weighted avg       0.71      0.09      0.10       464
#
# Roc Auc: 0.5635103173487825
# CUDA memory cleared and model deleted.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# MLP PERFORMANCE
# Accuracy: 0.4230769230769231
# Balanced Accuracy: 0.373015873015873
# Random Balanced Accuracy: 0.1277777777777778
#
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       0.33      0.67      0.44         3
#          1.0       0.00      0.00      0.00         3
#          2.0       0.40      0.29      0.33         7
#          3.0       0.40      0.29      0.33         7
#          4.0       0.56      1.00      0.71         5
#          5.0       0.00      0.00      0.00         1
#
#     accuracy                           0.42        26
#    macro avg       0.28      0.37      0.30        26
# weighted avg       0.36      0.42      0.37        26
#
# Roc Auc: 0.7649057426174131
# MLP PERFORMANCE FOR CONTROL
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Accuracy: 0.1788793103448276
# Balanced Accuracy: 0.15513980263157895
# Random Balanced Accuracy: 0.18229806019958922
#
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       1.00      0.15      0.26       320
#          1.0       0.00      0.00      0.00        61
#          2.0       0.21      0.47      0.29        76
#          3.0       0.00      0.00      0.00         7
#          4.0       0.00      0.00      0.00         0
#
#     accuracy                           0.18       464
#    macro avg       0.24      0.12      0.11       464
# weighted avg       0.72      0.18      0.22       464
#
# Roc Auc: 0.5511657345909258
# CUDA memory cleared and model deleted.
# tabpfn PERFORMANCE
# Accuracy: 0.46153846153846156
# Balanced Accuracy: 0.3968253968253968
# Random Balanced Accuracy: 0.07142857142857142
#
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       0.40      0.67      0.50         3
#          1.0       0.00      0.00      0.00         3
#          2.0       0.30      0.43      0.35         7
#          3.0       0.40      0.29      0.33         7
#          4.0       0.83      1.00      0.91         5
#          5.0       0.00      0.00      0.00         1
#
#     accuracy                           0.46        26
#    macro avg       0.32      0.40      0.35        26
# weighted avg       0.39      0.46      0.42        26
#
# Roc Auc: 0.8125335076822492
# tabpfn PERFORMANCE FOR CONTROL
# Accuracy: 0.08836206896551724
# Balanced Accuracy: 0.2575882264575373
# Random Balanced Accuracy: 0.19826575128792948
#
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       0.94      0.05      0.10       320
#          1.0       0.24      0.07      0.10        61
#          2.0       0.08      0.20      0.11        76
#          3.0       0.03      0.71      0.06         7
#          4.0       0.00      0.00      0.00         0
#
#     accuracy                           0.09       464
#    macro avg       0.26      0.21      0.08       464
# weighted avg       0.70      0.09      0.10       464
#
# Roc Auc: 0.5620698484803207
# CUDA memory cleared and model deleted.
# LGBM PERFORMANCE
# Accuracy: 0.46153846153846156
# Balanced Accuracy: 0.38730158730158726
# Random Balanced Accuracy: 0.2337301587301587
#
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       0.40      0.67      0.50         3
#          1.0       0.00      0.00      0.00         3
#          2.0       0.33      0.29      0.31         7
#          3.0       0.57      0.57      0.57         7
#          4.0       0.67      0.80      0.73         5
#          5.0       0.00      0.00      0.00         1
#
#     accuracy                           0.46        26
#    macro avg       0.33      0.39      0.35        26
# weighted avg       0.42      0.46      0.43        26
#
# Roc Auc: 0.706593294831281
# LGBM PERFORMANCE FOR CONTROL
# Accuracy: 0.11637931034482758
# Balanced Accuracy: 0.1746776007642056
# Random Balanced Accuracy: 0.2110694376127234
#
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       1.00      0.09      0.16       320
#          1.0       0.09      0.05      0.06        61
#          2.0       0.12      0.28      0.17        76
#          3.0       0.01      0.29      0.03         7
#          4.0       0.00      0.00      0.00         0
#          5.0       0.00      0.00      0.00         0
#
#     accuracy                           0.12       464
#    macro avg       0.20      0.12      0.07       464
# weighted avg       0.72      0.12      0.15       464
#
# Roc Auc: 0.5310164366490956
# CUDA memory cleared and model deleted.
#
# Fold 3
# RANDOM PERFORMANCE
# Accuracy: 0.2692307692307692
# Balanced Accuracy: 0.24999999999999997
# Random Balanced Accuracy: 0.02857142857142857
#
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       0.14      0.33      0.20         3
#          1.0       0.50      0.50      0.50         4
#          2.0       0.50      0.17      0.25         6
#          3.0       0.33      0.17      0.22         6
#          4.0       0.29      0.33      0.31         6
#          5.0       0.00      0.00      0.00         1
#
#     accuracy                           0.27        26
#    macro avg       0.29      0.25      0.25        26
# weighted avg       0.35      0.27      0.28        26
#
# Roc Auc: 0.4935638998682477
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# CNN PERFORMANCE
# Accuracy: 0.4230769230769231
# Balanced Accuracy: 0.3611111111111111
# Random Balanced Accuracy: 0.15555555555555553
#
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       0.40      0.67      0.50         3
#          1.0       0.00      0.00      0.00         4
#          2.0       0.17      0.17      0.17         6
#          3.0       0.50      0.67      0.57         6
#          4.0       0.57      0.67      0.62         6
#          5.0       0.00      0.00      0.00         1
#
#     accuracy                           0.42        26
#    macro avg       0.27      0.36      0.31        26
# weighted avg       0.33      0.42      0.37        26
#
# Roc Auc: 0.748756038647343
# CNN PERFORMANCE FOR CONTROL
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Accuracy: 0.1336206896551724
# Balanced Accuracy: 0.17411128358806852
# Random Balanced Accuracy: 0.18509853288835776
#
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       0.98      0.16      0.27       320
#          1.0       0.09      0.02      0.03        61
#          2.0       0.09      0.09      0.09        76
#          3.0       0.01      0.43      0.03         7
#          4.0       0.00      0.00      0.00         0
#
#     accuracy                           0.13       464
#    macro avg       0.23      0.14      0.08       464
# weighted avg       0.70      0.13      0.21       464
#
# Roc Auc: 0.5827296056029678
# CUDA memory cleared and model deleted.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# MLP PERFORMANCE
# Accuracy: 0.4230769230769231
# Balanced Accuracy: 0.3333333333333333
# Random Balanced Accuracy: 0.22103174603174602
#
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       0.25      0.33      0.29         3
#          1.0       0.00      0.00      0.00         4
#          2.0       0.31      0.67      0.42         6
#          3.0       0.60      0.50      0.55         6
#          4.0       0.75      0.50      0.60         6
#          5.0       0.00      0.00      0.00         1
#
#     accuracy                           0.42        26
#    macro avg       0.32      0.33      0.31        26
# weighted avg       0.41      0.42      0.39        26
#
# Roc Auc: 0.649370882740448
# MLP PERFORMANCE FOR CONTROL
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Accuracy: 0.10991379310344827
# Balanced Accuracy: 0.1949894266917293
# Random Balanced Accuracy: 0.17109399306425055
#
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       1.00      0.05      0.09       320
#          1.0       0.00      0.00      0.00        61
#          2.0       0.16      0.45      0.23        76
#          3.0       0.01      0.29      0.03         7
#          4.0       0.00      0.00      0.00         0
#
#     accuracy                           0.11       464
#    macro avg       0.23      0.16      0.07       464
# weighted avg       0.72      0.11      0.10       464
#
# Roc Auc: 0.5657447787385084
# CUDA memory cleared and model deleted.
# tabpfn PERFORMANCE
# Accuracy: 0.4230769230769231
# Balanced Accuracy: 0.34722222222222215
# Random Balanced Accuracy: 0.2111111111111111
#
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       0.50      0.33      0.40         3
#          1.0       0.25      0.25      0.25         4
#          2.0       0.30      0.50      0.38         6
#          3.0       0.40      0.33      0.36         6
#          4.0       0.80      0.67      0.73         6
#          5.0       0.00      0.00      0.00         1
#
#     accuracy                           0.42        26
#    macro avg       0.38      0.35      0.35        26
# weighted avg       0.44      0.42      0.42        26
#
# Roc Auc: 0.7956422924901184
# tabpfn PERFORMANCE FOR CONTROL
# Accuracy: 0.09698275862068965
# Balanced Accuracy: 0.29726403611487734
# Random Balanced Accuracy: 0.18740065178012216
#
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       0.87      0.06      0.12       320
#          1.0       0.24      0.10      0.14        61
#          2.0       0.09      0.17      0.12        76
#          3.0       0.03      0.86      0.06         7
#          4.0       0.00      0.00      0.00         0
#
#     accuracy                           0.10       464
#    macro avg       0.25      0.24      0.09       464
# weighted avg       0.65      0.10      0.12       464
#
# Roc Auc: 0.5143835002873118
# CUDA memory cleared and model deleted.
# LGBM PERFORMANCE
# Accuracy: 0.5
# Balanced Accuracy: 0.40277777777777773
# Random Balanced Accuracy: 0.1765873015873016
#
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       0.50      0.33      0.40         3
#          1.0       0.33      0.25      0.29         4
#          2.0       0.36      0.67      0.47         6
#          3.0       0.60      0.50      0.55         6
#          4.0       0.80      0.67      0.73         6
#          5.0       0.00      0.00      0.00         1
#
#     accuracy                           0.50        26
#    macro avg       0.43      0.40      0.40        26
# weighted avg       0.52      0.50      0.49        26
#
# Roc Auc: 0.6904984628897672
# LGBM PERFORMANCE FOR CONTROL
# Accuracy: 0.09482758620689655
# Balanced Accuracy: 0.11777317268581289
# Random Balanced Accuracy: 0.17426195176480905
#
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       0.96      0.07      0.14       320
#          1.0       0.04      0.02      0.02        61
#          2.0       0.11      0.24      0.15        76
#          3.0       0.01      0.14      0.01         7
#          4.0       0.00      0.00      0.00         0
#          5.0       0.00      0.00      0.00         0
#
#     accuracy                           0.09       464
#    macro avg       0.19      0.08      0.05       464
# weighted avg       0.69      0.09      0.12       464
#
# Roc Auc: 0.4233024491848836
# CUDA memory cleared and model deleted.
#
# Fold 4
# RANDOM PERFORMANCE
# Accuracy: 0.2692307692307692
# Balanced Accuracy: 0.2714285714285714
# Random Balanced Accuracy: 0.09351851851851851
#
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       0.00      0.00      0.00         3
#          1.0       0.17      0.33      0.22         3
#          2.0       0.60      0.43      0.50         7
#          3.0       0.20      0.17      0.18         6
#          4.0       0.25      0.20      0.22         5
#          5.0       0.33      0.50      0.40         2
#
#     accuracy                           0.27        26
#    macro avg       0.26      0.27      0.25        26
# weighted avg       0.30      0.27      0.28        26
#
# Roc Auc: 0.4478839762449602
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# CNN PERFORMANCE
# Accuracy: 0.2692307692307692
# Balanced Accuracy: 0.1880952380952381
# Random Balanced Accuracy: 0.15277777777777776
#
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       0.00      0.00      0.00         3
#          1.0       0.00      0.00      0.00         3
#          2.0       0.50      0.43      0.46         7
#          3.0       0.23      0.50      0.32         6
#          4.0       0.17      0.20      0.18         5
#          5.0       0.00      0.00      0.00         2
#
#     accuracy                           0.27        26
#    macro avg       0.15      0.19      0.16        26
# weighted avg       0.22      0.27      0.23        26
#
# Roc Auc: 0.5568091424212706
# CNN PERFORMANCE FOR CONTROL
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Accuracy: 0.0603448275862069
# Balanced Accuracy: 0.04857501078515962
# Random Balanced Accuracy: 0.2032051239297356
#
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       0.90      0.06      0.11       320
#          1.0       0.10      0.03      0.05        61
#          2.0       0.08      0.11      0.09        76
#          3.0       0.00      0.00      0.00         7
#          4.0       0.00      0.00      0.00         0
#
#     accuracy                           0.06       464
#    macro avg       0.22      0.04      0.05       464
# weighted avg       0.65      0.06      0.09       464
#
# Roc Auc: 0.47991334948542247
# CUDA memory cleared and model deleted.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# MLP PERFORMANCE
# Accuracy: 0.4230769230769231
# Balanced Accuracy: 0.33968253968253964
# Random Balanced Accuracy: 0.09444444444444444
#
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       1.00      0.33      0.50         3
#          1.0       0.00      0.00      0.00         3
#          2.0       0.40      0.57      0.47         7
#          3.0       0.50      0.33      0.40         6
#          4.0       0.40      0.80      0.53         5
#          5.0       0.00      0.00      0.00         2
#
#     accuracy                           0.42        26
#    macro avg       0.38      0.34      0.32        26
# weighted avg       0.42      0.42      0.38        26
#
# Roc Auc: 0.5727252914895936
# MLP PERFORMANCE FOR CONTROL
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Accuracy: 0.10129310344827586
# Balanced Accuracy: 0.12764159373844447
# Random Balanced Accuracy: 0.1724466057600029
#
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       1.00      0.07      0.14       320
#          1.0       0.04      0.02      0.02        61
#          2.0       0.14      0.28      0.18        76
#          3.0       0.01      0.14      0.02         7
#          4.0       0.00      0.00      0.00         0
#
#     accuracy                           0.10       464
#    macro avg       0.24      0.10      0.07       464
# weighted avg       0.72      0.10      0.13       464
#
# Roc Auc: 0.5219173666247123
# CUDA memory cleared and model deleted.
# tabpfn PERFORMANCE
# Accuracy: 0.4230769230769231
# Balanced Accuracy: 0.392063492063492
# Random Balanced Accuracy: 0.34722222222222227
#
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       0.00      0.00      0.00         3
#          1.0       0.50      1.00      0.67         3
#          2.0       0.50      0.29      0.36         7
#          3.0       0.44      0.67      0.53         6
#          4.0       0.29      0.40      0.33         5
#          5.0       0.00      0.00      0.00         2
#
#     accuracy                           0.42        26
#    macro avg       0.29      0.39      0.32        26
# weighted avg       0.35      0.42      0.36        26
#
# Roc Auc: 0.7893338418510042
# tabpfn PERFORMANCE FOR CONTROL
# Accuracy: 0.16163793103448276
# Balanced Accuracy: 0.24591955041291758
# Random Balanced Accuracy: 0.21910942183492477
#
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       0.74      0.13      0.22       320
#          1.0       0.20      0.15      0.17        61
#          2.0       0.20      0.28      0.23        76
#          3.0       0.02      0.43      0.04         7
#          4.0       0.00      0.00      0.00         0
#
#     accuracy                           0.16       464
#    macro avg       0.23      0.20      0.13       464
# weighted avg       0.57      0.16      0.21       464
#
# Roc Auc: 0.5363027995667836
# CUDA memory cleared and model deleted.
# LGBM PERFORMANCE
# Accuracy: 0.2692307692307692
# Balanced Accuracy: 0.1992063492063492
# Random Balanced Accuracy: 0.1111111111111111
#
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       0.00      0.00      0.00         3
#          1.0       0.00      0.00      0.00         3
#          2.0       0.43      0.43      0.43         7
#          3.0       0.11      0.17      0.13         6
#          4.0       0.38      0.60      0.46         5
#          5.0       0.00      0.00      0.00         2
#
#     accuracy                           0.27        26
#    macro avg       0.15      0.20      0.17        26
# weighted avg       0.21      0.27      0.23        26
#
# Roc Auc: 0.5331934909738113
# LGBM PERFORMANCE FOR CONTROL
# Accuracy: 0.09051724137931035
# Balanced Accuracy: 0.126243567422655
# Random Balanced Accuracy: 0.1627696494557076
#
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       1.00      0.06      0.11       320
#          1.0       0.04      0.02      0.02        61
#          2.0       0.15      0.29      0.19        76
#          3.0       0.01      0.14      0.01         7
#          4.0       0.00      0.00      0.00         0
#          5.0       0.00      0.00      0.00         0
#
#     accuracy                           0.09       464
#    macro avg       0.20      0.08      0.06       464
# weighted avg       0.72      0.09      0.11       464
#
# Roc Auc: 0.4834461729104872
# CUDA memory cleared and model deleted.
#
# Fold 5
# RANDOM PERFORMANCE
# Accuracy: 0.11538461538461539
# Balanced Accuracy: 0.14444444444444446
# Random Balanced Accuracy: 0.25595238095238093
#
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       0.00      0.00      0.00         3
#          1.0       0.00      0.00      0.00         3
#          2.0       0.00      0.00      0.00         7
#          3.0       0.33      0.17      0.22         6
#          4.0       0.17      0.20      0.18         5
#          5.0       0.20      0.50      0.29         2
#
#     accuracy                           0.12        26
#    macro avg       0.12      0.14      0.11        26
# weighted avg       0.12      0.12      0.11        26
#
# Roc Auc: 0.5423088972431077
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# CNN PERFORMANCE
# Accuracy: 0.38461538461538464
# Balanced Accuracy: 0.30873015873015874
# Random Balanced Accuracy: 0.2238095238095238
#
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       1.00      0.33      0.50         3
#          1.0       0.00      0.00      0.00         3
#          2.0       0.33      0.29      0.31         7
#          3.0       0.36      0.83      0.50         6
#          4.0       0.40      0.40      0.40         5
#          5.0       0.00      0.00      0.00         2
#
#     accuracy                           0.38        26
#    macro avg       0.35      0.31      0.28        26
# weighted avg       0.36      0.38      0.33        26
#
# Roc Auc: 0.6482406196651048
# CNN PERFORMANCE FOR CONTROL
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Accuracy: 0.11422413793103449
# Balanced Accuracy: 0.23130286654135337
# Random Balanced Accuracy: 0.2056071510887083
#
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       0.94      0.09      0.17       320
#          1.0       0.00      0.00      0.00        61
#          2.0       0.19      0.26      0.22        76
#          3.0       0.01      0.57      0.03         7
#          4.0       0.00      0.00      0.00         0
#
#     accuracy                           0.11       464
#    macro avg       0.23      0.19      0.08       464
# weighted avg       0.68      0.11      0.15       464
#
# Roc Auc: 0.5825694944842231
# CUDA memory cleared and model deleted.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# MLP PERFORMANCE
# Accuracy: 0.3076923076923077
# Balanced Accuracy: 0.2571428571428571
# Random Balanced Accuracy: 0.15
#
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       1.00      0.33      0.50         3
#          1.0       0.00      0.00      0.00         3
#          2.0       0.12      0.14      0.13         7
#          3.0       0.50      0.67      0.57         6
#          4.0       0.33      0.40      0.36         5
#          5.0       0.00      0.00      0.00         2
#
#     accuracy                           0.31        26
#    macro avg       0.33      0.26      0.26        26
# weighted avg       0.33      0.31      0.30        26
#
# Roc Auc: 0.6624273546184302
# MLP PERFORMANCE FOR CONTROL
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Accuracy: 0.12284482758620689
# Balanced Accuracy: 0.16959721280660667
# Random Balanced Accuracy: 0.2218891195157796
#
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       1.00      0.07      0.13       320
#          1.0       0.10      0.10      0.10        61
#          2.0       0.16      0.37      0.22        76
#          3.0       0.01      0.14      0.01         7
#          4.0       0.00      0.00      0.00         0
#
#     accuracy                           0.12       464
#    macro avg       0.25      0.14      0.09       464
# weighted avg       0.73      0.12      0.14       464
#
# Roc Auc: 0.5213808529284987
# CUDA memory cleared and model deleted.
# tabpfn PERFORMANCE
# Accuracy: 0.4230769230769231
# Balanced Accuracy: 0.3436507936507936
# Random Balanced Accuracy: 0.2833333333333333
#
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       0.00      0.00      0.00         3
#          1.0       0.17      0.33      0.22         3
#          2.0       0.60      0.43      0.50         7
#          3.0       0.50      0.50      0.50         6
#          4.0       0.44      0.80      0.57         5
#          5.0       0.00      0.00      0.00         2
#
#     accuracy                           0.42        26
#    macro avg       0.29      0.34      0.30        26
# weighted avg       0.38      0.42      0.39        26
#
# Roc Auc: 0.8035441865533398
# tabpfn PERFORMANCE FOR CONTROL
# Accuracy: 0.05387931034482758
# Balanced Accuracy: 0.25325865894243804
# Random Balanced Accuracy: 0.22563555515630612
#
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       0.00      0.00      0.00       320
#          1.0       0.29      0.18      0.22        61
#          2.0       0.06      0.12      0.08        76
#          3.0       0.03      0.71      0.05         7
#          4.0       0.00      0.00      0.00         0
#
#     accuracy                           0.05       464
#    macro avg       0.08      0.20      0.07       464
# weighted avg       0.05      0.05      0.04       464
#
# Roc Auc: 0.5435069469963242
# CUDA memory cleared and model deleted.
# LGBM PERFORMANCE
# Accuracy: 0.34615384615384615
# Balanced Accuracy: 0.28650793650793654
# Random Balanced Accuracy: 0.20833333333333334
#
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       1.00      0.33      0.50         3
#          1.0       0.00      0.00      0.00         3
#          2.0       0.25      0.29      0.27         7
#          3.0       0.33      0.50      0.40         6
#          4.0       0.50      0.60      0.55         5
#          5.0       0.00      0.00      0.00         2
#
#     accuracy                           0.35        26
#    macro avg       0.35      0.29      0.29        26
# weighted avg       0.36      0.35      0.33        26
#
# Roc Auc: 0.5918737060041407
# LGBM PERFORMANCE FOR CONTROL
# Accuracy: 0.10560344827586207
# Balanced Accuracy: 0.22164417832491062
# Random Balanced Accuracy: 0.20661752457104782
#
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       0.94      0.05      0.09       320
#          1.0       0.05      0.02      0.03        61
#          2.0       0.18      0.39      0.24        76
#          3.0       0.02      0.43      0.04         7
#          4.0       0.00      0.00      0.00         0
#          5.0       0.00      0.00      0.00         0
#
#     accuracy                           0.11       464
#    macro avg       0.20      0.15      0.07       464
# weighted avg       0.68      0.11      0.11       464
#
# Roc Auc: 0.5246986995432179
# CUDA memory cleared and model deleted.
#
#  Random Classifier Performance Validation:
# Mean Accuracy: 0.1769230769230769
# Std Accuracy: 0.07919715493066921
# Mean Balanced Accuracy: 0.16365079365079366
# Std Balanced Accuracy: 0.08529054577317886
# Mean Random Balanced Accuracy: 0.12838624338624335
# Std Random Balanced Accuracy: 0.0752930967521015
# Mean Roc Auc: 0.5008040952182828
# Std Roc Auc: 0.030975654341560993
#
#  TabPFN Classifier Performance Validation:
# Mean Accuracy: 0.4384615384615385
# Std Accuracy: 0.018842228790639844
# Mean Balanced Accuracy: 0.3734126984126983
# Std Balanced Accuracy: 0.023067812221695183
# Mean Random Balanced Accuracy: 0.2192857142857143
# Std Random Balanced Accuracy: 0.09347831844416331
# Mean Roc Auc: 0.8024004428066212
# Std Roc Auc: 0.008870886464265431
#
#  LGBM Classifier Performance Validation:
# Mean Accuracy: 0.3769230769230769
# Std Accuracy: 0.0890448992522325
# Mean Balanced Accuracy: 0.30785714285714283
# Std Balanced Accuracy: 0.07687703236543537
# Mean Random Balanced Accuracy: 0.18761904761904763
# Std Random Balanced Accuracy: 0.0423309853474231
# Mean Roc Auc: 0.6531684151089184
# Std Roc Auc: 0.07821980053762606
#
#  MLP Classifier Performance Validation:
# Mean Accuracy: 0.4
# Std Accuracy: 0.04615384615384615
# Mean Balanced Accuracy: 0.3231746031746031
# Std Balanced Accuracy: 0.03828787274444133
# Mean Random Balanced Accuracy: 0.15198412698412697
# Std Random Balanced Accuracy: 0.04215174927860239
# Mean Roc Auc: 0.6493737043531094
# Std Roc Auc: 0.06646836295718578
#
#  CNN Classifier Performance Validation:
# Mean Accuracy: 0.3769230769230769
# Std Accuracy: 0.0565266863719195
# Mean Balanced Accuracy: 0.2976190476190476
# Std Balanced Accuracy: 0.058848015593386115
# Mean Random Balanced Accuracy: 0.19714285714285712
# Std Random Balanced Accuracy: 0.059930567872184294
# Mean Roc Auc: 0.6554422832443427
# Std Roc Auc: 0.06117772177468131
#
#  TabPFN Classifier Performance Control:
# Mean Accuracy: 0.10344827586206898
# Std Accuracy: 0.035439318605335286
# Mean Balanced Accuracy: 0.2750186814371996
# Std Balanced Accuracy: 0.029117032406513615
# Mean Random Balanced Accuracy: 0.20972998815128735
# Std Random Balanced Accuracy: 0.014445654255733714
# Mean Roc Auc: 0.5422803454327089
# Std Roc Auc: 0.016567616213925756
#
#  LGBM Classifier Performance Control:
# Mean Accuracy: 0.1021551724137931
# Std Accuracy: 0.009000264231819438
# Mean Balanced Accuracy: 0.17537551614692468
# Std Balanced Accuracy: 0.048195920632283375
# Mean Random Balanced Accuracy: 0.18630825942020746
# Std Random Balanced Accuracy: 0.01905117887107468
# Mean Roc Auc: 0.5090066184056056
# Std Roc Auc: 0.05318023616473259
#
#  MLP Classifier Performance Control:
# Mean Accuracy: 0.13060344827586207
# Std Accuracy: 0.02745117815188045
# Mean Balanced Accuracy: 0.1682236071736719
# Std Balanced Accuracy: 0.025250656915750687
# Mean Random Balanced Accuracy: 0.19826974861604865
# Std Random Balanced Accuracy: 0.02924058376703013
# Mean Roc Auc: 0.538853921668262
# Std Roc Auc: 0.017261675766333414
#
#  CNN Classifier Performance Control:
# Mean Accuracy: 0.09999999999999999
# Std Accuracy: 0.024253111890750342
# Mean Balanced Accuracy: 0.1548846565697029
# Std Balanced Accuracy: 0.07363371884805538
# Mean Random Balanced Accuracy: 0.19252254842314165
# Std Random Balanced Accuracy: 0.013903919816657487
# Mean Roc Auc: 0.5487390172859545
# Std Roc Auc: 0.03858638905892523
#
# === Deconfounding Strategy: Correlation_in_Feature ===
#
#  #### TRAINING WITH 0.01 OF THE DATA ####
# Training data shape: (100, 192), length of y: 100
# Training data class distribution: label_age_group
# 2.0    29
# 3.0    27
# 4.0    21
# 1.0    11
# 0.0    10
# 5.0     2
# Name: count, dtype: int64
#
# Fold 1
# RANDOM PERFORMANCE
# Accuracy: 0.11538461538461539
# Balanced Accuracy: 0.1126984126984127
# Random Balanced Accuracy: 0.08888888888888889
#
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       0.25      0.33      0.29         3
#          1.0       0.00      0.00      0.00         3
#          2.0       0.12      0.14      0.13         7
#          3.0       0.00      0.00      0.00         7
#          4.0       0.33      0.20      0.25         5
#          5.0       0.00      0.00      0.00         1
#
#     accuracy                           0.12        26
#    macro avg       0.12      0.11      0.11        26
# weighted avg       0.13      0.12      0.12        26
#
# Roc Auc: 0.5112672986814863
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# CNN PERFORMANCE
# Accuracy: 0.34615384615384615
# Balanced Accuracy: 0.27460317460317457
# Random Balanced Accuracy: 0.10714285714285714
#
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       1.00      0.33      0.50         3
#          1.0       0.00      0.00      0.00         3
#          2.0       0.29      0.29      0.29         7
#          3.0       0.30      0.43      0.35         7
#          4.0       0.38      0.60      0.46         5
#          5.0       0.00      0.00      0.00         1
#
#     accuracy                           0.35        26
#    macro avg       0.33      0.27      0.27        26
# weighted avg       0.35      0.35      0.32        26
#
# Roc Auc: 0.5574436090225564
# CNN PERFORMANCE FOR CONTROL
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Accuracy: 0.1206896551724138
# Balanced Accuracy: 0.13655427631578948
# Random Balanced Accuracy: 0.18017802932966756
#
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       1.00      0.06      0.11       320
#          1.0       0.00      0.00      0.00        61
#          2.0       0.22      0.49      0.31        76
#          3.0       0.00      0.00      0.00         7
#          4.0       0.00      0.00      0.00         0
#
#     accuracy                           0.12       464
#    macro avg       0.24      0.11      0.08       464
# weighted avg       0.73      0.12      0.13       464
#
# Roc Auc: 0.5453958250090628
# CUDA memory cleared and model deleted.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# MLP PERFORMANCE
# Accuracy: 0.2692307692307692
# Balanced Accuracy: 0.2396825396825397
# Random Balanced Accuracy: 0.21587301587301588
#
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       0.50      0.33      0.40         3
#          1.0       0.50      0.33      0.40         3
#          2.0       0.17      0.29      0.21         7
#          3.0       0.33      0.29      0.31         7
#          4.0       0.25      0.20      0.22         5
#          5.0       0.00      0.00      0.00         1
#
#     accuracy                           0.27        26
#    macro avg       0.29      0.24      0.26        26
# weighted avg       0.30      0.27      0.27        26
#
# Roc Auc: 0.6342050779121718
# MLP PERFORMANCE FOR CONTROL
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Accuracy: 0.15517241379310345
# Balanced Accuracy: 0.19984554110686553
# Random Balanced Accuracy: 0.17949386574536103
#
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       1.00      0.09      0.16       320
#          1.0       0.03      0.02      0.02        61
#          2.0       0.25      0.55      0.34        76
#          3.0       0.01      0.14      0.01         7
#          4.0       0.00      0.00      0.00         0
#
#     accuracy                           0.16       464
#    macro avg       0.26      0.16      0.11       464
# weighted avg       0.73      0.16      0.17       464
#
# Roc Auc: 0.5692223114065713
# CUDA memory cleared and model deleted.
# tabpfn PERFORMANCE
# Accuracy: 0.23076923076923078
# Balanced Accuracy: 0.19365079365079363
# Random Balanced Accuracy: 0.22916666666666666
#
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       0.50      0.33      0.40         3
#          1.0       0.00      0.00      0.00         3
#          2.0       0.15      0.29      0.20         7
#          3.0       0.20      0.14      0.17         7
#          4.0       0.50      0.40      0.44         5
#          5.0       0.00      0.00      0.00         1
#
#     accuracy                           0.23        26
#    macro avg       0.23      0.19      0.20        26
# weighted avg       0.25      0.23      0.23        26
#
# Roc Auc: 0.7351603646798154
# tabpfn PERFORMANCE FOR CONTROL
# Accuracy: 0.12931034482758622
# Balanced Accuracy: 0.21707001879699248
# Random Balanced Accuracy: 0.20019617065887896
#
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       1.00      0.06      0.11       320
#          1.0       0.00      0.00      0.00        61
#          2.0       0.21      0.53      0.30        76
#          3.0       0.01      0.29      0.03         7
#          4.0       0.00      0.00      0.00         0
#
#     accuracy                           0.13       464
#    macro avg       0.24      0.17      0.09       464
# weighted avg       0.72      0.13      0.12       464
#
# Roc Auc: 0.5540448320362622
# CUDA memory cleared and model deleted.
# LGBM PERFORMANCE
# Accuracy: 0.23076923076923078
# Balanced Accuracy: 0.21587301587301586
# Random Balanced Accuracy: 0.027777777777777776
#
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       0.33      0.33      0.33         3
#          1.0       0.33      0.33      0.33         3
#          2.0       0.17      0.29      0.21         7
#          3.0       0.17      0.14      0.15         7
#          4.0       0.50      0.20      0.29         5
#          5.0       0.00      0.00      0.00         1
#
#     accuracy                           0.23        26
#    macro avg       0.25      0.22      0.22        26
# weighted avg       0.26      0.23      0.23        26
#
# Roc Auc: 0.6727049507827539
# LGBM PERFORMANCE FOR CONTROL
# Accuracy: 0.16810344827586207
# Balanced Accuracy: 0.22101806129052137
# Random Balanced Accuracy: 0.18388829017173416
#
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       1.00      0.13      0.23       320
#          1.0       0.11      0.05      0.07        61
#          2.0       0.20      0.42      0.27        76
#          3.0       0.01      0.29      0.02         7
#          4.0       0.00      0.00      0.00         0
#
#     accuracy                           0.17       464
#    macro avg       0.26      0.18      0.12       464
# weighted avg       0.74      0.17      0.21       464
#
# Roc Auc: 0.5791866544470401
# CUDA memory cleared and model deleted.
#
# Fold 2
# RANDOM PERFORMANCE
# Accuracy: 0.15384615384615385
# Balanced Accuracy: 0.11428571428571428
# Random Balanced Accuracy: 0.075
#
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       0.00      0.00      0.00         3
#          1.0       0.00      0.00      0.00         3
#          2.0       0.25      0.14      0.18         7
#          3.0       0.17      0.14      0.15         7
#          4.0       0.40      0.40      0.40         5
#          5.0       0.00      0.00      0.00         1
#
#     accuracy                           0.15        26
#    macro avg       0.14      0.11      0.12        26
# weighted avg       0.19      0.15      0.17        26
#
# Roc Auc: 0.532107079292434
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# CNN PERFORMANCE
# Accuracy: 0.19230769230769232
# Balanced Accuracy: 0.16984126984126982
# Random Balanced Accuracy: 0.2222222222222222
#
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       0.25      0.33      0.29         3
#          1.0       0.00      0.00      0.00         3
#          2.0       0.25      0.14      0.18         7
#          3.0       0.12      0.14      0.13         7
#          4.0       0.50      0.40      0.44         5
#          5.0       0.00      0.00      0.00         1
#
#     accuracy                           0.19        26
#    macro avg       0.19      0.17      0.17        26
# weighted avg       0.23      0.19      0.20        26
#
# Roc Auc: 0.6542457593258509
# CNN PERFORMANCE FOR CONTROL
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Accuracy: 0.12931034482758622
# Balanced Accuracy: 0.23428236318254653
# Random Balanced Accuracy: 0.20825080339927157
#
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       1.00      0.08      0.15       320
#          1.0       0.09      0.10      0.09        61
#          2.0       0.17      0.33      0.23        76
#          3.0       0.02      0.43      0.03         7
#          4.0       0.00      0.00      0.00         0
#
#     accuracy                           0.13       464
#    macro avg       0.26      0.19      0.10       464
# weighted avg       0.73      0.13      0.15       464
#
# Roc Auc: 0.590108914217334
# CUDA memory cleared and model deleted.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# MLP PERFORMANCE
# Accuracy: 0.46153846153846156
# Balanced Accuracy: 0.42857142857142855
# Random Balanced Accuracy: 0.25925925925925924
#
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       0.60      1.00      0.75         3
#          1.0       0.00      0.00      0.00         3
#          2.0       0.50      0.29      0.36         7
#          3.0       0.33      0.29      0.31         7
#          4.0       0.45      1.00      0.62         5
#          5.0       0.00      0.00      0.00         1
#
#     accuracy                           0.46        26
#    macro avg       0.31      0.43      0.34        26
# weighted avg       0.38      0.46      0.39        26
#
# Roc Auc: 0.6199535069557953
# MLP PERFORMANCE FOR CONTROL
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Accuracy: 0.11206896551724138
# Balanced Accuracy: 0.14973220063478368
# Random Balanced Accuracy: 0.17085321220835242
#
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       0.97      0.11      0.20       320
#          1.0       0.10      0.03      0.05        61
#          2.0       0.10      0.17      0.13        76
#          3.0       0.02      0.29      0.03         7
#          4.0       0.00      0.00      0.00         0
#
#     accuracy                           0.11       464
#    macro avg       0.24      0.12      0.08       464
# weighted avg       0.70      0.11      0.16       464
#
# Roc Auc: 0.5439743905771555
# CUDA memory cleared and model deleted.
# tabpfn PERFORMANCE
# Accuracy: 0.19230769230769232
# ...
#          2.0       0.00      0.00      0.00         7
#          3.0       0.30      0.43      0.35         7
#          4.0       0.50      0.80      0.62         5
#          5.0       0.00      0.00      0.00         1
#
#     accuracy                           0.38        26
#    macro avg       0.38      0.37      0.34        26
# weighted avg       0.35      0.38      0.34        26
#
# Roc Auc: 0.6369619701427482
# MLP PERFORMANCE FOR CONTROL
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Accuracy: 0.08405172413793104
# Balanced Accuracy: 0.2086331350918279
# Random Balanced Accuracy: 0.2510011441647597
#
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       1.00      0.06      0.12       320
#          1.0       0.06      0.02      0.03        61
#          2.0       0.12      0.18      0.14        76
#          3.0       0.02      0.57      0.03         7
#          4.0       0.00      0.00      0.00         0
#
#     accuracy                           0.08       464
#    macro avg       0.24      0.17      0.06       464
# weighted avg       0.72      0.08      0.11       464
#
# Roc Auc: 0.5648664075658034
# CUDA memory cleared and model deleted.
# tabpfn PERFORMANCE
# Accuracy: 0.2692307692307692
# Balanced Accuracy: 0.21746031746031744
# Random Balanced Accuracy: 0.11428571428571428
#
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       0.25      0.33      0.29         3
#          1.0       0.00      0.00      0.00         3
#          2.0       0.23      0.43      0.30         7
#          3.0       0.25      0.14      0.18         7
#          4.0       0.40      0.40      0.40         5
#          5.0       0.00      0.00      0.00         1
#
#     accuracy                           0.27        26
#    macro avg       0.19      0.22      0.19        26
# weighted avg       0.24      0.27      0.24        26
#
# Roc Auc: 0.6399636773092151
# tabpfn PERFORMANCE FOR CONTROL
# Accuracy: 0.17025862068965517
# Balanced Accuracy: 0.17924107142857143
# Random Balanced Accuracy: 0.22333495381623725
#
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       0.97      0.18      0.31       320
#          1.0       0.00      0.00      0.00        61
#          2.0       0.09      0.25      0.14        76
#          3.0       0.02      0.29      0.03         7
#          4.0       0.00      0.00      0.00         0
#
#     accuracy                           0.17       464
#    macro avg       0.22      0.14      0.09       464
# weighted avg       0.68      0.17      0.23       464
#
# Roc Auc: 0.529241255016973
# CUDA memory cleared and model deleted.
# LGBM PERFORMANCE
# Accuracy: 0.34615384615384615
# Balanced Accuracy: 0.2968253968253968
# Random Balanced Accuracy: 0.14444444444444446
#
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       0.33      0.67      0.44         3
#          1.0       0.00      0.00      0.00         3
#          2.0       0.33      0.43      0.38         7
#          3.0       0.50      0.29      0.36         7
#          4.0       0.50      0.40      0.44         5
#          5.0       0.00      0.00      0.00         1
#
#     accuracy                           0.35        26
#    macro avg       0.28      0.30      0.27        26
# weighted avg       0.36      0.35      0.34        26
#
# Roc Auc: 0.7036431658857287
# LGBM PERFORMANCE FOR CONTROL
# Accuracy: 0.13793103448275862
# Balanced Accuracy: 0.19090522155799333
# Random Balanced Accuracy: 0.22905892425707738
#
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       0.89      0.11      0.19       320
#          1.0       0.02      0.02      0.02        61
#          2.0       0.17      0.36      0.23        76
#          3.0       0.01      0.29      0.03         7
#          4.0       0.00      0.00      0.00         0
#
#     accuracy                           0.14       464
#    macro avg       0.22      0.15      0.09       464
# weighted avg       0.65      0.14      0.17       464
#
# Roc Auc: 0.4773999889862316
# CUDA memory cleared and model deleted.
#
# Fold 3
# RANDOM PERFORMANCE
# Accuracy: 0.11538461538461539
# Balanced Accuracy: 0.1111111111111111
# Random Balanced Accuracy: 0.17777777777777778
#
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       0.14      0.33      0.20         3
#          1.0       0.00      0.00      0.00         4
#          2.0       0.50      0.17      0.25         6
#          3.0       0.00      0.00      0.00         6
#          4.0       0.25      0.17      0.20         6
#          5.0       0.00      0.00      0.00         1
#
#     accuracy                           0.12        26
#    macro avg       0.15      0.11      0.11        26
# weighted avg       0.19      0.12      0.13        26
#
# Roc Auc: 0.6265327184892402
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# CNN PERFORMANCE
# Accuracy: 0.15384615384615385
# Balanced Accuracy: 0.13888888888888887
# Random Balanced Accuracy: 0.1111111111111111
#
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       0.50      0.33      0.40         3
#          1.0       0.00      0.00      0.00         4
#          2.0       0.10      0.33      0.15         6
#          3.0       0.25      0.17      0.20         6
#          4.0       0.00      0.00      0.00         6
#          5.0       0.00      0.00      0.00         1
#
#     accuracy                           0.15        26
#    macro avg       0.14      0.14      0.13        26
# weighted avg       0.14      0.15      0.13        26
#
# Roc Auc: 0.5754303908651736
# CNN PERFORMANCE FOR CONTROL
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Accuracy: 0.23060344827586207
# Balanced Accuracy: 0.25397086466165414
# Random Balanced Accuracy: 0.2543459373896275
#
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       0.98      0.16      0.28       320
#          1.0       0.00      0.00      0.00        61
#          2.0       0.16      0.71      0.27        76
#          3.0       0.01      0.14      0.02         7
#          4.0       0.00      0.00      0.00         0
#
#     accuracy                           0.23       464
#    macro avg       0.23      0.20      0.11       464
# weighted avg       0.70      0.23      0.24       464
#
# Roc Auc: 0.5854765864808047
# CUDA memory cleared and model deleted.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# MLP PERFORMANCE
# Accuracy: 0.38461538461538464
# Balanced Accuracy: 0.3333333333333333
# Random Balanced Accuracy: 0.3083333333333333
#
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       0.67      0.67      0.67         3
#          1.0       0.00      0.00      0.00         4
#          2.0       0.30      0.50      0.38         6
#          3.0       0.62      0.83      0.71         6
#          4.0       0.00      0.00      0.00         6
#          5.0       0.00      0.00      0.00         1
#
#     accuracy                           0.38        26
#    macro avg       0.27      0.33      0.29        26
# weighted avg       0.29      0.38      0.33        26
#
# Roc Auc: 0.7451943346508564
# MLP PERFORMANCE FOR CONTROL
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Accuracy: 0.10560344827586207
# Balanced Accuracy: 0.2206531954887218
# Random Balanced Accuracy: 0.1732245828171125
#
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       0.93      0.09      0.16       320
#          1.0       0.00      0.00      0.00        61
#          2.0       0.12      0.22      0.16        76
#          3.0       0.03      0.57      0.05         7
#          4.0       0.00      0.00      0.00         0
#
#     accuracy                           0.11       464
#    macro avg       0.22      0.18      0.07       464
# weighted avg       0.66      0.11      0.14       464
#
# Roc Auc: 0.6060977045685366
# CUDA memory cleared and model deleted.
# tabpfn PERFORMANCE
# Accuracy: 0.4230769230769231
# Balanced Accuracy: 0.3611111111111111
# Random Balanced Accuracy: 0.09325396825396826
#
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       0.67      0.67      0.67         3
#          1.0       0.00      0.00      0.00         4
#          2.0       0.30      0.50      0.38         6
#          3.0       0.43      0.50      0.46         6
#          4.0       0.50      0.50      0.50         6
#          5.0       0.00      0.00      0.00         1
#
#     accuracy                           0.42        26
#    macro avg       0.32      0.36      0.33        26
# weighted avg       0.36      0.42      0.39        26
#
# Roc Auc: 0.7106686429512518
# tabpfn PERFORMANCE FOR CONTROL
# Accuracy: 0.07974137931034483
# Balanced Accuracy: 0.2112781954887218
# Random Balanced Accuracy: 0.19317474835642387
#
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       0.94      0.05      0.09       320
#          1.0       0.00      0.00      0.00        61
#          2.0       0.08      0.22      0.12        76
#          3.0       0.03      0.57      0.06         7
#          4.0       0.00      0.00      0.00         0
#
#     accuracy                           0.08       464
#    macro avg       0.21      0.17      0.05       464
# weighted avg       0.66      0.08      0.09       464
#
# Roc Auc: 0.5570424903230715
# CUDA memory cleared and model deleted.
# LGBM PERFORMANCE
# Accuracy: 0.34615384615384615
# Balanced Accuracy: 0.25
# Random Balanced Accuracy: 0.10416666666666667
#
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       0.00      0.00      0.00         3
#          1.0       0.00      0.00      0.00         4
#          2.0       0.31      0.67      0.42         6
#          3.0       0.67      0.67      0.67         6
#          4.0       0.20      0.17      0.18         6
#          5.0       0.00      0.00      0.00         1
#
#     accuracy                           0.35        26
#    macro avg       0.20      0.25      0.21        26
# weighted avg       0.27      0.35      0.29        26
#
# Roc Auc: 0.6115447957839263
# LGBM PERFORMANCE FOR CONTROL
# Accuracy: 0.11206896551724138
# Balanced Accuracy: 0.21225569687538517
# Random Balanced Accuracy: 0.20077742306003174
#
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       0.88      0.07      0.13       320
#          1.0       0.07      0.03      0.04        61
#          2.0       0.12      0.32      0.18        76
#          3.0       0.02      0.43      0.04         7
#          4.0       0.00      0.00      0.00         0
#
#     accuracy                           0.11       464
#    macro avg       0.22      0.17      0.08       464
# weighted avg       0.64      0.11      0.13       464
#
# Roc Auc: 0.49590473473259145
# CUDA memory cleared and model deleted.
#
# Fold 4
# RANDOM PERFORMANCE
# Accuracy: 0.23076923076923078
# Balanced Accuracy: 0.19603174603174603
# Random Balanced Accuracy: 0.28888888888888886
#
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       0.00      0.00      0.00         3
#          1.0       1.00      0.33      0.50         3
#          2.0       0.17      0.14      0.15         7
#          3.0       0.43      0.50      0.46         6
#          4.0       0.50      0.20      0.29         5
#          5.0       0.00      0.00      0.00         2
#
#     accuracy                           0.23        26
#    macro avg       0.35      0.20      0.23        26
# weighted avg       0.36      0.23      0.26        26
#
# Roc Auc: 0.6565737259816207
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# CNN PERFORMANCE
# Accuracy: 0.23076923076923078
# Balanced Accuracy: 0.1714285714285714
# Random Balanced Accuracy: 0.2738095238095238
#
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       0.00      0.00      0.00         3
#          1.0       0.00      0.00      0.00         3
#          2.0       0.33      0.43      0.38         7
#          3.0       0.00      0.00      0.00         6
#          4.0       0.23      0.60      0.33         5
#          5.0       0.00      0.00      0.00         2
#
#     accuracy                           0.23        26
#    macro avg       0.09      0.17      0.12        26
# weighted avg       0.13      0.23      0.17        26
#
# Roc Auc: 0.4803557807562384
# CNN PERFORMANCE FOR CONTROL
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Accuracy: 0.14655172413793102
# Balanced Accuracy: 0.15076362781954888
# Random Balanced Accuracy: 0.1448600101197504
#
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       0.98      0.13      0.23       320
#          1.0       0.00      0.00      0.00        61
#          2.0       0.14      0.33      0.20        76
#          3.0       0.03      0.14      0.05         7
#          4.0       0.00      0.00      0.00         0
#
#     accuracy                           0.15       464
#    macro avg       0.23      0.12      0.10       464
# weighted avg       0.70      0.15      0.19       464
#
# Roc Auc: 0.589098745474997
# CUDA memory cleared and model deleted.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# MLP PERFORMANCE
# Accuracy: 0.19230769230769232
# Balanced Accuracy: 0.19444444444444442
# Random Balanced Accuracy: 0.18888888888888888
#
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       0.50      0.67      0.57         3
#          1.0       0.00      0.00      0.00         3
#          2.0       0.00      0.00      0.00         7
#          3.0       0.21      0.50      0.30         6
#          4.0       0.00      0.00      0.00         5
#          5.0       0.00      0.00      0.00         2
#
#     accuracy                           0.19        26
#    macro avg       0.12      0.19      0.15        26
# weighted avg       0.11      0.19      0.14        26
#
# Roc Auc: 0.6292134321310522
# MLP PERFORMANCE FOR CONTROL
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Accuracy: 0.16163793103448276
# Balanced Accuracy: 0.2442828061444595
# Random Balanced Accuracy: 0.16753377766147212
#
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       1.00      0.17      0.28       320
#          1.0       0.06      0.02      0.03        61
#          2.0       0.18      0.22      0.20        76
#          3.0       0.02      0.57      0.04         7
#          4.0       0.00      0.00      0.00         0
#
#     accuracy                           0.16       464
#    macro avg       0.25      0.20      0.11       464
# weighted avg       0.73      0.16      0.23       464
#
# Roc Auc: 0.5716158501485071
# CUDA memory cleared and model deleted.
# tabpfn PERFORMANCE
# Accuracy: 0.34615384615384615
# Balanced Accuracy: 0.24523809523809526
# Random Balanced Accuracy: 0.19444444444444442
#
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       0.00      0.00      0.00         3
#          1.0       0.00      0.00      0.00         3
#          2.0       0.33      0.57      0.42         7
#          3.0       0.33      0.50      0.40         6
#          4.0       0.40      0.40      0.40         5
#          5.0       0.00      0.00      0.00         2
#
#     accuracy                           0.35        26
#    macro avg       0.18      0.25      0.20        26
# weighted avg       0.24      0.35      0.28        26
#
# Roc Auc: 0.7155946932548763
# tabpfn PERFORMANCE FOR CONTROL
# Accuracy: 0.10129310344827586
# Balanced Accuracy: 0.16409187030075187
# Random Balanced Accuracy: 0.20028014605367295
#
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       1.00      0.11      0.20       320
#          1.0       0.00      0.00      0.00        61
#          2.0       0.05      0.12      0.07        76
#          3.0       0.02      0.43      0.03         7
#          4.0       0.00      0.00      0.00         0
#
#     accuracy                           0.10       464
#    macro avg       0.21      0.13      0.06       464
# weighted avg       0.70      0.10      0.15       464
#
# Roc Auc: 0.5451314117394996
# CUDA memory cleared and model deleted.

# %%
for percentage, models in percentage_dict.items():
    print(f"\nResults for {percentage*100:.0f}% of the data:")
    for model, results in models.items():
        print(f"  {model} - Results: {results['results']}")
        if 'results_eval' in results:
            print(f"  {model} - Evaluation Results: {results['results_eval']}")
# Out:
# Results for 1% of the data:
#   TabPFN - Results: {'mean_accuracy': 0.4384615384615385, 'std_accuracy': 0.05217176910096361, 'mean_balanced_accuracy': 0.3692857142857143, 'std_balanced_accuracy': 0.04836166969816029, 'mean_random_balanced_accuracy': 0.11039682539682538, 'std_random_balanced_accuracy': 0.010842559592341622, 'mean_roc_auc': 0.810111207696448, 'std_roc_auc': 0.03102397465316427}
#   TabPFN - Evaluation Results: {'mean_accuracy': 0.09051724137931035, 'std_accuracy': 0.02786763771593899, 'mean_balanced_accuracy': 0.2384368451867373, 'std_balanced_accuracy': 0.03958976135137044, 'mean_random_balanced_accuracy': 0.1960002863992195, 'std_random_balanced_accuracy': 0.01798297888384614, 'mean_roc_auc': 0.5415129034561159, 'std_roc_auc': 0.03607018924889107}
#   LGBM - Results: {'mean_accuracy': 0.36923076923076925, 'std_accuracy': 0.018842228790639848, 'mean_balanced_accuracy': 0.3336507936507936, 'std_balanced_accuracy': 0.03682265999682292, 'mean_random_balanced_accuracy': 0.14527777777777778, 'std_random_balanced_accuracy': 0.0664672944730557, 'mean_roc_auc': 0.6413536567043432, 'std_roc_auc': 0.036912372896314875}
#   LGBM - Evaluation Results: {'mean_accuracy': 0.10043103448275863, 'std_accuracy': 0.014718423343934372, 'mean_balanced_accuracy': 0.17439054218538147, 'std_balanced_accuracy': 0.031173774640224375, 'mean_random_balanced_accuracy': 0.1996903840707246, 'std_random_balanced_accuracy': 0.011782852000437327, 'mean_roc_auc': 0.49068629873420233, 'std_roc_auc': 0.03327142858163014}
#   Random - Results: {'mean_accuracy': 0.2230769230769231, 'std_accuracy': 0.02878197989826108, 'mean_balanced_accuracy': 0.1969047619047619, 'std_balanced_accuracy': 0.05049789889584453, 'mean_random_balanced_accuracy': 0.16817460317460317, 'std_random_balanced_accuracy': 0.07109507684874529, 'mean_roc_auc': 0.49999979774865366, 'std_roc_auc': 0.062376774709205565}
#   Random - Evaluation Results: {'mean_accuracy': 0.2230769230769231, 'std_accuracy': 0.02878197989826108, 'mean_balanced_accuracy': 0.1969047619047619, 'std_balanced_accuracy': 0.05049789889584453, 'mean_random_balanced_accuracy': 0.16817460317460317, 'std_random_balanced_accuracy': 0.07109507684874529, 'mean_roc_auc': 0.49999979774865366, 'std_roc_auc': 0.062376774709205565}
#   MLP - Results: {'mean_accuracy': 0.3846153846153846, 'std_accuracy': 0.0910166120476864, 'mean_balanced_accuracy': 0.3233333333333333, 'std_balanced_accuracy': 0.08977393853626131, 'mean_random_balanced_accuracy': 0.23113997113997115, 'std_random_balanced_accuracy': 0.06549110337050636, 'mean_roc_auc': 0.6831045821074426, 'std_roc_auc': 0.06278898074836058}
#   MLP - Evaluation Results: {'mean_accuracy': 0.15387931034482757, 'std_accuracy': 0.051949938172243096, 'mean_balanced_accuracy': 0.2477887726488352, 'std_balanced_accuracy': 0.031155437649682094, 'mean_random_balanced_accuracy': 0.21033949078831551, 'std_random_balanced_accuracy': 0.015669909206086758, 'mean_roc_auc': 0.5643282323370773, 'std_roc_auc': 0.0488244324669222}
#   CNN - Results: {'mean_accuracy': 0.3615384615384616, 'std_accuracy': 0.10204999354939691, 'mean_balanced_accuracy': 0.3066666666666667, 'std_balanced_accuracy': 0.08323365164364714, 'mean_random_balanced_accuracy': 0.15388888888888888, 'std_random_balanced_accuracy': 0.04936635531449568, 'mean_roc_auc': 0.7112754844951642, 'std_roc_auc': 0.02879781623375072}
#   CNN - Evaluation Results: {'mean_accuracy': 0.13577586206896552, 'std_accuracy': 0.054504987826607176, 'mean_balanced_accuracy': 0.2086283010292124, 'std_balanced_accuracy': 0.08054408061309619, 'mean_random_balanced_accuracy': 0.21042134847128838, 'std_random_balanced_accuracy': 0.039079774249885624, 'mean_roc_auc': 0.5634544066518326, 'std_roc_auc': 0.0350692024273905}

# %%
Feature_extraction_applied = False
Pretraining_applied = False
all_rows = []
for percentage, model in percentage_dict.items():
    for model_name, train_summary in models.items():
        for i, (cv_result, cv_result_eval) in enumerate(zip(train_summary["cv_results"], train_summary["cv_results_eval"])):
            row_train = {
                        "label_col": label_col,
                        "mri_table": mri_table,
                        "test_set_size": f"{(1 - percentage):.2%} (approx. of data left for test)",
                        "Feature_extraction_applied": Feature_extraction_applied,
                        "Pretraining_applied": Pretraining_applied,
                        "model_type": model_name,
                        "Accuracy": cv_result.get("accuracy", None),
                        "AUC": cv_result.get("roc_auc", None),  # or "auc" or whatever your aggregator uses
                        "Balanced_ACC": cv_result.get("balanced_accuracy", None),
                        "Permutation_Balanced_ACC": cv_result.get("random_balanced_accuracy", None), 
                        "number_of_cross_validations": n_splits,
                        "cross_validation_count": i,
                        "search_term": f"{percentage}_{model_name}_train",
                        "percentage_of_data": percentage,  # storing the used fraction
                        "eval_or_train": "train"
                    }
            row_eval = {
                        "label_col": label_col,
                        "mri_table": mri_table,
                        "test_set_size": f"{(1 - percentage):.2%} (approx. of data left for test)",
                        "Feature_extraction_applied": Feature_extraction_applied,
                        "Pretraining_applied": Pretraining_applied,
                        "model_type": model_name,
                        "Accuracy": cv_result_eval.get("accuracy", None),
                        "AUC": cv_result_eval.get("roc_auc", None),  # or "auc" or whatever your aggregator uses
                        "Balanced_ACC": cv_result_eval.get("balanced_accuracy", None),
                        "Permutation_Balanced_ACC": cv_result_eval.get("random_balanced_accuracy", None), 
                        "number_of_cross_validations": n_splits,
                        "cross_validation_count": i,
                        "search_term": f"{percentage}_{model_name}_eval",
                        "percentage_of_data": percentage,  # storing the used fraction
                        "eval_or_train": "eval"
                    }
        all_rows.append(row_eval)
        all_rows.append(row_train)
df_results = pd.DataFrame(all_rows)
df_results.to_csv("results_classification.csv", index=False)

# %%
print(percentage_dict)
# Out:
# {0.01: {'TabPFN': {'results': {'mean_accuracy': 0.4384615384615385, 'std_accuracy': 0.05217176910096361, 'mean_balanced_accuracy': 0.3692857142857143, 'std_balanced_accuracy': 0.04836166969816029, 'mean_random_balanced_accuracy': 0.11039682539682538, 'std_random_balanced_accuracy': 0.010842559592341622, 'mean_roc_auc': 0.810111207696448, 'std_roc_auc': 0.03102397465316427}, 'results_eval': {'mean_accuracy': 0.09051724137931035, 'std_accuracy': 0.02786763771593899, 'mean_balanced_accuracy': 0.2384368451867373, 'std_balanced_accuracy': 0.03958976135137044, 'mean_random_balanced_accuracy': 0.1960002863992195, 'std_random_balanced_accuracy': 0.01798297888384614, 'mean_roc_auc': 0.5415129034561159, 'std_roc_auc': 0.03607018924889107}, 'cv_results': [{'accuracy': 0.5, 'balanced_accuracy': 0.4428571428571429, 'random_balanced_accuracy': 0.1130952380952381, 'classification_report': '              precision    recall  f1-score   support\n\n         0.0       1.00      0.67      0.80         3\n         1.0       0.50      0.33      0.40         3\n         2.0       0.42      0.71      0.53         7\n         3.0       0.20      0.14      0.17         7\n         4.0       0.80      0.80      0.80         5\n         5.0       0.00      0.00      0.00         1\n\n    accuracy                           0.50        26\n   macro avg       0.49      0.44      0.45        26\nweighted avg       0.49      0.50      0.48        26\n', 'roc_auc': 0.8389379245214484}, {'accuracy': 0.46153846153846156, 'balanced_accuracy': 0.3968253968253968, 'random_balanced_accuracy': 0.08888888888888889, 'classification_report': '              precision    recall  f1-score   support\n\n         0.0       0.40      0.67      0.50         3\n         1.0       0.00      0.00      0.00         3\n         2.0       0.27      0.43      0.33         7\n         3.0       0.50      0.29      0.36         7\n         4.0       0.83      1.00      0.91         5\n         5.0       0.00      0.00      0.00         1\n\n    accuracy                           0.46        26\n   macro avg       0.33      0.40      0.35        26\nweighted avg       0.41      0.46      0.42        26\n', 'roc_auc': 0.8310602593440123}, {'accuracy': 0.4230769230769231, 'balanced_accuracy': 0.3194444444444444, 'random_balanced_accuracy': 0.11666666666666665, 'classification_report': '              precision    recall  f1-score   support\n\n         0.0       0.00      0.00      0.00         3\n         1.0       0.50      0.25      0.33         4\n         2.0       0.30      0.50      0.38         6\n         3.0       0.29      0.33      0.31         6\n         4.0       0.71      0.83      0.77         6\n         5.0       0.00      0.00      0.00         1\n\n    accuracy                           0.42        26\n   macro avg       0.30      0.32      0.30        26\nweighted avg       0.38      0.42      0.39        26\n', 'roc_auc': 0.7786089152393499}, {'accuracy': 0.34615384615384615, 'balanced_accuracy': 0.3142857142857143, 'random_balanced_accuracy': 0.11666666666666665, 'classification_report': '              precision    recall  f1-score   support\n\n         0.0       0.00      0.00      0.00         3\n         1.0       0.67      0.67      0.67         3\n         2.0       0.29      0.29      0.29         7\n         3.0       0.33      0.33      0.33         6\n         4.0       0.38      0.60      0.46         5\n         5.0       0.00      0.00      0.00         2\n\n    accuracy                           0.35        26\n   macro avg       0.28      0.31      0.29        26\nweighted avg       0.30      0.35      0.32        26\n', 'roc_auc': 0.7664546329592096}, {'accuracy': 0.46153846153846156, 'balanced_accuracy': 0.373015873015873, 'random_balanced_accuracy': 0.11666666666666665, 'classification_report': '              precision    recall  f1-score   support\n\n         0.0       0.00      0.00      0.00         3\n         1.0       0.20      0.33      0.25    ...

# %%
""" #load a model
import pickle
import os
save_dir = "../98_models/"
with open(os.path.join(save_dir, "tabpfn.pkl"), "rb") as f:
    model = pickle.load(f)
    original_classes = np.unique(y_control)
    results, balanced_accuracy = predict_and_evaluate(model, X_control, y_control, original_classes=original_classes)
    print_model_performance(results) """
# Out:
# ' #load a model\nimport pickle\nimport os\nsave_dir = "../98_models/"\nwith open(os.path.join(save_dir, "tabpfn.pkl"), "rb") as f:\n    model = pickle.load(f)\n    original_classes = np.unique(y_control)\n    results, balanced_accuracy = predict_and_evaluate(model, X_control, y_control, original_classes=original_classes)\n    print_model_performance(results) '
